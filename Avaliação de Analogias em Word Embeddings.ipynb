# %% [markdown]
# !pip install gensim sklearn numpy

# %% [markdown]
# ### Bibliotecas Usadas

# %%
from gensim.models import KeyedVectors, FastText
from gensim.models.fasttext import load_facebook_vectors
import fasttext
import nltk

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from glob import glob

import multiprocessing
from itertools import product

# %% [markdown]
# ### Funções Utilizadas

# %%
def getModel(modelFile, facebook_model=False):
    if(facebook_model):
        model = load_facebook_vectors(modelFile)
    else:
        model = KeyedVectors.load_word2vec_format(modelFile)
    return model

def analogy(model, pos, neg=[], n=5):
    return model.most_similar(pos,neg,n)

def showList(resultList):
    for el in resultList:
        print("\t",el,"\n")
        
def trainUnsupervisedTxt(inFile, outFile, dimension=100,model="skipgram"):
    model = fasttext.train_unsupervised(inFile, model=model, dim=dimension)
    model.save_model(outFile)
    
    return 'Model %s saved(%s %s) @ %s' % (inFile, dimension, model, outFile)

def eval_analogies_acc_keydvec(model_ref,test_set,case_insensitive=True,dummy4unknown=False):
    if(isinstance(model_ref, str)):
        model = getModel(model_ref)
    else:
        model = model_ref
    for test in test_set:
        acc_ = model.evaluate_word_analogies(test, case_insensitive=case_insensitive, dummy4unknown=dummy4unknown)
        
        obs = ''
        if(dummy4unknown):
            obs += ' | setting 0 to missing words'
        if(case_insensitive):
            obs += ' | case insensitive'
        else:
            obs += ' | case sensitive'
        log_str =  test + ' %.4f ' % acc_[0] + obs     
        
    return acc_[0], acc_[1], log_str

def get_facebook_vecs_word_analogy_accuracy(model_ref, test, case_insensitive=True, dummy4unknown=False):
    if(isinstance(model_ref, str)):
        model = load_facebook_vectors(model_ref)
    else:
        model = model_ref
#     for test in test_set:
    acc_ = model.evaluate_word_analogies(test, case_insensitive=case_insensitive, dummy4unknown=dummy4unknown)

    obs = ''
    if(dummy4unknown):
        obs += ' | setting 0 to missing words'
    if(case_insensitive):
        obs += ' | case insensitive'
    else:
        obs += ' | case sensitive'
    log_str = test + ' %.4f ' % acc_[0] +  obs
    
    return acc_[0], acc_[1], log_str

# WRAPPERS
def evaluate_acc_by_function(model, model_ref, test, case_insensitive, dummy4unknown, acc_func):
    
    acc, res, log = acc_func(model, test, case_insensitive, dummy4unknown)
    print(model_ref + " @ " + log)
    
    return

def eval_all_params(model_ref, test_set, eval_func, facebook_model=False):
    model = getModel(model_ref, facebook_model)

    evaluate_acc_by_function(model, model_ref, test_set, True, 
                                 True, eval_func)
    evaluate_acc_by_function(model, model_ref, test_set, True, 
                            False, eval_func)
    evaluate_acc_by_function(model, model_ref, test_set, False, 
                             True, eval_func)
    evaluate_acc_by_function(model, model_ref, test_set, False, 
                             False, eval_func)
    
def eval_default_param(model_ref, test_set, eval_func, facebook_model=False):
    model = getModel(model_ref, facebook_model)
    
    acc, res, log = eval_func(model, test)
    print(model_ref + " @ " + log)
    
    return

def get_model_info(model_ref, testset, analogy_acc_func, facebook_model=False):
    model_info = {}
    model_info['model_ref'] = model_ref
    model_info['benchmark'] = {}

    model_info['model'] = getModel(model_info['model_ref'], facebook_model)
    
    for test in testset:
        model_info['benchmark'][test] = {
            'accuracy': None,
            'results': None,
            'log' : None
        }
        model_info['benchmark'][test]['accuracy'], \
        model_info['benchmark'][test]['results'], \
        model_info['benchmark'][test]['log'] = analogy_acc_func(model_info['model'], test)

    return model_info

def print_model_acc(model, test, acc, info = ''):
    print(model, ' @ ', test, ' : ', acc, info)
    
def print_tex_table_format(matrix):
    for row in matrix:
        print(str(row[0]) + ' & %.4f' % row[1])

def build_model_accuracy_tuple(model_list, testset, func, facebook_model):
    product_set = product(model_list, testset)
    
    return [(*i, func, facebook_model) for i in product_set]

testset = glob('../testsets/LX-4WAnalogies*')

# %% [markdown]
# ### Eval Mock

# %%
poolMock = multiprocessing.Pool()
# Out:
# ../models/mock.txt @ ../testsets/LX-4WAnalogiesBr.txt0.0 | setting 0 to missing words | case insensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogies.txt0.0 | setting 0 to missing words | case insensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogiesBr.txtNone | case insensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogies.txtNone | case insensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogiesBr.txt0.0 | setting 0 to missing words | case sensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogies.txt0.0 | setting 0 to missing words | case sensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogiesBr.txtNone | case sensitive
# ../models/mock.txt @ ../testsets/LX-4WAnalogies.txtNone | case sensitive

# %%
pool_res = poolMock.starmap(eval_all_params, [('../models/mock.txt','../testsets/LX-4WAnalogiesBr.txt', get_facebook_vecs_word_analogy_accuracy)])

# %%
product_set = product(['../models/mock.txt'],['../testsets/LX-4WAnalogiesBr.txt', '../testsets/LX-4WAnalogies.txt'])

# %%
pool_res = poolMock.starmap(eval_all_params, build_model_accuracy_tuple(['../models/mock.txt'],['../testsets/LX-4WAnalogiesBr.txt', '../testsets/LX-4WAnalogies.txt'], get_facebook_vecs_word_analogy_accuracy, facebook_model=False))

# %%
[(*i, get_facebook_vecs_word_analogy_accuracy) for i in product_set]
# Out:
# [('../models/mock.txt',
#   '../testsets/LX-4WAnalogiesBr.txt',
#   <function __main__.get_facebook_vecs_word_analogy_accuracy(model_ref, test, case_insensitive=True, dummy4unknown=False)>),
#  ('../models/mock.txt',
#   '../testsets/LX-4WAnalogies.txt',
#   <function __main__.get_facebook_vecs_word_analogy_accuracy(model_ref, test, case_insensitive=True, dummy4unknown=False)>)]

# %%
def processTriadAnalogy(word1,word2,word3, modelsList):
    result = []
    for modelFileRef in modelsList:
        model = getModel(modelFileRef)
        if(word1 in model and word2 in model and word3 in model):
            
            v_word1 = model.word_vec(word1)
            v_word2 = model.word_vec(word2)
            v_word3 = model.word_vec(word3)
    #         basisRelation = extract_relation(v_word1, v_word2)
            basisRelation = v_word1 - v_word2 + v_word3
            bestWordOnModel = find_best_related_word(basisRelation, model)
            result.append('Model: ' + modelFileRef + '/n Best Word : ' + bestWordOnModel)
        else:
            print('Fail:Word not found in model')
    return result

# https://datascience-enthusiast.com/DL/Operations_on_word_vectors.html
def similar_cos(u, v):
    distance = 0.0

    # Compute the dot product between u and v (≈1 line)
    dot = np.dot(u, v)
    # Compute the L2 norm of u (≈1 line)
#     norm_u = np.sqrt(np.sum(u**2))
    norm_u = np.linalg.norm(u)
    
    # Compute the L2 norm of v (≈1 line)
#     norm_v = np.sqrt(np.sum(v**2))
    norm_v = np.linalg.norm(v)
    
    # Compute the cosine similarity defined by formula (1) (≈1 line)
    cosine_similarity = dot / (norm_u * norm_v)

    return cosine_similarity

def extract_relation(target, related):
    return target - related

def find_best_related_word(analogy_vector, model):
#     related = target + relation
    max_sim = 0.0
    best_word = None
    for word in model.vocab:
#         relation1 = relation.reshape(1,-1)
#         relation2 = extract_relation(model.word_vec(target), model.word_vec(word)).reshape(1,-1)
        sim = similar_cos(analogy_vector, model[word])
        if(sim > max_sim):
            best_word = word
    return best_word;

def analogy(pos, neg):
    return model.most_similar(pos,neg)

# %%
# result = processTriadAnalogy(word1,word2,word3,modelsList)

# %% [markdown]
# ### Teste 1 - Biblioteca KeyedVector e seus metodos de similaridade

# %%
modelsList = glob('../models/cbow_*.txt')
model = [getModel(x) for x in modelsList]

print(modelsList)
# Out:
# ['../models/cbow_s300.txt', '../models/cbow_s100.txt', '../models/cbow_s50.txt']

# %%
model[0].most_similar(positive=['barack', 'obama'])
# Out:
# [('eisenhower', 0.47269853949546814),
#  ('lula', 0.460972398519516),
#  ('bush', 0.4601280987262726),
#  ('ratsiraka', 0.43053072690963745),
#  ('clinton', 0.4282917082309723),
#  ('saakashvili', 0.4188674986362457),
#  ('uribe', 0.4161287844181061),
#  ('draghi', 0.40998852252960205),
#  ('netanyahu', 0.403103768825531),
#  ('yushchenko', 0.3994860053062439)]

# %% [markdown]
# - Comparação dos modelos para a analogia Rei-Homem, Rainha-X

# %%
word1 = 'rei'
word2 = 'homem'
word3 = 'rainha'

for index, x in enumerate(model):
    nMostSimilar = x.most_similar(positive=[word1,word3], negative=[word2])

    print(modelsList[index], nMostSimilar)
    print('Positive:  ', word1,word3, '\nNegative:',word2)
    print()
# Out:
# ../models/cbow_s300.txt [('princesa', 0.5880060791969299), ('infanta', 0.5544092655181885), ('rainha-mãe', 0.5047087669372559), ('ex-rainha', 0.5002995729446411), ('imperatriz', 0.4982605278491974), ('raínha', 0.498224675655365), ('rainha-consorte', 0.4923296570777893), ('duquesa', 0.4890612065792084), ('condessa', 0.4880494177341461), ('regente', 0.460879385471344)]
# Positive:   rei rainha
# Negative: homem
#
# ../models/cbow_s100.txt [('raínha', 0.6748343706130981), ('princesa', 0.6687842607498169), ('rainha-consorte', 0.6617846488952637), ('rainha-mãe', 0.6472653746604919), ('duquesa', 0.6418556571006775), ('pártia', 0.6328529119491577), ('imperatriz', 0.628162682056427), ('primogénita', 0.6190635561943054), ('condessa', 0.6179429292678833), ('coroação', 0.6084483861923218)]
# Positive:   rei rainha
# Negative: homem
#
# ../models/cbow_s50.txt [('duquesa', 0.7385571002960205), ('princesa', 0.724755048751831), ('grã-duquesa', 0.7228216528892517), ('imperatriz', 0.7180843949317932), ('rainha-consorte', 0.7107272744178772), ('ex-rainha', 0.7102654576301575), ('dinastia', 0.7076348066329956), ('herdeira', 0.7072440981864929), ('czarina', 0.7034566402435303), ('sibila', 0.6953685283660889)]
# Positive:   rei rainha
# Negative: homem

# %% [markdown]
# Troca de Palavras

# %%
word1 = 'rei'
word2 = 'homem'
word3 = 'mulher'

model = getModel(modelsList[2])

list = model.most_similar(positive=[word1,word3], negative=[word2])

# %%
print(modelsList[2], list)
print('Positive:  ', word1,word3, '\nNegative:',word2)
# Out:
# ../models/cbow_s100.txt [('esposa', 0.688875675201416), ('filha', 0.6741011142730713), ('governanta', 0.6724554896354675), ('sobrinha', 0.669994056224823), ('madrasta', 0.6670832633972168), ('concubina', 0.6659663915634155), ('dama-de-companhia', 0.6614803075790405), ('benção', 0.659320056438446), ('múmia', 0.6535747051239014), ('bênção', 0.6500141620635986)]
# Positive:   rei mulher
# Negative: homem

# %% [markdown]
# ### Analise da relação lateral genero / realeza na analogia rei-homem, rainha-mulher

# %%
model_cbow_300 = getModel('../models/ext/nilc/cbow_s300.txt')

# %%
model_cbow_300.most_similar(positive=['rei','mulher'],negative=['homem'])
# Out:
# [('rainha', 0.6863137483596802),
#  ('rei/rainha', 0.6846991181373596),
#  ('rainha-viúva', 0.6582984924316406),
#  ('rainha-mãe', 0.6532368659973145),
#  ('rainha-avó', 0.6457090377807617),
#  ('rainha-consorte', 0.6448943614959717),
#  ('rainha-a', 0.6409841775894165),
#  ('esposa', 0.6285491585731506),
#  ('rainha-imperatriz', 0.6235716938972473),
#  ('esposa-irmã', 0.6200047135353088)]

# %%
model_cbow_300.most_similar(positive=['rei','mulher'],negative=['rainha'])
# Out:
# [('homem/mulher', 0.6432656049728394),
#  ('homem', 0.6159863471984863),
#  ('esposo', 0.610273003578186),
#  ('meio-mulher', 0.5849580764770508),
#  ('marido-mulher', 0.5848926305770874),
#  ("'mulher", 0.5845355987548828),
#  ('mulher-homem', 0.5817847847938538),
#  ('\x93mulher', 0.5811667442321777),
#  ('[mulher', 0.5805800557136536),
#  ('homem-homem', 0.5773978233337402)]

# %%
model_cbow_300.most_similar(positive=['rainha','homem'],negative=['rei'])
# Out:
# [('homem/mulher', 0.7166236639022827),
#  ('mulher', 0.6981459259986877),
#  ('mulher-homem', 0.6651076078414917),
#  ('«mulher', 0.6586583852767944),
#  ('amulher', 0.6527774333953857),
#  ("'mulher", 0.649071216583252),
#  ('[mulher', 0.6452865600585938),
#  ('mulher-gorila', 0.6439161896705627),
#  ('\x93mulher', 0.6409512758255005),
#  ('(mulher', 0.6398382186889648)]

# %% [markdown]
# ft skip 300

# %%
model_skip_300 = getModel('../models/ext/nilc/skip_s300.txt')

# %%
analogy(model_skip_300,['rei','mulher'],['homem'])
# Out:
# [('rainha', 0.7449504137039185),
#  ('rainha-regente', 0.6796571016311646),
#  ('princesa-regente', 0.6528103351593018),
#  ('esposa', 0.6449020504951477),
#  ('princesa', 0.6373282670974731)]

# %%
model_skip_300.most_similar(['rei','mulher'],['rainha'],5)
# Out:
# [('homem', 0.7047942876815796),
#  ('marido', 0.6593904495239258),
#  ('esposa', 0.6394582986831665),
#  ('pai', 0.608444094657898),
#  ('filho', 0.6038110256195068)]

# %%
model_skip_300.most_similar(['rainha','homem'],['rei'],5)
# Out:
# [('mulher', 0.7244539260864258),
#  ("'mulher", 0.6234444379806519),
#  ('amulher', 0.6227772831916809),
#  ('mulher.', 0.6099158525466919),
#  ('rapaz', 0.6031544208526611)]

# %% [markdown]
# glove 300

# %%
model_glove_300 = getModel('../models/ext/nilc/glove_s300.txt')

# %%
analogy(model_glove_300,['rei','mulher'],['homem'])
# Out:
# [('rainha', 0.7193282842636108),
#  ('filha', 0.6310628652572632),
#  ('esposa', 0.627386212348938),
#  ('princesa', 0.6068347096443176),
#  ('isabel', 0.5972704887390137)]

# %%
model_glove_300.most_similar(['rei','mulher'],['rainha'],5)
# Out:
# [('homem', 0.6963078379631042),
#  ('filho', 0.6240413188934326),
#  ('marido', 0.596142590045929),
#  ('pai', 0.5748201608657837),
#  ('jovem', 0.5624553561210632)]

# %%
model_glove_300.most_similar(['rainha','homem'],['rei'],5)
# Out:
# [('mulher', 0.6987082958221436),
#  ('rapaz', 0.5554484128952026),
#  ('ela', 0.548879861831665),
#  ('menina', 0.5305519700050354),
#  ('mãe', 0.5255801677703857)]

# %%
print_tex_table_format(analogy(model_glove_300, ['imperador','mulher'], ['homem']))
# Out:
# imperatriz & 0.60276
# esposa & 0.58376
# constantino & 0.55014
# rainha & 0.53609
# filha & 0.51772

# %%
print_tex_table_format(analogy(model_glove_300, ['duque','mulher'], ['homem']))
# Out:
# duquesa & 0.62535
# filha & 0.58326
# princesa & 0.57004
# esposa & 0.56504
# isabel & 0.55134

# %%
print_tex_table_format(analogy(model_glove_300, ['bombeiro','mulher'], ['homem']))
# Out:
# enfermeira & 0.45481
# funcionária & 0.42359
# bailarina & 0.41011
# aposentada & 0.39691
# cozinheira & 0.39164

# %%
vocab = model_glove_300.vocab

# %%
vocab['\x93dilma'].count
# Out:
# 601835

# %%
vocab['dilma'].count
# Out:
# 928201

# %%
vocab['bombeira'].count
# Out:
# 772888

# %%
model_glove_300['bombeira']
# Out:
# array([ 8.46990e-02, -8.92620e-02,  5.58364e-01, -2.03585e-01,
#         1.08923e-01, -2.42163e-01,  2.89198e-01,  4.09869e-01,
#         3.27623e-01,  3.64873e-01,  8.50960e-02, -2.32650e-02,
#         8.73880e-02,  1.40500e-01,  2.05821e-01, -1.82127e-01,
#        -6.51860e-02, -3.36552e-01, -1.02728e-01, -3.34929e-01,
#        -2.90140e-01, -9.08200e-03,  1.81294e-01, -6.15830e-02,
#         8.32000e-03,  1.73651e-01, -1.03636e-01,  6.05953e-01,
#        -4.43466e-01, -1.98048e-01,  3.71138e-01,  4.44034e-01,
#        -2.11854e-01,  3.34787e-01, -1.09660e-01, -7.53010e-02,
#         8.64020e-02,  2.97713e-01, -5.67650e-02, -2.25977e-01,
#         3.04881e-01, -4.60010e-02,  1.96470e-02, -2.72156e-01,
#         5.36984e-01,  1.07498e-01, -4.27200e-02, -4.18589e-01,
#         2.10829e-01,  9.20270e-02,  1.45941e-01, -1.95663e-01,
#         4.79655e-01, -4.90820e-01,  2.99465e-01, -2.24454e-01,
#        -9.12500e-02, -3.88920e-02,  3.76397e-01,  4.16080e-02,
#         1.33836e-01, -1.25850e-02,  6.31380e-02, -2.36650e-01,
#        -1.57357e-01,  3.64372e-01, -4.09400e-03, -2.69662e-01,
#         1.21818e-01, -2.13303e-01, -5.20210e-02, -1.66444e-01,
#         5.71160e-02, -1.04288e-01,  1.38765e-01, -8.33900e-03,
#         6.62760e-02, -1.83860e-02, -1.11084e-01, -5.09330e-02,
#         1.99998e-01, -2.70007e-01, -1.00903e-01,  1.04454e-01,
#        -4.44218e-01,  6.99770e-02,  9.06970e-02,  1.71329e-01,
#         6.10480e-02, -2.38098e-01, -1.93247e-01,  2.41070e-01,
#         1.10811e-01,  2.08850e-02, -2.58133e-01,  7.78100e-03,
#        -1.08530e-01,  2.51369e-01,  1.75682e-01,  2.46314e-01,
#        -8.43200e-02,  2.98810e-01, -4.16254e-01, -4.61129e-01,
#        -8.98409e-01,  2.64750e-02, -2.08065e-01,  1.89253e-01,
#         1.95458e-01,  2.86843e-01,  7.26825e-01,  6.35180e-02,
#         7.04100e-02, -7.14380e-02,  2.43049e-01,  4.63306e-01,
#         3.10691e-01, -2.33002e-01,  2.67990e-01,  1.97785e-01,
#         1.66593e-01, -2.87950e-02,  3.44711e-01,  1.38092e-01,
#        -3.22670e-02,  2.17502e-01, -1.81141e-01, -2.42661e-01,
#         3.89111e-01,  3.88000e-04, -1.83142e-01, -1.19097e-01,
#         3.25558e-01,  3.80801e-01,  5.72160e-02, -3.92600e-03,
#        -2.47270e-02, -9.99350e-02, -3.45000e-04,  3.19579e-01,
#         3.00000e-01, -1.64307e-01,  8.55877e-01, -2.87545e-01,
#         1.69835e-01, -7.71300e-03, -1.63989e-01,  2.33253e-01,
#         4.05311e-01,  2.26129e-01, -1.01191e-01,  1.50474e-01,
#         7.36140e-02, -2.37801e-01,  1.07872e-01, -1.10027e-01,
#         9.43030e-02, -6.15910e-02, -3.49620e-01,  1.04572e-01,
#        -3.90501e-01, -1.08730e-02, -1.29023e-01,  5.15515e-01,
#        -2.45769e-01,  2.05647e-01, -5.11798e-01,  3.17670e-02,
#         3.26700e-02,  2.68367e-01, -6.03480e-02,  2.58025e-01,
#        -6.91170e-02, -1.67568e-01,  6.24736e-01, -2.56283e-01,
#         3.09200e-02,  2.71230e-02, -1.05446e-01,  1.68960e-01,
#        -7.45300e-03,  8.20610e-02, -1.42480e-01,  2.73753e-01,
#        -2.80658e-01, -5.04570e-02, -1.16436e-01, -2.12377e-01,
#         2.81916e-01,  9.29200e-03, -4.04669e-01, -2.83390e-01,
#         2.86828e-01, -5.77217e-01, -1.81443e-01,  8.51080e-02,
#         1.78532e-01, -8.65160e-02, -2.03754e-01, -1.85446e-01,
#        -7.47460e-02, -4.72460e-02,  3.55419e-01, -2.63135e-01,
#         9.07900e-02,  4.38160e-02,  3.76026e-01,  1.67999e-01,
#        -1.52747e-01, -9.75150e-02,  8.48800e-03, -4.19056e-01,
#         2.34433e-01, -7.55120e-02,  5.85000e-03, -8.51540e-02,
#        -3.96974e-01, -3.67784e-01, -3.34930e-01, -2.07699e-01,
#         8.84400e-02, -4.83790e-02, -2.32793e-01, -1.14435e-01,
#         3.23483e-01,  7.72500e-02,  4.63650e-02,  3.01869e-01,
#        -4.28756e-01, -4.30903e-01, -5.05470e-02, -5.91360e-02,
#        -3.20321e-01,  9.83320e-02,  7.06894e-01,  1.54675e-01,
#        -2.73692e-01,  2.78241e-01, -1.03942e-01,  2.28924e-01,
#        -2.13963e-01,  5.30670e-02,  6.62680e-02,  1.73884e-01,
#        -1.17012e-01,  9.80210e-02, -1.58013e-01,  4.79900e-03,
#        -5.81260e-02,  1.89171e-01,  1.80832e-01, -3.56400e-01,
#         2.10742e-01, -4.00218e-01, -1.08684e-01, -1.74759e-01,
#         2.23812e-01,  6.19611e-01,  6.72800e-03,  1.24195e-01,
#        -2.22774e-01, -8.92480e-02,  2.07440e-02,  2.87280e-02,
#        -5.47558e-01, -1.56936e-01,  1.05905e-01, -1.20888e-01,
#        -4.66270e-02, -5.49626e-01, -3.52569e-01, -2.46799e-01,
#         2.74995e-01,  3.82043e-01, -3.24574e-01,  3.71770e-02,
#         2.14707e-01, -2.91303e-01, -1.28968e-01, -1.83225e-01,
#         3.05312e-01,  1.94302e-01, -6.96030e-02,  2.49420e-02,
#        -1.85279e-01,  1.01036e-01, -1.20847e-01,  3.26730e-02,
#        -1.62365e-01, -1.35038e-01,  1.47041e-01,  3.91748e-01,
#        -1.81091e-01,  2.97800e-01, -5.41660e-02, -3.18087e-01,
#        -7.24300e-02, -2.50862e-01, -5.20448e-01,  7.96930e-02],
#       dtype=float32)

# %%
print_tex_table_format(analogy(model_glove_300, ['pai','mulher'], ['homem']))
# Out:
# mãe & 0.80397
# filha & 0.79023
# esposa & 0.75751
# irmã & 0.73740
# marido & 0.72126

# %%
print_tex_table_format(analogy(model_glove_300, ['médica','homem'], ['mulher']))
# Out:
# médico & 0.59299
# clínica & 0.54171
# medicina & 0.53221
# paciente & 0.49083
# saúde & 0.48852

# %% [markdown]
# ## Testando os métodos indicados pelo Paper - FastText 300 e  Glove 300

# %%
models = []
fast = '../models/skip_s300fast.txt'
glove = '../models/glove_s300.txt'
models.append(getModel(fast))
models.append(getModel(glove))

# %%
model = models[0]
word1 = 'rei'
word2 = 'homem'
word3 = 'mulher'
# FastText skip300
list = model.most_similar(positive=[word1,word3], negative=[word2])

# %%
model = models[1]
# Glove s300
list2 = model.most_similar(positive=[word1,word3], negative=[word2])b

# %%
print(list)
print(list2)
# Out:
# [('rainha', 0.7449502348899841), ('rainha-regente', 0.6796571016311646), ('princesa-regente', 0.6528101563453674), ('esposa', 0.6449019908905029), ('princesa', 0.6373282670974731), ('consorte', 0.6351529955863953), ('«rainha', 0.6276739835739136), ('filha', 0.6266849040985107), ('desposa', 0.6201632022857666), ('rainha-a', 0.6200650930404663)]
# [('rainha', 0.7193283438682556), ('filha', 0.6310628652572632), ('esposa', 0.627386212348938), ('princesa', 0.6068346500396729), ('isabel', 0.5972704887390137), ('irmã', 0.5631763935089111), ('consorte', 0.5383861064910889), ('trono', 0.5359665155410767), ('príncipe', 0.5172233581542969), ('joana', 0.5126430988311768)]

# %%
models[0].most_similar(positive=['primeira-dama','obama'])
# Out:
# [('primeira-damas', 0.8656221628189087),
#  ('barack', 0.8468867540359497),
#  ('ex-primeira-dama', 0.7975351214408875),
#  ('obamas', 0.762374997138977),
#  ('clinton', 0.7279771566390991),
#  ('obama.a', 0.7279264330863953),
#  ('segunda-dama', 0.721454918384552),
#  ('vice-primeira-dama', 0.7174794673919678),
#  ('robama', 0.713536262512207),
#  ('hillary', 0.7119442224502563)]

# %% [markdown]
# ## Exploração de Relações

# %% [markdown]
# ### Pais-Presidente

# %%
def analogy(pos, neg):
    return model.most_similar(pos,neg)

# %%
modelsList = glob('../models/*fast.txt')
model  =  getModel(modelsList[0])

# %%
# !ls ../models/ext/fasttext
# Out:
# cc.pt.300.vec  wiki-news-300d-1M-subword.vec  wiki-news-300d-1M.vec

# %% [markdown]
# ### testes feitos em 26/abril Experimentos pro relatorio

# %%
modelBR = getModel('../models/ext/nilc/skip_s300.txt')

# %%
modelBR.most_similar(['rajoy','brasil'],['espanha'])
# Out:
# [('governo.dilma', 0.574255645275116),
#  ('brasileira.brasília', 0.5486313700675964),
#  ('temer', 0.5484487414360046),
#  ('brasil\x94.', 0.5476303100585938),
#  ('presidente.dilma', 0.5410065054893494),
#  ('\x93dilma', 0.5401182174682617),
#  ('governo.em', 0.5393486022949219),
#  ('brasileirуo', 0.5374867916107178),
#  ('impeachment.brasília', 0.5352616310119629),
#  ('dilma\x94;', 0.5319989919662476)]

# %%
modelBR.most_similar(['japão','hamburguer'],['sushi'])
# Out:
# [('japão-', 0.5559786558151245),
#  ('coréia/japão', 0.5467069149017334),
#  ('alemanha', 0.54466712474823),
#  ('tóquio', 0.5241599678993225),
#  ('japão-00', 0.5202561616897583),
#  ('japão.', 0.5193050503730774),
#  ('japão-eua', 0.5170083045959473),
#  ('japonese', 0.5135980844497681),
#  ('japão-brasil', 0.5119423270225525),
#  ('japãoe', 0.5075770616531372)]

# %%
modelBR.most_similar(['japão','hamburguer'],['eua'])
# Out:
# [('hamburgueria', 0.6456806659698486),
#  ('hamburguerias', 0.6179660558700562),
#  ('hamburgueres', 0.6069141030311584),
#  ('hamburguers', 0.601699709892273),
#  ('sushi', 0.598118007183075),
#  ('shitake', 0.5863547325134277),
#  ('japonesinho', 0.5727366209030151),
#  ('miyaki', 0.5720593929290771),
#  ('japãozinho', 0.5718837976455688),
#  ('japonesinha', 0.5680685043334961)]

# %%
modelBR.most_similar(['japão','burguer'],['sushi'])
# Out:
# [('coréia/japão', 0.5539045333862305),
#  ('japão.', 0.5332754850387573),
#  ('canadá', 0.5200167298316956),
#  ('unidos-japão', 0.5161298513412476),
#  ('unidos', 0.5141969919204712),
#  ('japão-', 0.51331627368927),
#  ('coreia', 0.5122588276863098),
#  ('coréia', 0.5115976333618164),
#  ('unidos,e', 0.505362868309021),
#  ('japão-eua', 0.5047953128814697)]

# %%
modelBR.most_similar(['japão','burguer'],['eua'])
# Out:
# [('x-burguer', 0.6115728616714478),
#  ('sushi', 0.5868093371391296),
#  ('youburguer', 0.582853376865387),
#  ('burguers', 0.5764532089233398),
#  ('japãozinho', 0.5654754638671875),
#  ('burgueras', 0.5545012950897217),
#  ('sushiman', 0.5537513494491577),
#  ('sushi-bar', 0.5413253307342529),
#  ('miashiro', 0.5411183834075928),
#  ('sujiyama', 0.5286682844161987)]

# %%
modelBR.most_similar(['japão','pizza'],['sushi'])
# Out:
# [('japão.', 0.5643796920776367),
#  ('japão-', 0.5541791915893555),
#  ('coreia', 0.5432860851287842),
#  ('japãoe', 0.5388157367706299),
#  ('grã-bretanha', 0.5379763841629028),
#  ('coréia/japão', 0.5329406261444092),
#  ('coréia', 0.5293791890144348),
#  ('japão-coreia', 0.5285506844520569),
#  ('japão.a', 0.5228054523468018),
#  ('ojapão', 0.5205355286598206)]

# %%
modelBR.most_similar(['japão','pizza'],['itália'])
# Out:
# [('sushi', 0.6261380910873413),
#  ('taiyaki', 0.625140905380249),
#  ('dorayaki', 0.5991750359535217),
#  ('donuts', 0.5868442058563232),
#  ('sukiyaki', 0.5848889350891113),
#  ('cachorro-quente', 0.5829704999923706),
#  ('miyaki', 0.5812810659408569),
#  ('temaki', 0.5793612599372864),
#  ('cachorro-quentes', 0.5730295777320862),
#  ('panqueca', 0.5695137977600098)]

# %%
analogy(modelBR, ['alemanha','pedro'],['merkel'])
# Out:
# [('almerico', 0.5518991351127625),
#  ('casimiro', 0.5496414303779602),
#  ('espanha', 0.5445067286491394),
#  ('d.álvaro', 0.544254720211029),
#  ('espanha—', 0.5391455888748169)]

# %%
analogy(modelBR,['merkel','espanha'],['alemanha'])
# Out:
# [('rajoy', 0.7286854982376099),
#  ('aznar', 0.6592538952827454),
#  ('psoe', 0.620030403137207),
#  ('zapatero', 0.6065688133239746),
#  ('aznarez', 0.5837963223457336)]

# %%
analogy(modelBR,['merkel','espanha'],['rajoy'])
# Out:
# [('alemanha', 0.7647017240524292),
#  ('—alemanha', 0.6655969619750977),
#  ('alemanhã', 0.6514356136322021),
#  ('alemanhao', 0.6505364775657654),
#  ('flalemanha', 0.6500216722488403)]

# %%
analogy(modelBR, ['merkel','espanha'],['pedro'])
# Out:
# [('alemanha', 0.6142593026161194),
#  ('merkels', 0.6087908744812012),
#  ('—alemanha', 0.5496106147766113),
#  ('alemanhã', 0.5418404340744019),
#  ('daalemanha', 0.5393726825714111)]

# %%
analogy(modelBR, ['eua','merkel'],['obama'])
# Out:
# [('alemanha', 0.5969653129577637),
#  ('merkels', 0.566200852394104),
#  ('unidos-alemanha', 0.5261813402175903),
#  ('norte-alemanha', 0.5244130492210388),
#  ('unidos', 0.5220237970352173)]

# %% [markdown]
# Podemos observar algumas "sujeiras" na base, como palavras do vocabulário iguais [alemanha, -alemanha, alemanha., aalemanha, etc] que possivelmente poderiam acresentar o conhecimento porém são distinguidas.

# %%
analogy(modelBR, ['eua','rajoy'],['obama'])
# Out:
# [('espanha', 0.5240928530693054),
#  ('psoe', 0.5091130137443542),
#  ('ciudadanos', 0.483136922121048),
#  ('psoe-ciudadanos', 0.47759437561035156),
#  ('euskadiko', 0.467637836933136)]

# %%
analogy(modelBR, ['eua','conte'],['obama'])
# Out:
# [('aconte', 0.48051655292510986),
#  ('reconte', 0.4697737693786621),
#  ('contare', 0.46969354152679443),
#  ('contar', 0.4668620526790619),
#  ('laconte', 0.4613805115222931)]

# %%
analogy(modelBR, ['eua','berlusconi'],['obama'])
# Out:
# [('berlusconni', 0.6438901424407959),
#  ('berlusconis', 0.6181439161300659),
#  ('anti-berlusconi', 0.5776601433753967),
#  ('fininvest', 0.5587810277938843),
#  ('itália', 0.5479344725608826)]

# %%
analogy(modelBR, ['eua','monti'],['obama'])
# Out:
# [('donnini', 0.4999428987503052),
#  ('brugnetti', 0.4880524277687073),
#  ('pettini', 0.4826626479625702),
#  ('rigamonti', 0.48097920417785645),
#  ('gargani', 0.47859570384025574)]

# %%
analogy(modelBR, ['eua','enrico'],['obama'])
# Out:
# [('henrico', 0.5625894069671631),
#  ('valerio', 0.5209310054779053),
#  ('vitagliano', 0.5094318985939026),
#  ('defrancesco', 0.5074387788772583),
#  ('battistini', 0.49750643968582153)]

# %%
analogy(modelBR, ['eua','matteo'],['obama'])
# Out:
# [('itália', 0.5320799946784973),
#  ('matteoti', 0.5318585634231567),
#  ('itáliano', 0.5174192786216736),
#  ('matteotti', 0.5150493383407593),
#  ('matteoli', 0.5115050077438354),
#  ('pierini', 0.5032851099967957),
#  ('bartoloni', 0.5032413005828857),
#  ('francesco', 0.5031288862228394),
#  ('vittorini', 0.5030046105384827),
#  ('itáliao', 0.5030040144920349)]

# %%
analogy(modelBR, ['eua','renzi'],['obama'])
# Out:
# [('itália', 0.5503702163696289),
#  ('firenzi', 0.5223994851112366),
#  ('unidos', 0.4993197023868561),
#  ('matteo', 0.49648967385292053),
#  ('renzis', 0.4830038547515869)]

# %%
analogy(modelBR, ['china','macarrão'],['yakisoba'])
# Out:
# [('xangai-china', 0.5721220374107361),
#  ('chineses', 0.5484108924865723),
#  ('chinês', 0.5439407229423523),
#  ('eu-china', 0.5283563733100891),
#  ('jianchang', 0.5267598032951355)]

# %%
analogy(modelBR, ['merkel','eua'],['alemanha'])
# Out:
# [('obama', 0.6659966111183167),
#  ('barack', 0.6550233364105225),
#  ('clinton.a', 0.594444751739502),
#  ('clinton', 0.5942842960357666),
#  ('clinton-assad', 0.5905669927597046)]

# %%
analogy(modelBR, ['merkel','italia'],['alemanha'])
# Out:
# [('renzi', 0.5919278860092163),
#  ('italiani', 0.5549381971359253),
#  ('ditalia', 0.5436686277389526),
#  ('italiamo', 0.5381110310554504),
#  ('italia0', 0.536308765411377)]

# %%
analogy(modelBR, ['merkel','brasil'],['alemanha'])
# Out:
# [('brasil)em', 0.5761305093765259),
#  ('\x93dilma', 0.5755375623703003),
#  ('brasil)\x94,', 0.5744104385375977),
#  ('brasilês', 0.566964328289032),
#  ('presidenta', 0.5624070167541504)]

# %%
analogy(modelBR, ['merkel','holanda'],['alemanha'])
# Out:
# [('dijssebloem', 0.6147078275680542),
#  ('dijsselbloem', 0.6047036051750183),
#  ('merkell', 0.596217155456543),
#  ('juncker', 0.5896487236022949),
#  ('merkels', 0.5853166580200195)]

# %%
model.most_similar(positive=['estados','unidos'])
# Out:
# [('eua', 0.8173750638961792),
#  ('unidos,e', 0.7958360910415649),
#  ('unidos.', 0.7799003720283508),
#  ('unidos-', 0.7789234519004822),
#  ('unidos.é', 0.7481932640075684),
#  ('estadosunidos', 0.7360846400260925),
#  ('unidos.fica', 0.7329683303833008),
#  ('estados-unidos', 0.7277584075927734),
#  ('unidos.ela', 0.7264972925186157),
#  ('e.u.a', 0.7021260857582092)]

# %%
model.most_similar(positive=['holanda'])
# Out:
# [('holanda.', 0.8068545460700989),
#  ('holandas', 0.7937363982200623),
#  ('roterdã-holanda', 0.7753633856773376),
#  ('frança/holanda', 0.7715115547180176),
#  ('holanda-bélgica', 0.7678250670433044),
#  ('holand', 0.7434194087982178),
#  ('holanda.o', 0.7411854863166809),
#  ('bélgica', 0.7325699925422668),
#  ('espanha-holanda', 0.7311862111091614),
#  ('holanda-alemanha', 0.7242059707641602)]

# %%
model.most_similar(positive=['holanda','país'])
# Out:
# [('frança/holanda', 0.6957878470420837),
#  ('holandas', 0.6895419359207153),
#  ('bélgica', 0.6713705658912659),
#  ('espanha', 0.6704224944114685),
#  ('portugal', 0.6673567295074463),
#  ('inglaterra-holanda', 0.6671522259712219),
#  ('espanha-holanda', 0.6555101871490479),
#  ('frança', 0.6544818878173828),
#  ('holanda-bélgica', 0.6528982520103455),
#  ('abélgica', 0.647580623626709)]

# %%
analogy(modelBR, ['neve','calor'],['frio'])
# Out:
# [('chuva', 0.5868127346038818),
#  ('granizo', 0.5454442501068115),
#  ('evaporação', 0.5385027527809143),
#  ('aguaneve', 0.5326475501060486),
#  ('chuva.a', 0.5262962579727173)]

# %%
analogy(modelBR, ['neve', 'calor'])
# Out:
# [('frio', 0.7200497388839722),
#  ('chuva', 0.7158651351928711),
#  ('calorão', 0.7057672739028931),
#  ('friagem', 0.6958485841751099),
#  ('temperaturas', 0.6911848783493042)]

# %%
analogy(modelBR, ['neve'], ['frio'])
# Out:
# [('cinderela', 0.2628064453601837),
#  ('«montanha', 0.252099871635437),
#  ('montanha', 0.24522665143013),
#  ('snowboards', 0.24412553012371063),
#  ('augi', 0.23581856489181519)]

# %%
analogy(modelBR, ['cachoro','felino'],['canino'])
# Out:
# [('cachorrinho', 0.6359288096427917),
#  ('cachora', 0.6300210952758789),
#  ('cachorrito', 0.6155411005020142),
#  ('cachorrona', 0.6097216606140137),
#  ('cachorrinhos', 0.6066243648529053)]

# %%
analogy(modelBR, ['gato','canino'],['cachorro'])
# Out:
# [('caninos', 0.6211661100387573),
#  ('felino', 0.6080907583236694),
#  ('gatopardo', 0.5799951553344727),
#  ('canini', 0.5735528469085693),
#  ('canin', 0.5718478560447693)]

# %% [markdown]
# #### Update 02/05/2020
# ## Exploração de analogias em Fastext Cbow 300

# %%
fastext_cbow_300_pt = getModel('../models/ext/nilc/cbow_s300.txt')

# %%
print_tex_table_format(analogy(fastext_cbow_300_pt, ['merkel','espanha'], ['alemanha']))
# Out:
# merkez & 0.71391
# merkel.o & 0.66448
# merkell & 0.60394
# merkels & 0.59695
# aznarez & 0.59658

# %%
print_tex_table_format(analogy(fastext_cbow_300_pt, ['rajoy','brasil'], ['espanha']))
# Out:
# tucano.o & 0.52610
# brasil), & 0.49735
# fhc & 0.47915
# tucanês & 0.47823
# tucan & 0.47559

# %%
print_tex_table_format(analogy(fastext_cbow_300_pt, ['merkel','brasil'], ['alemanha']))
# Out:
# brasil), & 0.60519
# brasil, & 0.60134
# brasil. & 0.57375
# brasil_ & 0.57179
# brasil,o & 0.56721

# %%
print_tex_table_format(analogy(fastext_cbow_300_pt, ['gato','canino'], ['cachorro']))
# Out:
# ganino & 0.66918
# gatopardo & 0.66591
# gato-leopardo & 0.65985
# gato-andino & 0.65909
# anino & 0.65885

# %%
print_tex_table_format(analogy(fastext_cbow_300_pt, ['japão','burger'], ['sushi']))
# Out:
# brandenburger & 0.59032
# teuto-norte-americano & 0.58228
# marburger & 0.58033
# neerlando-americano & 0.58029
# nordbrandenburger & 0.57957

# %% [markdown]
# ## Exploração de analogias em GloVe 300

# %%
# !ls ../models/ext/nilc
# Out:
# cbow_s300.txt  glove_s300.txt  skip_s300.txt

# %%
glove_300_pt = getModel('../models/ext/nilc/glove_s300.txt')

# %%
print_tex_table_format(glove_300_pt.most_similar_cosmul(['obama','brasil'], ['eua'], 5))
# Out:
# dilma & 0.7911
# lembrou & 0.7808
# temer & 0.7797
# rousseff & 0.7732
# presidenta & 0.7682

# %%
print_tex_table_format(glove_300_pt.most_similar(['obama','brasil'], ['eua'], 5))
# Out:
# barack & 0.5020
# dilma & 0.4605
# lembrou & 0.4471
# temer & 0.4423
# rousseff & 0.4331

# %%
print_tex_table_format(glove_300_pt.most_similar('rainha'))
# Out:
# princesa & 0.68855
# isabel & 0.67442
# rei & 0.64577
# esposa & 0.59849
# irmã & 0.58511
# príncipe & 0.58037
# consorte & 0.56825
# filha & 0.55982
# margarida & 0.55164
# maria & 0.55025

# %%
print_tex_table_format(glove_300_pt.most_similar_cosmul(['merkel','espanha'], ['alemanha'], 5))
# Out:
# aznar & 0.89494
# rajoy & 0.80040
# hollande & 0.77528
# tsipras & 0.76724
# sarkozy & 0.75418

# %%
print_tex_table_format(analogy(glove_300_pt, ['merkel','espanha'], ['alemanha']))
# Out:
# aznar & 0.57278
# hollande & 0.51189
# angela & 0.48401
# rajoy & 0.47394
# tsipras & 0.46970

# %%
print_tex_table_format(analogy(glove_300_pt, ['rajoy','brasil'], ['espanha']))
# Out:
# temer & 0.40790
# dilma & 0.35921
# interino & 0.35611
# rousseff & 0.35059
# fhc & 0.34323

# %%
print_tex_table_format(analogy(glove_300_pt, ['merkel','brasil'], ['alemanha']))
# Out:
# angela & 0.43377
# obama & 0.43102
# dilma & 0.42379
# hollande & 0.40792
# rousseff & 0.40785

# %%
print_tex_table_format(analogy(glove_300_pt, ['gato','canino'], ['cachorro']))
# Out:
# metálico & 0.36818
# fino & 0.32361
# mitológico & 0.31854
# bárbaro & 0.31614
# sedentário & 0.31549

# %%
print_tex_table_format(analogy(glove_300_pt, ['gato','canino'], ['felino']))
# Out:
# cão & 0.44328
# cachorro & 0.41754
# garoto & 0.36823
# cavalo & 0.36806
# meu & 0.34271

# %% [markdown]
# Parece que soluções laterais podem ser obtidas - Problema do método linear -> so verifica uma resposta

# %%
print_tex_table_format(analogy(glove_300_pt, ["cão","felino"], ['canino']))
# Out:
# gato & 0.55100
# cachorro & 0.54393
# cães & 0.47377
# animal & 0.47262
# macaco & 0.45189

# %%
print_tex_table_format(analogy(glove_300_pt, ["cão","felino"], ['gato']))
# Out:
# predador & 0.49886
# animal & 0.41843
# canídeo & 0.38755
# pré-histórico & 0.37428
# nativo & 0.37316

# %%
print_tex_table_format(analogy(glove_300_pt, ['japão','burger'], ['eua']))
# Out:
# aki & 0.37331
# hokkaido & 0.35904
# cooter & 0.35661
# mcdonald's & 0.35195
# shima & 0.34307

# %%
print_tex_table_format(glove_300_pt.most_similar_cosmul(['japão','burger'], ['alemanha'], 5))
# Out:
# mcdonald's & 0.83972
# nightmare & 0.81441
# abe & 0.79952
# candy & 0.79379
# mekk & 0.78611

# %% [markdown]
# ### Utilizando Base Pre-Treinada com o FastText a partir da Wikipedia
#
# src: https://fasttext.cc/docs/en/english-vectors.html

# %%
modelList = glob('../models/eng/*.vec')
model = getModel('../models/ext/fasttext/wiki-news-300d-1M.vec')

# %%
model.most_similar(['canine','cat'],['dog'])
# Out:
# [('feline', 0.8340439796447754),
#  ('cats', 0.7032248973846436),
#  ('felines', 0.6862081289291382),
#  ('Feline', 0.6237226724624634),
#  ('Cat', 0.5961567759513855),
#  ('Saber-toothed', 0.5884695053100586),
#  ('kitten', 0.5774850845336914),
#  ('cat-related', 0.5745742321014404),
#  ('cat-like', 0.5722991228103638),
#  ('rodent', 0.5714539289474487)]

# %%
model.most_similar(positive=['Japan','burger'], negative=['U.S.A'])
# Out:
# [('hamburger', 0.6090177893638611),
#  ('burgers', 0.5968979597091675),
#  ('sushi', 0.5891664028167725),
#  ('cheeseburger', 0.5540557503700256),
#  ('ramen', 0.5526171922683716),
#  ('sashimi', 0.5424988269805908),
#  ('sandwich', 0.5383584499359131),
#  ('hamburgers', 0.5355225205421448),
#  ('fast-food', 0.5213922262191772),
#  ('steak', 0.5205715894699097)]

# %%
model.most_similar(positive=['Japan','burger'], negative=['USA'])
# Out:
# [('hamburger', 0.630410373210907),
#  ('sushi', 0.6180722713470459),
#  ('burgers', 0.6126525402069092),
#  ('ramen', 0.6112750172615051),
#  ('yakitori', 0.6034594178199768),
#  ('sashimi', 0.5863991975784302),
#  ('cheeseburger', 0.5636043548583984),
#  ('teriyaki', 0.5585513114929199),
#  ('hamburgers', 0.5578770637512207),
#  ('gyoza', 0.5487343668937683)]

# %%
model.most_similar(positive=['Japan','burger'], negative=['sushi'])
# Out:
# [('Germany', 0.589952290058136),
#  ('Canada', 0.5562193393707275),
#  ('U.S.A.', 0.5414534211158752),
#  ('Australia', 0.5396606922149658),
#  ('Britain', 0.5318068265914917),
#  ('France', 0.5265113711357117),
#  ('China', 0.5201818943023682),
#  ('Burger', 0.5177664756774902),
#  ('USA', 0.5154217481613159),
#  ('Korea', 0.5103574395179749)]

# %%
model.most_similar(positive=['Japan','pizza'], negative=['sushi'])
# Out:
# [('Italy', 0.6227899789810181),
#  ('Germany', 0.60132896900177),
#  ('Pizza', 0.5715957283973694),
#  ('Canada', 0.5570455193519592),
#  ('Australia', 0.5475723743438721),
#  ('Greece', 0.5475215911865234),
#  ('Europe', 0.5442083477973938),
#  ('USA', 0.534557580947876),
#  ('China', 0.5322703123092651),
#  ('Poland', 0.5261463522911072)]

# %% [markdown]
# ### Nota-se a seguir a diferença para resultados lower-case, demonstrando a diferença entre vetores na base

# %%
model.most_similar(positive=['Merkel','Brazil'], negative=['Germany'])
# Out:
# [('Rousseff', 0.7313451170921326),
#  ('Roussef', 0.6911478042602539),
#  ('Rouseff', 0.6840354204177856),
#  ('Dilma', 0.6766487956047058),
#  ('Lula', 0.6736571788787842),
#  ('Petrobras', 0.5874807238578796),
#  ('Cardoso', 0.5827363133430481),
#  ('Suplicy', 0.5818279981613159),
#  ('Sarney', 0.5682660937309265),
#  ('Brazilians', 0.5665429830551147)]

# %%
analogy(['snow','hot'], ['cold'])
# Out:
# [('snowfall', 0.5610437393188477),
#  ('snow.', 0.5231389403343201),
#  ('mountain', 0.5171799659729004),
#  ('leopard', 0.5139029026031494),
#  ('snows', 0.5021113157272339)]

# %%
analogy(['germany','pedro'],['merkel'])
# Out:
# [('spain', 0.5449022054672241),
#  ('uruguay', 0.5438195466995239),
#  ('austrailia', 0.5267531871795654),
#  ('france', 0.5248713493347168),
#  ('brasil', 0.520304799079895),
#  ('italy', 0.5182735323905945),
#  ('mexico', 0.5151197910308838),
#  ('brazil', 0.5144617557525635),
#  ('diego', 0.5095052719116211),
#  ('portugal', 0.5055333375930786)]

# %%
analogy(['brazil', 'merkel'],['germany'])
# Out:
# [('Rouseff', 0.5680029988288879),
#  ('Roussef', 0.558526337146759),
#  ('juncker', 0.5372946262359619),
#  ('Dilma', 0.5332738161087036),
#  ('oboma', 0.5172426700592041),
#  ('jarrett', 0.5172005295753479),
#  ('blatter', 0.5170618295669556),
#  ('butt.', 0.516357958316803),
#  ('zuma', 0.5108668804168701),
#  ('Merkal', 0.5086339712142944)]

# %%
analogy(['germany','Dilma'],['merkel'])
# Out:
# [('Brazil', 0.6214088201522827),
#  ('Brasil', 0.6054402589797974),
#  ('brazil', 0.5685147047042847),
#  ('brazilian', 0.5589703321456909),
#  ('PSDB', 0.5487357378005981),
#  ('brazilians', 0.5418741106987),
#  ('Brazilians', 0.5331428050994873),
#  ('Roussef', 0.5214848518371582),
#  ('Campinas', 0.5139091610908508),
#  ('Brasilian', 0.5097894072532654)]

# %%
analogy(['germany','Lula'],['merkel'])
# Out:
# [('Brazil', 0.6056524515151978),
#  ('Brasil', 0.5765014886856079),
#  ('Argentina', 0.507718026638031),
#  ('Brazilian', 0.493157297372818),
#  ('Brasilia', 0.48074477910995483),
#  ('Campinas', 0.4762342572212219),
#  ('Uruguay', 0.47142088413238525),
#  ('brazil', 0.46736085414886475),
#  ('Ecuador', 0.46712833642959595),
#  ('Brazilians', 0.46171486377716064)]

# %%
analogy(['Germany','Pedro'],['Merkel'])
# Out:
# [('Luis', 0.5925270318984985),
#  ('Carlos', 0.5798797607421875),
#  ('Juan', 0.5720661878585815),
#  ('Miguel', 0.5616669654846191),
#  ('Francisco', 0.5607050657272339),
#  ('Fernando', 0.5570615530014038),
#  ('Felipe', 0.5556502342224121),
#  ('Spain', 0.5526822805404663),
#  ('Brazil', 0.5482572317123413),
#  ('Portugal', 0.5244642496109009)]

# %%
analogy(['canine','cat'],['dog'])
# Out:
# [('feline', 0.8340439796447754),
#  ('cats', 0.703224778175354),
#  ('felines', 0.6862080097198486),
#  ('Feline', 0.6237226724624634),
#  ('Cat', 0.5961567163467407),
#  ('Saber-toothed', 0.5884692668914795),
#  ('kitten', 0.5774850249290466),
#  ('cat-related', 0.5745742321014404),
#  ('cat-like', 0.5722991824150085),
#  ('rodent', 0.5714539885520935)]

# %%
analogy(['china','dish'],[])
# Out:
# [('dishes', 0.7780748605728149),
#  ('porcelain', 0.6793701648712158),
#  ('cuisine', 0.6353912949562073),
#  ('crockery', 0.625084638595581),
#  ('tableware', 0.6163812875747681),
#  ('chinese', 0.6142603158950806),
#  ('dessert', 0.6098870635032654),
#  ('chinaware', 0.5995481014251709),
#  ('vase', 0.5953329801559448),
#  ('kitchen', 0.5941058993339539)]

# %%
analogy(['spain','minister'],[])
# Out:
# [('ministers', 0.6690819263458252),
#  ('france', 0.6395168900489807),
#  ('governement', 0.639469563961029),
#  ('minster', 0.6383272409439087),
#  ('england', 0.6359577775001526),
#  ('goverment', 0.6316805481910706),
#  ('minister.', 0.6290231943130493),
#  ('minsiter', 0.6260089874267578),
#  ('catalonia', 0.6244105100631714),
#  ('britain', 0.6221211552619934)]

# %%
analogy(['america','conte'],['obama'])
# Out:
# [('novelle', 0.49730175733566284),
#  ('imaginaire', 0.4891471266746521),
#  ('comedia', 0.4860025644302368),
#  ('marchand', 0.4846856892108917),
#  ('contes', 0.4834492802619934)]

# %% [markdown]
# * Testando relações de Comidas e Regiões

# %%
# !ls ../models/ext/fasttext
# Out:
# cc.pt.300.vec  wiki-news-300d-1M-subword.vec  wiki-news-300d-1M.vec

# %%
model = getModel("../models/ext/fasttext/wiki-news-300d-1M-subword.vec")

# %%
analogy(model,['china'])
# Out:
# [('china.', 0.6974451541900635),
#  ('chinas', 0.6943490505218506),
#  ('porcelain', 0.6891270875930786),
#  ('chinese', 0.6583600044250488),
#  ('taiwan', 0.6369878053665161)]

# %%
analogy(model, ["usa","china"],["hamburger"])
# Out:
# [('russia', 0.6298999786376953),
#  ('india', 0.5967906713485718),
#  ('china.', 0.5941920876502991),
#  ('america', 0.5697692632675171),
#  ('brazil', 0.5591113567352295)]

# %%
analogy(model, ["hamburger", "japan"],["usa"])
# Out:
# [('hamburgers', 0.6760963201522827),
#  ('burger', 0.6408655643463135),
#  ('cheeseburger', 0.598473072052002),
#  ('burgers', 0.5784617066383362),
#  ('steak', 0.5778934359550476)]

# %%
analogy(model, ["japan", "hamburger"],["sushi"])
# Out:
# [('hamburg', 0.5717610120773315),
#  ('germany', 0.564173698425293),
#  ('america', 0.5614770650863647),
#  ('europe', 0.5546668767929077),
#  ('britain', 0.5541375875473022)]

# %%
analogy(model, ["usa", "sushi"],["hamburger"])
# Out:
# [('japan', 0.5848140716552734),
#  ('sochi', 0.5593737363815308),
#  ('usa.', 0.5162376165390015),
#  ('japan.', 0.5158356428146362),
#  ('peru', 0.5003796219825745)]

# %%
res = model.evaluate_word_analogies("../testsets/ownBR.txt")

# %%
res
# Out:
# (0.25,
#  [{'section': 'country-food',
#    'correct': [('JAPAN', 'SUSHI', 'USA', 'PIZZA')],
#    'incorrect': [('JAPAN', 'SUSHI', 'USA', 'HAMBURGER'),
#     ('JAPAN', 'SUSHI', 'FRANCE', 'TAPAS'),
#     ('JAPAN', 'SUSHI', 'GERMANY', 'BRATWURST')]},
#   {'section': 'Total accuracy',
#    'correct': [('JAPAN', 'SUSHI', 'USA', 'PIZZA')],
#    'incorrect': [('JAPAN', 'SUSHI', 'USA', 'HAMBURGER'),
#     ('JAPAN', 'SUSHI', 'FRANCE', 'TAPAS'),
#     ('JAPAN', 'SUSHI', 'GERMANY', 'BRATWURST')]}])

# %% [markdown]
# ## Comparando Modelos FastText [ Default x Subword by Wiki]

# %%
modelList = glob('../models/*.vec')

def getAnalogyByTriple(triple):
    return analogy(triple[:2], triple[2:])

def getAnalogies(model):
    analogieSet = [
        ['canine','cat','dog'],
        ['Germany','Pedro','Merkel'],
        ['germany','Lula','merkel'],
        ['germany','Dilma','merkel'],
        ['brazil', 'merkel','germany'],
        ['germany','pedro','merkel'],
        ['merkel','italy','germany'],
        ['usa','conte','obama']]
    
    res=[]
    
    for triple in analogieSet:
        res.append(str(triple) + ' : ' + str(getAnalogyByTriple(triple)))
    
    
    
    return res

# %%
resultsDict = {}
for modelRef in modelList:
    model = getModel(modelRef)
    
    analogiesSet = getAnalogies(model)
    resultsDict[modelRef] = analogiesSet
# Out:
# ["['canine', 'cat', 'dog'] : [('feline', 0.8340439796447754), ('cats', 0.7032248973846436), ('felines', 0.6862081289291382), ('Feline', 0.6237226724624634), ('Cat', 0.5961567759513855)]", "['Germany', 'Pedro', 'Merkel'] : [('Luis', 0.5925270915031433), ('Carlos', 0.5798799395561218), ('Juan', 0.5720661282539368), ('Miguel', 0.5616670250892639), ('Francisco', 0.5607051253318787)]", "['germany', 'Lula', 'merkel'] : [('Brazil', 0.6056525707244873), ('Brasil', 0.5765014886856079), ('Argentina', 0.5077179670333862), ('Brazilian', 0.4931572675704956), ('Brasilia', 0.48074474930763245)]", "['germany', 'Dilma', 'merkel'] : [('Brazil', 0.6214088201522827), ('Brasil', 0.6054402589797974), ('brazil', 0.5685147047042847), ('brazilian', 0.5589703917503357), ('PSDB', 0.5487357378005981)]", "['brazil', 'merkel', 'germany'] : [('Rouseff', 0.5680030584335327), ('Roussef', 0.5585262775421143), ('juncker', 0.5372946262359619), ('Dilma', 0.5332738161087036), ('oboma', 0.5172426700592041)]", "['germany', 'pedro', 'merkel'] : [('spain', 0.5449022054672241), ('uruguay', 0.5438195466995239), ('austrailia', 0.5267531871795654), ('france', 0.5248713493347168), ('brasil', 0.520304799079895)]", "['merkel', 'italy', 'germany'] : [('berlusconi', 0.578383207321167), ('Merkal', 0.5773833990097046), ('juncker', 0.5768158435821533), ('barroso', 0.541594922542572), ('sarkozy', 0.5400439500808716)]", "['usa', 'conte', 'obama'] : [('finto', 0.4869907796382904), ('borghese', 0.4839317798614502), ('piccole', 0.48308873176574707), ('pittore', 0.48174625635147095), ('novelle', 0.48168542981147766)]"]
# ["['canine', 'cat', 'dog'] : [('feline', 0.7983354330062866), ('felines', 0.6860271692276001), ('cats', 0.6761199235916138), ('canines', 0.6240333318710327), ('housecat', 0.6178314089775085)]", "['Germany', 'Pedro', 'Merkel'] : [('Spain', 0.5514919757843018), ('Portugal', 0.531652569770813), ('Idelfonso', 0.5182946920394897), ('Miguel', 0.5150940418243408), ('Portugual', 0.5140479803085327)]", "['germany', 'Lula', 'merkel'] : [('Brazil', 0.606690526008606), ('Campinas', 0.5239420533180237), ('Brasil', 0.5114449262619019), ('Florianópolis', 0.5012084245681763), ('Manaus', 0.4971565008163452)]", "['germany', 'Dilma', 'merkel'] : [('Brazil', 0.6060876846313477), ('brazil', 0.5319264531135559), ('Brasil', 0.5258484482765198), ('Aécio', 0.5237767100334167), ('Rousseff', 0.5230662822723389)]", "['brazil', 'merkel', 'germany'] : [('brasil', 0.6085155606269836), ('batista', 0.5891100168228149), ('carvalho', 0.5841729044914246), ('tamara', 0.5830487012863159), ('miranda', 0.5822145342826843)]", "['germany', 'pedro', 'merkel'] : [('valencia', 0.5128980278968811), ('carlos', 0.49286261200904846), ('rico', 0.4855315387248993), ('alberto', 0.4848318099975586), ('fernando', 0.48232245445251465)]", "['merkel', 'italy', 'germany'] : [('italia', 0.6678920984268188), ('platini', 0.6066913604736328), ('itan', 0.6020712852478027), ('russo', 0.5817698836326599), ('fabio', 0.5798777341842651)]", "['usa', 'conte', 'obama'] : [('conti', 0.623619556427002), ('ente', 0.6231015920639038), ('colla', 0.6164557933807373), ('pittura', 0.6077091693878174), ('resta', 0.6057831048965454)]"]

# %%
for modelRef in resultsDict:
    print('\n' + modelRef.split('/')[2])
    showList(resultsDict[modelRef])
# Out:
# wiki-news-300d-1M.vec
# 	 ['canine', 'cat', 'dog'] : [('feline', 0.8340439796447754), ('cats', 0.7032248973846436), ('felines', 0.6862081289291382), ('Feline', 0.6237226724624634), ('Cat', 0.5961567759513855)]
#
# 	 ['Germany', 'Pedro', 'Merkel'] : [('Luis', 0.5925270915031433), ('Carlos', 0.5798799395561218), ('Juan', 0.5720661282539368), ('Miguel', 0.5616670250892639), ('Francisco', 0.5607051253318787)]
#
# 	 ['germany', 'Lula', 'merkel'] : [('Brazil', 0.6056525707244873), ('Brasil', 0.5765014886856079), ('Argentina', 0.5077179670333862), ('Brazilian', 0.4931572675704956), ('Brasilia', 0.48074474930763245)]
#
# 	 ['germany', 'Dilma', 'merkel'] : [('Brazil', 0.6214088201522827), ('Brasil', 0.6054402589797974), ('brazil', 0.5685147047042847), ('brazilian', 0.5589703917503357), ('PSDB', 0.5487357378005981)]
#
# 	 ['brazil', 'merkel', 'germany'] : [('Rouseff', 0.5680030584335327), ('Roussef', 0.5585262775421143), ('juncker', 0.5372946262359619), ('Dilma', 0.5332738161087036), ('oboma', 0.5172426700592041)]
#
# 	 ['germany', 'pedro', 'merkel'] : [('spain', 0.5449022054672241), ('uruguay', 0.5438195466995239), ('austrailia', 0.5267531871795654), ('france', 0.5248713493347168), ('brasil', 0.520304799079895)]
#
# 	 ['merkel', 'italy', 'germany'] : [('berlusconi', 0.578383207321167), ('Merkal', 0.5773833990097046), ('juncker', 0.5768158435821533), ('barroso', 0.541594922542572), ('sarkozy', 0.5400439500808716)]
#
# 	 ['usa', 'conte', 'obama'] : [('finto', 0.4869907796382904), ('borghese', 0.4839317798614502), ('piccole', 0.48308873176574707), ('pittore', 0.48174625635147095), ('novelle', 0.48168542981147766)]
#
#
# wiki-news-300d-1M-subword.vec
# 	 ['canine', 'cat', 'dog'] : [('feline', 0.7983354330062866), ('felines', 0.6860271692276001), ('cats', 0.6761199235916138), ('canines', 0.6240333318710327), ('housecat', 0.6178314089775085)]
#
# 	 ['Germany', 'Pedro', 'Merkel'] : [('Spain', 0.5514919757843018), ('Portugal', 0.531652569770813), ('Idelfonso', 0.5182946920394897), ('Miguel', 0.5150940418243408), ('Portugual', 0.5140479803085327)]
#
# 	 ['germany', 'Lula', 'merkel'] : [('Brazil', 0.606690526008606), ('Campinas', 0.5239420533180237), ('Brasil', 0.5114449262619019), ('Florianópolis', 0.5012084245681763), ('Manaus', 0.4971565008163452)]
#
# 	 ['germany', 'Dilma', 'merkel'] : [('Brazil', 0.6060876846313477), ('brazil', 0.5319264531135559), ('Brasil', 0.5258484482765198), ('Aécio', 0.5237767100334167), ('Rousseff', 0.5230662822723389)]
#
# 	 ['brazil', 'merkel', 'germany'] : [('brasil', 0.6085155606269836), ('batista', 0.5891100168228149), ('carvalho', 0.5841729044914246), ('tamara', 0.5830487012863159), ('miranda', 0.5822145342826843)]
#
# 	 ['germany', 'pedro', 'merkel'] : [('valencia', 0.5128980278968811), ('carlos', 0.49286261200904846), ('rico', 0.4855315387248993), ('alberto', 0.4848318099975586), ('fernando', 0.48232245445251465)]
#
# 	 ['merkel', 'italy', 'germany'] : [('italia', 0.6678920984268188), ('platini', 0.6066913604736328), ('itan', 0.6020712852478027), ('russo', 0.5817698836326599), ('fabio', 0.5798777341842651)]
#
# 	 ['usa', 'conte', 'obama'] : [('conti', 0.623619556427002), ('ente', 0.6231015920639038), ('colla', 0.6164557933807373), ('pittura', 0.6077091693878174), ('resta', 0.6057831048965454)]

# %% [markdown]
# ## Acuracia dos Modelos pré-treinados para os TestSets obtidos

# %% [markdown]
# ### Modelo PT disponivel em fasttext.cc

# %%
# !ls ../models/ext/fasttext
# Out:
# cc.pt.300.vec  wiki-news-300d-1M-subword.vec  wiki-news-300d-1M.vec

# %%
fastxt_pt_model_ref = '../models/ext/fasttext/cc.pt.300.vec'
test_set = glob('../testsets/*Analogies*')

print('fastxt_pt', fastxt_pt_model_ref)
print('test_set', test_set)
# Out:
# fastxt_pt ../models/ext/fasttext/cc.pt.300.vec
# test_set ['../testsets/LX-4WAnalogiesBr.txt', '../testsets/LX-4WAnalogies.txt']

# %%
fastxt_model = getModel(fastxt_pt_model_ref)

# %%
eval_analogies_acc_keydvec(fastxt_model, test_set, case_insensitive=True, dummy4unknown=True)
eval_analogies_acc_keydvec(fastxt_model, test_set, case_insensitive=True, dummy4unknown=False)
eval_analogies_acc_keydvec(fastxt_model, test_set, case_insensitive=False, dummy4unknown=True)
eval_analogies_acc_keydvec(fastxt_model, test_set, case_insensitive=False, dummy4unknown=False)
# Out:
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogiesBr.txt  :  0.5622508258343775  /   | setting 0 to missing words | case insensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogies.txt  :  0.5491507977354606  /   | setting 0 to missing words | case insensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogiesBr.txt  :  0.6830888458344866  /   | case insensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogies.txt  :  0.666736096646532  /   | case insensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogiesBr.txt  :  0.5436837908645632  /   | setting 0 to missing words | case sensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogies.txt  :  0.5313661577171613  /   | setting 0 to missing words | case sensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogiesBr.txt  :  0.6775017743080198  /   | case sensitive
# ../models/ext/fasttext/cc.pt.300.vec  @  ../testsets/LX-4WAnalogies.txt  :  0.6649967795033278  /   | case sensitive

# %% [markdown]
# * Modelos FastText: CBOW(300) e Skipgram(300); e Glove(300) disponiveis no repositorio de wordEmebddings do NILC

# %% [markdown]
# #### Modelos obtidos em Nilc

# %%
nilc_model_ref_list = glob('../models/ext/nilc/*.txt')

# %%
pool = multiprocessing.Pool()
pool_res = pool.starmap(eval_all_params, product(nilc_model_ref_list, test_set))
# Out:
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.43655313817063446 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogies.txt0.42889003259564246 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.49407677412005924 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogies.txt0.3837708011665809 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.3660439685613396 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogies.txt0.49385257619946243 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.47632363907531694 | case insensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogies.txt0.46462644034196504 | case insensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.5390877454635844 | case insensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogies.txt0.4157477388179903 | case insensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.39939100173999503 | case insensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogies.txt0.5350018585057613 | case insensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.17274177013327258 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogies.txt0.1781895122090696 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.2513384212324866 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.24165622508258344 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogies.txt0.254817864699491 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogies.txt0.25784868759650026 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.4263424233904976 | case sensitive
# ../models/ext/nilc/glove_s300.txt @ ../testsets/LX-4WAnalogies.txt0.43733333333333335 | case sensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.6203261175147596 | case sensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogiesBr.txt0.5964295754849592 | case sensitive
# ../models/ext/nilc/cbow_s300.txt @ ../testsets/LX-4WAnalogies.txt0.6254035087719299 | case sensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/LX-4WAnalogies.txt0.6328421052631579 | case sensitive

# %%
skip_s300 = getModel('../models/ext/nilc//skip_s300.txt')

# %%
skip_s300

# %%
skip_s300.evaluate_word_analogies('../testsets/LX-4WAnalogies.txt', case_insensitive=True, dummy4unknown=False)
# Out:
# (0.5350018585057613,
#  [{'section': 'capital-common-countries',
#    'correct': [('ATENAS', 'GRÉCIA', 'BAGDADE', 'IRAQUE'),
#     ('ATENAS', 'GRÉCIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ATENAS', 'GRÉCIA', 'PEQUIM', 'CHINA'),
#     ('ATENAS', 'GRÉCIA', 'BERLIM', 'ALEMANHA'),
#     ('ATENAS', 'GRÉCIA', 'CAIRO', 'EGITO'),
#     ('ATENAS', 'GRÉCIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ATENAS', 'GRÉCIA', 'HANÓI', 'VIETNAME'),
#     ('ATENAS', 'GRÉCIA', 'HAVANA', 'CUBA'),
#     ('ATENAS', 'GRÉCIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('ATENAS', 'GRÉCIA', 'LONDRES', 'INGLATERRA'),
#     ('ATENAS', 'GRÉCIA', 'MADRID', 'ESPANHA'),
#     ('ATENAS', 'GRÉCIA', 'MOSCOVO', 'RÚSSIA'),
#     ('ATENAS', 'GRÉCIA', 'OSLO', 'NORUEGA'),
#     ('ATENAS', 'GRÉCIA', 'OTTAWA', 'CANADÁ'),
#     ('ATENAS', 'GRÉCIA', 'PARIS', 'FRANÇA'),
#     ('ATENAS', 'GRÉCIA', 'ROMA', 'ITÁLIA'),
#     ('ATENAS', 'GRÉCIA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('ATENAS', 'GRÉCIA', 'TÓQUIO', 'JAPÃO'),
#     ('BAGDADE', 'IRAQUE', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('BAGDADE', 'IRAQUE', 'PEQUIM', 'CHINA'),
#     ('BAGDADE', 'IRAQUE', 'BERLIM', 'ALEMANHA'),
#     ('BAGDADE', 'IRAQUE', 'BERNA', 'SUÍÇA'),
#     ('BAGDADE', 'IRAQUE', 'CAIRO', 'EGITO'),
#     ('BAGDADE', 'IRAQUE', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BAGDADE', 'IRAQUE', 'HAVANA', 'CUBA'),
#     ('BAGDADE', 'IRAQUE', 'MOSCOVO', 'RÚSSIA'),
#     ('BAGDADE', 'IRAQUE', 'OSLO', 'NORUEGA'),
#     ('BAGDADE', 'IRAQUE', 'OTTAWA', 'CANADÁ'),
#     ('BAGDADE', 'IRAQUE', 'PARIS', 'FRANÇA'),
#     ('BAGDADE', 'IRAQUE', 'ROMA', 'ITÁLIA'),
#     ('BAGDADE', 'IRAQUE', 'TÓQUIO', 'JAPÃO'),
#     ('BAGDADE', 'IRAQUE', 'ATENAS', 'GRÉCIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'PEQUIM', 'CHINA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BERLIM', 'ALEMANHA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CAIRO', 'EGITO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'HAVANA', 'CUBA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'LONDRES', 'INGLATERRA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'MOSCOVO', 'RÚSSIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'OSLO', 'NORUEGA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'OTTAWA', 'CANADÁ'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'PARIS', 'FRANÇA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'ROMA', 'ITÁLIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'TÓQUIO', 'JAPÃO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'ATENAS', 'GRÉCIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BAGDADE', 'IRAQUE'),
#     ('PEQUIM', 'CHINA', 'BERLIM', 'ALEMANHA'),
#     ('PEQUIM', 'CHINA', 'CAIRO', 'EGITO'),
#     ('PEQUIM', 'CHINA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('PEQUIM', 'CHINA', 'HAVANA', 'CUBA'),
#     ('PEQUIM', 'CHINA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('PEQUIM', 'CHINA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('PEQUIM', 'CHINA', 'LONDRES', 'INGLATERRA'),
#     ('PEQUIM', 'CHINA', 'MOSCOVO', 'RÚSSIA'),
#     ('PEQUIM', 'CHINA', 'OSLO', 'NORUEGA'),
#     ('PEQUIM', 'CHINA', 'OTTAWA', 'CANADÁ'),
#     ('PEQUIM', 'CHINA', 'PARIS', 'FRANÇA'),
#     ('PEQUIM', 'CHINA', 'ROMA', 'ITÁLIA'),
#     ('PEQUIM', 'CHINA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('PEQUIM', 'CHINA', 'TÓQUIO', 'JAPÃO'),
#     ('PEQUIM', 'CHINA', 'ATENAS', 'GRÉCIA'),
#     ('PEQUIM', 'CHINA', 'BAGDADE', 'IRAQUE'),
#     ('PEQUIM', 'CHINA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('BERLIM', 'ALEMANHA', 'CAIRO', 'EGITO'),
#     ('BERLIM', 'ALEMANHA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BERLIM', 'ALEMANHA', 'HAVANA', 'CUBA'),
#     ('BERLIM', 'ALEMANHA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BERLIM', 'ALEMANHA', 'LONDRES', 'INGLATERRA'),
#     ('BERLIM', 'ALEMANHA', 'MADRID', 'ESPANHA'),
#     ('BERLIM', 'ALEMANHA', 'MOSCOVO', 'RÚSSIA'),
#     ('BERLIM', 'ALEMANHA', 'OSLO', 'NORUEGA'),
#     ('BERLIM', 'ALEMANHA', 'OTTAWA', 'CANADÁ'),
#     ('BERLIM', 'ALEMANHA', 'PARIS', 'FRANÇA'),
#     ('BERLIM', 'ALEMANHA', 'ROMA', 'ITÁLIA'),
#     ('BERLIM', 'ALEMANHA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('BERLIM', 'ALEMANHA', 'TÓQUIO', 'JAPÃO'),
#     ('BERLIM', 'ALEMANHA', 'ATENAS', 'GRÉCIA'),
#     ('BERLIM', 'ALEMANHA', 'BAGDADE', 'IRAQUE'),
#     ('BERLIM', 'ALEMANHA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('BERLIM', 'ALEMANHA', 'PEQUIM', 'CHINA'),
#     ('BERNA', 'SUÍÇA', 'CAIRO', 'EGITO'),
#     ('BERNA', 'SUÍÇA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BERNA', 'SUÍÇA', 'HANÓI', 'VIETNAME'),
#     ('BERNA', 'SUÍÇA', 'HAVANA', 'CUBA'),
#     ('BERNA', 'SUÍÇA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BERNA', 'SUÍÇA', 'LONDRES', 'INGLATERRA'),
#     ('BERNA', 'SUÍÇA', 'MOSCOVO', 'RÚSSIA'),
#     ('BERNA', 'SUÍÇA', 'OSLO', 'NORUEGA'),
#     ('BERNA', 'SUÍÇA', 'OTTAWA', 'CANADÁ'),
#     ('BERNA', 'SUÍÇA', 'PARIS', 'FRANÇA'),
#     ('BERNA', 'SUÍÇA', 'ROMA', 'ITÁLIA'),
#     ('BERNA', 'SUÍÇA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('BERNA', 'SUÍÇA', 'TÓQUIO', 'JAPÃO'),
#     ('BERNA', 'SUÍÇA', 'ATENAS', 'GRÉCIA'),
#     ('BERNA', 'SUÍÇA', 'BAGDADE', 'IRAQUE'),
#     ('BERNA', 'SUÍÇA', 'PEQUIM', 'CHINA'),
#     ('BERNA', 'SUÍÇA', 'BERLIM', 'ALEMANHA'),
#     ('CAIRO', 'EGITO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('CAIRO', 'EGITO', 'HAVANA', 'CUBA'),
#     ('CAIRO', 'EGITO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('CAIRO', 'EGITO', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('CAIRO', 'EGITO', 'LONDRES', 'INGLATERRA'),
#     ('CAIRO', 'EGITO', 'MOSCOVO', 'RÚSSIA'),
#     ('CAIRO', 'EGITO', 'OSLO', 'NORUEGA'),
#     ('CAIRO', 'EGITO', 'OTTAWA', 'CANADÁ'),
#     ('CAIRO', 'EGITO', 'PARIS', 'FRANÇA'),
#     ('CAIRO', 'EGITO', 'ROMA', 'ITÁLIA'),
#     ('CAIRO', 'EGITO', 'ESTOCOLMO', 'SUÉCIA'),
#     ('CAIRO', 'EGITO', 'TÓQUIO', 'JAPÃO'),
#     ('CAIRO', 'EGITO', 'ATENAS', 'GRÉCIA'),
#     ('CAIRO', 'EGITO', 'BAGDADE', 'IRAQUE'),
#     ('CAIRO', 'EGITO', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('CAIRO', 'EGITO', 'PEQUIM', 'CHINA'),
#     ('CAIRO', 'EGITO', 'BERLIM', 'ALEMANHA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'HAVANA', 'CUBA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'LONDRES', 'INGLATERRA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'MOSCOVO', 'RÚSSIA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'OSLO', 'NORUEGA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'OTTAWA', 'CANADÁ'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'PARIS', 'FRANÇA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'ROMA', 'ITÁLIA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'TÓQUIO', 'JAPÃO'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'ATENAS', 'GRÉCIA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'PEQUIM', 'CHINA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'BERLIM', 'ALEMANHA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'BERNA', 'SUÍÇA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'CAIRO', 'EGITO'),
#     ('HANÓI', 'VIETNAME', 'HAVANA', 'CUBA'),
#     ('HANÓI', 'VIETNAME', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('HANÓI', 'VIETNAME', 'MOSCOVO', 'RÚSSIA'),
#     ('HANÓI', 'VIETNAME', 'OSLO', 'NORUEGA'),
#     ('HANÓI', 'VIETNAME', 'OTTAWA', 'CANADÁ'),
#     ('HANÓI', 'VIETNAME', 'PARIS', 'FRANÇA'),
#     ('HANÓI', 'VIETNAME', 'ROMA', 'ITÁLIA'),
#     ('HANÓI', 'VIETNAME', 'TÓQUIO', 'JAPÃO'),
#     ('HANÓI', 'VIETNAME', 'ATENAS', 'GRÉCIA'),
#     ('HANÓI', 'VIETNAME', 'BAGDADE', 'IRAQUE'),
#     ('HANÓI', 'VIETNAME', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('HANÓI', 'VIETNAME', 'PEQUIM', 'CHINA'),
#     ('HANÓI', 'VIETNAME', 'BERLIM', 'ALEMANHA'),
#     ('HANÓI', 'VIETNAME', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('HAVANA', 'CUBA', 'LONDRES', 'INGLATERRA'),
#     ('HAVANA', 'CUBA', 'MOSCOVO', 'RÚSSIA'),
#     ('HAVANA', 'CUBA', 'OSLO', 'NORUEGA'),
#     ('HAVANA', 'CUBA', 'OTTAWA', 'CANADÁ'),
#     ('HAVANA', 'CUBA', 'PARIS', 'FRANÇA'),
#     ('HAVANA', 'CUBA', 'ROMA', 'ITÁLIA'),
#     ('HAVANA', 'CUBA', 'TÓQUIO', 'JAPÃO'),
#     ('HAVANA', 'CUBA', 'ATENAS', 'GRÉCIA'),
#     ('HAVANA', 'CUBA', 'BAGDADE', 'IRAQUE'),
#     ('HAVANA', 'CUBA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('HAVANA', 'CUBA', 'PEQUIM', 'CHINA'),
#     ('HAVANA', 'CUBA', 'BERLIM', 'ALEMANHA'),
#     ('HAVANA', 'CUBA', 'CAIRO', 'EGITO'),
#     ('HAVANA', 'CUBA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('HAVANA', 'CUBA', 'HANÓI', 'VIETNAME'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'LONDRES', 'INGLATERRA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'MADRID', 'ESPANHA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'MOSCOVO', 'RÚSSIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'OSLO', 'NORUEGA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'OTTAWA', 'CANADÁ'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'PARIS', 'FRANÇA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'ROMA', 'ITÁLIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'TÓQUIO', 'JAPÃO'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'ATENAS', 'GRÉCIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'BAGDADE', 'IRAQUE'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'PEQUIM', 'CHINA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'BERLIM', 'ALEMANHA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'CAIRO', 'EGITO'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'HAVANA', 'CUBA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'LONDRES', 'INGLATERRA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'MOSCOVO', 'RÚSSIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'OSLO', 'NORUEGA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'PARIS', 'FRANÇA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'ROMA', 'ITÁLIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'ESTOCOLMO', 'SUÉCIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'TÓQUIO', 'JAPÃO'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'ATENAS', 'GRÉCIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'BAGDADE', 'IRAQUE'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'PEQUIM', 'CHINA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'BERLIM', 'ALEMANHA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'BERNA', 'SUÍÇA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'CAIRO', 'EGITO'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'HAVANA', 'CUBA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('LONDRES', 'INGLATERRA', 'MOSCOVO', 'RÚSSIA'),
#     ('LONDRES', 'INGLATERRA', 'OSLO', 'NORUEGA'),
#     ('LONDRES', 'INGLATERRA', 'PARIS', 'FRANÇA'),
#     ('LONDRES', 'INGLATERRA', 'ROMA', 'ITÁLIA'),
#     ('LONDRES', 'INGLATERRA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('LONDRES', 'INGLATERRA', 'TÓQUIO', 'JAPÃO'),
#     ('LONDRES', 'INGLATERRA', 'ATENAS', 'GRÉCIA'),
#     ('LONDRES', 'INGLATERRA', 'BAGDADE', 'IRAQUE'),
#     ('LONDRES', 'INGLATERRA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('LONDRES', 'INGLATERRA', 'PEQUIM', 'CHINA'),
#     ('LONDRES', 'INGLATERRA', 'BERLIM', 'ALEMANHA'),
#     ('LONDRES', 'INGLATERRA', 'CAIRO', 'EGITO'),
#     ('LONDRES', 'INGLATERRA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('LONDRES', 'INGLATERRA', 'HANÓI', 'VIETNAME'),
#     ('LONDRES', 'INGLATERRA', 'HAVANA', 'CUBA'),
#     ('LONDRES', 'INGLATERRA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('MADRID', 'ESPANHA', 'MOSCOVO', 'RÚSSIA'),
#     ('MADRID', 'ESPANHA', 'OSLO', 'NORUEGA'),
#     ('MADRID', 'ESPANHA', 'OTTAWA', 'CANADÁ'),
#     ('MADRID', 'ESPANHA', 'PARIS', 'FRANÇA'),
#     ('MADRID', 'ESPANHA', 'ROMA', 'ITÁLIA'),
#     ('MADRID', 'ESPANHA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('MADRID', 'ESPANHA', 'TÓQUIO', 'JAPÃO'),
#     ('MADRID', 'ESPANHA', 'ATENAS', 'GRÉCIA'),
#     ('MADRID', 'ESPANHA', 'BAGDADE', 'IRAQUE'),
#     ('MADRID', 'ESPANHA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('MADRID', 'ESPANHA', 'PEQUIM', 'CHINA'),
#     ('MADRID', 'ESPANHA', 'BERLIM', 'ALEMANHA'),
#     ('MADRID', 'ESPANHA', 'CAIRO', 'EGITO'),
#     ('MADRID', 'ESPANHA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('MADRID', 'ESPANHA', 'HAVANA', 'CUBA'),
#     ('MADRID', 'ESPANHA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('MADRID', 'ESPANHA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('MOSCOVO', 'RÚSSIA', 'OSLO', 'NORUEGA'),
#     ('MOSCOVO', 'RÚSSIA', 'OTTAWA', 'CANADÁ'),
#     ('MOSCOVO', 'RÚSSIA', 'PARIS', 'FRANÇA'),
#     ('MOSCOVO', 'RÚSSIA', 'ROMA', 'ITÁLIA'),
#     ('MOSCOVO', 'RÚSSIA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('MOSCOVO', 'RÚSSIA', 'TÓQUIO', 'JAPÃO'),
#     ('MOSCOVO', 'RÚSSIA', 'ATENAS', 'GRÉCIA'),
#     ('MOSCOVO', 'RÚSSIA', 'BAGDADE', 'IRAQUE'),
#     ('MOSCOVO', 'RÚSSIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('MOSCOVO', 'RÚSSIA', 'PEQUIM', 'CHINA'),
#     ('MOSCOVO', 'RÚSSIA', 'BERLIM', 'ALEMANHA'),
#     ('MOSCOVO', 'RÚSSIA', 'BERNA', 'SUÍÇA'),
#     ('MOSCOVO', 'RÚSSIA', 'CAIRO', 'EGITO'),
#     ('MOSCOVO', 'RÚSSIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('MOSCOVO', 'RÚSSIA', 'HAVANA', 'CUBA'),
#     ('MOSCOVO', 'RÚSSIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('MOSCOVO', 'RÚSSIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('MOSCOVO', 'RÚSSIA', 'LONDRES', 'INGLATERRA'),
#     ('OSLO', 'NORUEGA', 'OTTAWA', 'CANADÁ'),
#     ('OSLO', 'NORUEGA', 'PARIS', 'FRANÇA'),
#     ('OSLO', 'NORUEGA', 'ROMA', 'ITÁLIA'),
#     ('OSLO', 'NORUEGA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('OSLO', 'NORUEGA', 'TÓQUIO', 'JAPÃO'),
#     ('OSLO', 'NORUEGA', 'ATENAS', 'GRÉCIA'),
#     ('OSLO', 'NORUEGA', 'BAGDADE', 'IRAQUE'),
#     ('OSLO', 'NORUEGA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('OSLO', 'NORUEGA', 'PEQUIM', 'CHINA'),
#     ('OSLO', 'NORUEGA', 'BERLIM', 'ALEMANHA'),
#     ('OSLO', 'NORUEGA', 'CAIRO', 'EGITO'),
#     ('OSLO', 'NORUEGA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('OSLO', 'NORUEGA', 'HANÓI', 'VIETNAME'),
#     ('OSLO', 'NORUEGA', 'HAVANA', 'CUBA'),
#     ('OSLO', 'NORUEGA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('OSLO', 'NORUEGA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('OSLO', 'NORUEGA', 'LONDRES', 'INGLATERRA'),
#     ('OSLO', 'NORUEGA', 'MADRID', 'ESPANHA'),
#     ('OSLO', 'NORUEGA', 'MOSCOVO', 'RÚSSIA'),
#     ('OTTAWA', 'CANADÁ', 'PARIS', 'FRANÇA'),
#     ('OTTAWA', 'CANADÁ', 'ROMA', 'ITÁLIA'),
#     ('OTTAWA', 'CANADÁ', 'ESTOCOLMO', 'SUÉCIA'),
#     ('OTTAWA', 'CANADÁ', 'TÓQUIO', 'JAPÃO'),
#     ('OTTAWA', 'CANADÁ', 'ATENAS', 'GRÉCIA'),
#     ('OTTAWA', 'CANADÁ', 'BAGDADE', 'IRAQUE'),
#     ('OTTAWA', 'CANADÁ', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('OTTAWA', 'CANADÁ', 'PEQUIM', 'CHINA'),
#     ('OTTAWA', 'CANADÁ', 'BERLIM', 'ALEMANHA'),
#     ('OTTAWA', 'CANADÁ', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('OTTAWA', 'CANADÁ', 'HANÓI', 'VIETNAME'),
#     ('OTTAWA', 'CANADÁ', 'HAVANA', 'CUBA'),
#     ('OTTAWA', 'CANADÁ', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('OTTAWA', 'CANADÁ', 'MADRID', 'ESPANHA'),
#     ('OTTAWA', 'CANADÁ', 'MOSCOVO', 'RÚSSIA'),
#     ('OTTAWA', 'CANADÁ', 'OSLO', 'NORUEGA'),
#     ('PARIS', 'FRANÇA', 'ROMA', 'ITÁLIA'),
#     ('PARIS', 'FRANÇA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('PARIS', 'FRANÇA', 'TÓQUIO', 'JAPÃO'),
#     ('PARIS', 'FRANÇA', 'ATENAS', 'GRÉCIA'),
#     ('PARIS', 'FRANÇA', 'BAGDADE', 'IRAQUE'),
#     ('PARIS', 'FRANÇA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('PARIS', 'FRANÇA', 'PEQUIM', 'CHINA'),
#     ('PARIS', 'FRANÇA', 'BERLIM', 'ALEMANHA'),
#     ('PARIS', 'FRANÇA', 'BERNA', 'SUÍÇA'),
#     ('PARIS', 'FRANÇA', 'CAIRO', 'EGITO'),
#     ('PARIS', 'FRANÇA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('PARIS', 'FRANÇA', 'HANÓI', 'VIETNAME'),
#     ('PARIS', 'FRANÇA', 'HAVANA', 'CUBA'),
#     ('PARIS', 'FRANÇA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('PARIS', 'FRANÇA', 'MADRID', 'ESPANHA'),
#     ('PARIS', 'FRANÇA', 'MOSCOVO', 'RÚSSIA'),
#     ('PARIS', 'FRANÇA', 'OSLO', 'NORUEGA'),
#     ('PARIS', 'FRANÇA', 'OTTAWA', 'CANADÁ'),
#     ('ROMA', 'ITÁLIA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('ROMA', 'ITÁLIA', 'TÓQUIO', 'JAPÃO'),
#     ('ROMA', 'ITÁLIA', 'ATENAS', 'GRÉCIA'),
#     ('ROMA', 'ITÁLIA', 'BAGDADE', 'IRAQUE'),
#     ('ROMA', 'ITÁLIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ROMA', 'ITÁLIA', 'PEQUIM', 'CHINA'),
#     ('ROMA', 'ITÁLIA', 'BERLIM', 'ALEMANHA'),
#     ('ROMA', 'ITÁLIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ROMA', 'ITÁLIA', 'HAVANA', 'CUBA'),
#     ('ROMA', 'ITÁLIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('ROMA', 'ITÁLIA', 'MADRID', 'ESPANHA'),
#     ('ROMA', 'ITÁLIA', 'MOSCOVO', 'RÚSSIA'),
#     ('ROMA', 'ITÁLIA', 'OSLO', 'NORUEGA'),
#     ('ROMA', 'ITÁLIA', 'OTTAWA', 'CANADÁ'),
#     ('ROMA', 'ITÁLIA', 'PARIS', 'FRANÇA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'TÓQUIO', 'JAPÃO'),
#     ('ESTOCOLMO', 'SUÉCIA', 'ATENAS', 'GRÉCIA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'BAGDADE', 'IRAQUE'),
#     ('ESTOCOLMO', 'SUÉCIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'PEQUIM', 'CHINA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'BERLIM', 'ALEMANHA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'CAIRO', 'EGITO'),
#     ('ESTOCOLMO', 'SUÉCIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'HANÓI', 'VIETNAME'),
#     ('ESTOCOLMO', 'SUÉCIA', 'HAVANA', 'CUBA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('ESTOCOLMO', 'SUÉCIA', 'LONDRES', 'INGLATERRA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'MADRID', 'ESPANHA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'MOSCOVO', 'RÚSSIA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'OSLO', 'NORUEGA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'OTTAWA', 'CANADÁ'),
#     ('ESTOCOLMO', 'SUÉCIA', 'PARIS', 'FRANÇA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'ROMA', 'ITÁLIA'),
#     ('TÓQUIO', 'JAPÃO', 'ATENAS', 'GRÉCIA'),
#     ('TÓQUIO', 'JAPÃO', 'BAGDADE', 'IRAQUE'),
#     ('TÓQUIO', 'JAPÃO', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('TÓQUIO', 'JAPÃO', 'PEQUIM', 'CHINA'),
#     ('TÓQUIO', 'JAPÃO', 'BERLIM', 'ALEMANHA'),
#     ('TÓQUIO', 'JAPÃO', 'BERNA', 'SUÍÇA'),
#     ('TÓQUIO', 'JAPÃO', 'CAIRO', 'EGITO'),
#     ('TÓQUIO', 'JAPÃO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('TÓQUIO', 'JAPÃO', 'HAVANA', 'CUBA'),
#     ('TÓQUIO', 'JAPÃO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('TÓQUIO', 'JAPÃO', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('TÓQUIO', 'JAPÃO', 'LONDRES', 'INGLATERRA'),
#     ('TÓQUIO', 'JAPÃO', 'MADRID', 'ESPANHA'),
#     ('TÓQUIO', 'JAPÃO', 'MOSCOVO', 'RÚSSIA'),
#     ('TÓQUIO', 'JAPÃO', 'OSLO', 'NORUEGA'),
#     ('TÓQUIO', 'JAPÃO', 'OTTAWA', 'CANADÁ'),
#     ('TÓQUIO', 'JAPÃO', 'PARIS', 'FRANÇA'),
#     ('TÓQUIO', 'JAPÃO', 'ROMA', 'ITÁLIA'),
#     ('TÓQUIO', 'JAPÃO', 'ESTOCOLMO', 'SUÉCIA')],
#    'incorrect': [('ATENAS', 'GRÉCIA', 'BERNA', 'SUÍÇA'),
#     ('ATENAS', 'GRÉCIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('ATENAS', 'GRÉCIA', 'TEERÃO', 'IRÃO'),
#     ('BAGDADE', 'IRAQUE', 'HANÓI', 'VIETNAME'),
#     ('BAGDADE', 'IRAQUE', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BAGDADE', 'IRAQUE', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BAGDADE', 'IRAQUE', 'LONDRES', 'INGLATERRA'),
#     ('BAGDADE', 'IRAQUE', 'MADRID', 'ESPANHA'),
#     ('BAGDADE', 'IRAQUE', 'ESTOCOLMO', 'SUÉCIA'),
#     ('BAGDADE', 'IRAQUE', 'TEERÃO', 'IRÃO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BERNA', 'SUÍÇA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'HANÓI', 'VIETNAME'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'MADRID', 'ESPANHA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'TEERÃO', 'IRÃO'),
#     ('PEQUIM', 'CHINA', 'BERNA', 'SUÍÇA'),
#     ('PEQUIM', 'CHINA', 'HANÓI', 'VIETNAME'),
#     ('PEQUIM', 'CHINA', 'MADRID', 'ESPANHA'),
#     ('PEQUIM', 'CHINA', 'TEERÃO', 'IRÃO'),
#     ('BERLIM', 'ALEMANHA', 'BERNA', 'SUÍÇA'),
#     ('BERLIM', 'ALEMANHA', 'HANÓI', 'VIETNAME'),
#     ('BERLIM', 'ALEMANHA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BERLIM', 'ALEMANHA', 'TEERÃO', 'IRÃO'),
#     ('BERNA', 'SUÍÇA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BERNA', 'SUÍÇA', 'MADRID', 'ESPANHA'),
#     ('BERNA', 'SUÍÇA', 'TEERÃO', 'IRÃO'),
#     ('BERNA', 'SUÍÇA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('CAIRO', 'EGITO', 'HANÓI', 'VIETNAME'),
#     ('CAIRO', 'EGITO', 'MADRID', 'ESPANHA'),
#     ('CAIRO', 'EGITO', 'TEERÃO', 'IRÃO'),
#     ('CAIRO', 'EGITO', 'BERNA', 'SUÍÇA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'HANÓI', 'VIETNAME'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'MADRID', 'ESPANHA'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'TEERÃO', 'IRÃO'),
#     ('CAMBERRA', 'AUSTRÁLIA', 'BAGDADE', 'IRAQUE'),
#     ('HANÓI', 'VIETNAME', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('HANÓI', 'VIETNAME', 'LONDRES', 'INGLATERRA'),
#     ('HANÓI', 'VIETNAME', 'MADRID', 'ESPANHA'),
#     ('HANÓI', 'VIETNAME', 'ESTOCOLMO', 'SUÉCIA'),
#     ('HANÓI', 'VIETNAME', 'TEERÃO', 'IRÃO'),
#     ('HANÓI', 'VIETNAME', 'BERNA', 'SUÍÇA'),
#     ('HANÓI', 'VIETNAME', 'CAIRO', 'EGITO'),
#     ('HAVANA', 'CUBA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('HAVANA', 'CUBA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('HAVANA', 'CUBA', 'MADRID', 'ESPANHA'),
#     ('HAVANA', 'CUBA', 'ESTOCOLMO', 'SUÉCIA'),
#     ('HAVANA', 'CUBA', 'TEERÃO', 'IRÃO'),
#     ('HAVANA', 'CUBA', 'BERNA', 'SUÍÇA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'TEERÃO', 'IRÃO'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'BERNA', 'SUÍÇA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'HANÓI', 'VIETNAME'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'MADRID', 'ESPANHA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'OTTAWA', 'CANADÁ'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'TEERÃO', 'IRÃO'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'HANÓI', 'VIETNAME'),
#     ('LONDRES', 'INGLATERRA', 'MADRID', 'ESPANHA'),
#     ('LONDRES', 'INGLATERRA', 'OTTAWA', 'CANADÁ'),
#     ('LONDRES', 'INGLATERRA', 'TEERÃO', 'IRÃO'),
#     ('LONDRES', 'INGLATERRA', 'BERNA', 'SUÍÇA'),
#     ('LONDRES', 'INGLATERRA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('MADRID', 'ESPANHA', 'TEERÃO', 'IRÃO'),
#     ('MADRID', 'ESPANHA', 'BERNA', 'SUÍÇA'),
#     ('MADRID', 'ESPANHA', 'HANÓI', 'VIETNAME'),
#     ('MADRID', 'ESPANHA', 'LONDRES', 'INGLATERRA'),
#     ('MOSCOVO', 'RÚSSIA', 'TEERÃO', 'IRÃO'),
#     ('MOSCOVO', 'RÚSSIA', 'HANÓI', 'VIETNAME'),
#     ('MOSCOVO', 'RÚSSIA', 'MADRID', 'ESPANHA'),
#     ('OSLO', 'NORUEGA', 'TEERÃO', 'IRÃO'),
#     ('OSLO', 'NORUEGA', 'BERNA', 'SUÍÇA'),
#     ('OTTAWA', 'CANADÁ', 'TEERÃO', 'IRÃO'),
#     ('OTTAWA', 'CANADÁ', 'BERNA', 'SUÍÇA'),
#     ('OTTAWA', 'CANADÁ', 'CAIRO', 'EGITO'),
#     ('OTTAWA', 'CANADÁ', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('OTTAWA', 'CANADÁ', 'LONDRES', 'INGLATERRA'),
#     ('PARIS', 'FRANÇA', 'TEERÃO', 'IRÃO'),
#     ('PARIS', 'FRANÇA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('PARIS', 'FRANÇA', 'LONDRES', 'INGLATERRA'),
#     ('ROMA', 'ITÁLIA', 'TEERÃO', 'IRÃO'),
#     ('ROMA', 'ITÁLIA', 'BERNA', 'SUÍÇA'),
#     ('ROMA', 'ITÁLIA', 'CAIRO', 'EGITO'),
#     ('ROMA', 'ITÁLIA', 'HANÓI', 'VIETNAME'),
#     ('ROMA', 'ITÁLIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('ROMA', 'ITÁLIA', 'LONDRES', 'INGLATERRA'),
#     ('ESTOCOLMO', 'SUÉCIA', 'TEERÃO', 'IRÃO'),
#     ('ESTOCOLMO', 'SUÉCIA', 'BERNA', 'SUÍÇA'),
#     ('TEERÃO', 'IRÃO', 'TÓQUIO', 'JAPÃO'),
#     ('TEERÃO', 'IRÃO', 'ATENAS', 'GRÉCIA'),
#     ('TEERÃO', 'IRÃO', 'BAGDADE', 'IRAQUE'),
#     ('TEERÃO', 'IRÃO', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('TEERÃO', 'IRÃO', 'PEQUIM', 'CHINA'),
#     ('TEERÃO', 'IRÃO', 'BERLIM', 'ALEMANHA'),
#     ('TEERÃO', 'IRÃO', 'BERNA', 'SUÍÇA'),
#     ('TEERÃO', 'IRÃO', 'CAIRO', 'EGITO'),
#     ('TEERÃO', 'IRÃO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('TEERÃO', 'IRÃO', 'HANÓI', 'VIETNAME'),
#     ('TEERÃO', 'IRÃO', 'HAVANA', 'CUBA'),
#     ('TEERÃO', 'IRÃO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('TEERÃO', 'IRÃO', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('TEERÃO', 'IRÃO', 'LONDRES', 'INGLATERRA'),
#     ('TEERÃO', 'IRÃO', 'MADRID', 'ESPANHA'),
#     ('TEERÃO', 'IRÃO', 'MOSCOVO', 'RÚSSIA'),
#     ('TEERÃO', 'IRÃO', 'OSLO', 'NORUEGA'),
#     ('TEERÃO', 'IRÃO', 'OTTAWA', 'CANADÁ'),
#     ('TEERÃO', 'IRÃO', 'PARIS', 'FRANÇA'),
#     ('TEERÃO', 'IRÃO', 'ROMA', 'ITÁLIA'),
#     ('TEERÃO', 'IRÃO', 'ESTOCOLMO', 'SUÉCIA'),
#     ('TÓQUIO', 'JAPÃO', 'HANÓI', 'VIETNAME'),
#     ('TÓQUIO', 'JAPÃO', 'TEERÃO', 'IRÃO')]},
#   {'section': 'capital-world',
#    'correct': [('ABUJA', 'NIGÉRIA', 'ACRA', 'GANA'),
#     ('ABUJA', 'NIGÉRIA', 'ARGEL', 'ARGÉLIA'),
#     ('ABUJA', 'NIGÉRIA', 'AMÃ', 'JORDÂNIA'),
#     ('ABUJA', 'NIGÉRIA', 'ANCARA', 'TURQUIA'),
#     ('ABUJA', 'NIGÉRIA', 'ANTANANARIVO', 'MADAGÁSCAR'),
#     ('ABUJA', 'NIGÉRIA', 'ATENAS', 'GRÉCIA'),
#     ('ABUJA', 'NIGÉRIA', 'BAGDADE', 'IRAQUE'),
#     ('ABUJA', 'NIGÉRIA', 'BAKU', 'AZERBAIJÃO'),
#     ('ABUJA', 'NIGÉRIA', 'BAMAKO', 'MALI'),
#     ('ABUJA', 'NIGÉRIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ABUJA', 'NIGÉRIA', 'PEQUIM', 'CHINA'),
#     ('ABUJA', 'NIGÉRIA', 'BEIRUTE', 'LÍBANO'),
#     ('ABUJA', 'NIGÉRIA', 'BELGRADO', 'SÉRVIA'),
#     ('ABUJA', 'NIGÉRIA', 'BERLIM', 'ALEMANHA'),
#     ('ABUJA', 'NIGÉRIA', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('ABUJA', 'NIGÉRIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ABUJA', 'NIGÉRIA', 'BRUXELAS', 'BÉLGICA'),
#     ('ABUJA', 'NIGÉRIA', 'BUCARESTE', 'ROMÉNIA'),
#     ('ABUJA', 'NIGÉRIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('ABUJA', 'NIGÉRIA', 'BUJUMBURA', 'BURUNDI'),
#     ('ABUJA', 'NIGÉRIA', 'CAIRO', 'EGITO'),
#     ('ABUJA', 'NIGÉRIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ABUJA', 'NIGÉRIA', 'CARACAS', 'VENEZUELA'),
#     ('ABUJA', 'NIGÉRIA', 'DACAR', 'SENEGAL'),
#     ('ABUJA', 'NIGÉRIA', 'DAMASCO', 'SÍRIA'),
#     ('ABUJA', 'NIGÉRIA', 'DUBLIM', 'IRLANDA'),
#     ('ACRA', 'GANA', 'AMÃ', 'JORDÂNIA'),
#     ('ACRA', 'GANA', 'ANCARA', 'TURQUIA'),
#     ('ACRA', 'GANA', 'ATENAS', 'GRÉCIA'),
#     ('ACRA', 'GANA', 'BAGDADE', 'IRAQUE'),
#     ('ACRA', 'GANA', 'BAKU', 'AZERBAIJÃO'),
#     ('ACRA', 'GANA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ACRA', 'GANA', 'PEQUIM', 'CHINA'),
#     ('ACRA', 'GANA', 'BEIRUTE', 'LÍBANO'),
#     ('ACRA', 'GANA', 'BERLIM', 'ALEMANHA'),
#     ('ACRA', 'GANA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ACRA', 'GANA', 'BRUXELAS', 'BÉLGICA'),
#     ('ACRA', 'GANA', 'BUDAPESTE', 'HUNGRIA'),
#     ('ACRA', 'GANA', 'BUJUMBURA', 'BURUNDI'),
#     ('ACRA', 'GANA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ACRA', 'GANA', 'CARACAS', 'VENEZUELA'),
#     ('ACRA', 'GANA', 'COPENHAGA', 'DINAMARCA'),
#     ('ACRA', 'GANA', 'DACAR', 'SENEGAL'),
#     ('ACRA', 'GANA', 'DUBLIM', 'IRLANDA'),
#     ('ARGEL', 'ARGÉLIA', 'AMÃ', 'JORDÂNIA'),
#     ('ARGEL', 'ARGÉLIA', 'ANCARA', 'TURQUIA'),
#     ('ARGEL', 'ARGÉLIA', 'ANTANANARIVO', 'MADAGÁSCAR'),
#     ('ARGEL', 'ARGÉLIA', 'APIA', 'SAMOA'),
#     ('ARGEL', 'ARGÉLIA', 'ASTANA', 'CAZAQUISTÃO'),
#     ('ARGEL', 'ARGÉLIA', 'ATENAS', 'GRÉCIA'),
#     ('ARGEL', 'ARGÉLIA', 'BAGDADE', 'IRAQUE'),
#     ('ARGEL', 'ARGÉLIA', 'BAKU', 'AZERBAIJÃO'),
#     ('ARGEL', 'ARGÉLIA', 'BAMAKO', 'MALI'),
#     ('ARGEL', 'ARGÉLIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ARGEL', 'ARGÉLIA', 'PEQUIM', 'CHINA'),
#     ('ARGEL', 'ARGÉLIA', 'BEIRUTE', 'LÍBANO'),
#     ('ARGEL', 'ARGÉLIA', 'BERLIM', 'ALEMANHA'),
#     ('ARGEL', 'ARGÉLIA', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('ARGEL', 'ARGÉLIA', 'BRUXELAS', 'BÉLGICA'),
#     ('ARGEL', 'ARGÉLIA', 'BUCARESTE', 'ROMÉNIA'),
#     ('ARGEL', 'ARGÉLIA', 'BUJUMBURA', 'BURUNDI'),
#     ('ARGEL', 'ARGÉLIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ARGEL', 'ARGÉLIA', 'CARACAS', 'VENEZUELA'),
#     ('ARGEL', 'ARGÉLIA', 'COPENHAGA', 'DINAMARCA'),
#     ('ARGEL', 'ARGÉLIA', 'DACAR', 'SENEGAL'),
#     ('ARGEL', 'ARGÉLIA', 'DAMASCO', 'SÍRIA'),
#     ('ARGEL', 'ARGÉLIA', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('AMÃ', 'JORDÂNIA', 'ANCARA', 'TURQUIA'),
#     ('AMÃ', 'JORDÂNIA', 'ANTANANARIVO', 'MADAGÁSCAR'),
#     ('AMÃ', 'JORDÂNIA', 'APIA', 'SAMOA'),
#     ('AMÃ', 'JORDÂNIA', 'ASMARA', 'ERITREIA'),
#     ('AMÃ', 'JORDÂNIA', 'ASTANA', 'CAZAQUISTÃO'),
#     ('AMÃ', 'JORDÂNIA', 'ATENAS', 'GRÉCIA'),
#     ('AMÃ', 'JORDÂNIA', 'BAGDADE', 'IRAQUE'),
#     ('AMÃ', 'JORDÂNIA', 'BAKU', 'AZERBAIJÃO'),
#     ('AMÃ', 'JORDÂNIA', 'BAMAKO', 'MALI'),
#     ('AMÃ', 'JORDÂNIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('AMÃ', 'JORDÂNIA', 'PEQUIM', 'CHINA'),
#     ('AMÃ', 'JORDÂNIA', 'BEIRUTE', 'LÍBANO'),
#     ('AMÃ', 'JORDÂNIA', 'BERLIM', 'ALEMANHA'),
#     ('AMÃ', 'JORDÂNIA', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('AMÃ', 'JORDÂNIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('AMÃ', 'JORDÂNIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('AMÃ', 'JORDÂNIA', 'BUJUMBURA', 'BURUNDI'),
#     ('AMÃ', 'JORDÂNIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('AMÃ', 'JORDÂNIA', 'CARACAS', 'VENEZUELA'),
#     ('AMÃ', 'JORDÂNIA', 'CHISINAU', 'MOLDÁVIA'),
#     ('AMÃ', 'JORDÂNIA', 'COPENHAGA', 'DINAMARCA'),
#     ('AMÃ', 'JORDÂNIA', 'DACAR', 'SENEGAL'),
#     ('AMÃ', 'JORDÂNIA', 'DAMASCO', 'SÍRIA'),
#     ('AMÃ', 'JORDÂNIA', 'DUBLIM', 'IRLANDA'),
#     ('AMÃ', 'JORDÂNIA', 'GABORONE', 'BOTSUANA'),
#     ('ANCARA', 'TURQUIA', 'ANTANANARIVO', 'MADAGÁSCAR'),
#     ('ANCARA', 'TURQUIA', 'APIA', 'SAMOA'),
#     ('ANCARA', 'TURQUIA', 'ATENAS', 'GRÉCIA'),
#     ('ANCARA', 'TURQUIA', 'BAGDADE', 'IRAQUE'),
#     ('ANCARA', 'TURQUIA', 'BAKU', 'AZERBAIJÃO'),
#     ('ANCARA', 'TURQUIA', 'BAMAKO', 'MALI'),
#     ('ANCARA', 'TURQUIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ANCARA', 'TURQUIA', 'PEQUIM', 'CHINA'),
#     ('ANCARA', 'TURQUIA', 'BEIRUTE', 'LÍBANO'),
#     ('ANCARA', 'TURQUIA', 'BERLIM', 'ALEMANHA'),
#     ('ANCARA', 'TURQUIA', 'BERNA', 'SUÍÇA'),
#     ('ANCARA', 'TURQUIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ANCARA', 'TURQUIA', 'BRUXELAS', 'BÉLGICA'),
#     ('ANCARA', 'TURQUIA', 'BUCARESTE', 'ROMÉNIA'),
#     ('ANCARA', 'TURQUIA', 'BUJUMBURA', 'BURUNDI'),
#     ('ANCARA', 'TURQUIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ANCARA', 'TURQUIA', 'CARACAS', 'VENEZUELA'),
#     ('ANCARA', 'TURQUIA', 'DACAR', 'SENEGAL'),
#     ('ANCARA', 'TURQUIA', 'DAMASCO', 'SÍRIA'),
#     ('ANCARA', 'TURQUIA', 'GABORONE', 'BOTSUANA'),
#     ('ANCARA', 'TURQUIA', 'HANÓI', 'VIETNAME'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'ASGABATE', 'TURQUEMENISTÃO'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'ASMARA', 'ERITREIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'ASTANA', 'CAZAQUISTÃO'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'ATENAS', 'GRÉCIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BAKU', 'AZERBAIJÃO'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BAMAKO', 'MALI'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'PEQUIM', 'CHINA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BEIRUTE', 'LÍBANO'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BELGRADO', 'SÉRVIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BERLIM', 'ALEMANHA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BUCARESTE', 'ROMÉNIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BUDAPESTE', 'HUNGRIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'BUJUMBURA', 'BURUNDI'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'CARACAS', 'VENEZUELA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'DACAR', 'SENEGAL'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'GABORONE', 'BOTSUANA'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'HANÓI', 'VIETNAME'),
#     ('ANTANANARIVO', 'MADAGÁSCAR', 'HARARE', 'ZIMBABUÉ'),
#     ('APIA', 'SAMOA', 'ATENAS', 'GRÉCIA'),
#     ('APIA', 'SAMOA', 'BAKU', 'AZERBAIJÃO'),
#     ('APIA', 'SAMOA', 'BEIRUTE', 'LÍBANO'),
#     ('APIA', 'SAMOA', 'BERLIM', 'ALEMANHA'),
#     ('APIA', 'SAMOA', 'BERNA', 'SUÍÇA'),
#     ('APIA', 'SAMOA', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('APIA', 'SAMOA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('APIA', 'SAMOA', 'BUJUMBURA', 'BURUNDI'),
#     ('APIA', 'SAMOA', 'CARACAS', 'VENEZUELA'),
#     ('APIA', 'SAMOA', 'DACAR', 'SENEGAL'),
#     ('APIA', 'SAMOA', 'DAMASCO', 'SÍRIA'),
#     ('APIA', 'SAMOA', 'FUNAFUTI', 'TUVALU'),
#     ('APIA', 'SAMOA', 'GABORONE', 'BOTSUANA'),
#     ('APIA', 'SAMOA', 'HANÓI', 'VIETNAME'),
#     ('APIA', 'SAMOA', 'HAVANA', 'CUBA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'ASTANA', 'CAZAQUISTÃO'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'ATENAS', 'GRÉCIA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BAGDADE', 'IRAQUE'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BAKU', 'AZERBAIJÃO'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'PEQUIM', 'CHINA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BEIRUTE', 'LÍBANO'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BUCARESTE', 'ROMÉNIA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BUDAPESTE', 'HUNGRIA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'BUJUMBURA', 'BURUNDI'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'CARACAS', 'VENEZUELA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'DACAR', 'SENEGAL'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'DAMASCO', 'SÍRIA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'GABORONE', 'BOTSUANA'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'HANÓI', 'VIETNAME'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'HARARE', 'ZIMBABUÉ'),
#     ('ASGABATE', 'TURQUEMENISTÃO', 'HAVANA', 'CUBA'),
#     ('ASMARA', 'ERITREIA', 'ATENAS', 'GRÉCIA'),
#     ('ASMARA', 'ERITREIA', 'BAGDADE', 'IRAQUE'),
#     ('ASMARA', 'ERITREIA', 'BAKU', 'AZERBAIJÃO'),
#     ('ASMARA', 'ERITREIA', 'BAMAKO', 'MALI'),
#     ('ASMARA', 'ERITREIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ASMARA', 'ERITREIA', 'PEQUIM', 'CHINA'),
#     ('ASMARA', 'ERITREIA', 'BEIRUTE', 'LÍBANO'),
#     ('ASMARA', 'ERITREIA', 'BELGRADO', 'SÉRVIA'),
#     ('ASMARA', 'ERITREIA', 'BERLIM', 'ALEMANHA'),
#     ('ASMARA', 'ERITREIA', 'BERNA', 'SUÍÇA'),
#     ('ASMARA', 'ERITREIA', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('ASMARA', 'ERITREIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ASMARA', 'ERITREIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('ASMARA', 'ERITREIA', 'BUJUMBURA', 'BURUNDI'),
#     ('ASMARA', 'ERITREIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ASMARA', 'ERITREIA', 'CARACAS', 'VENEZUELA'),
#     ('ASMARA', 'ERITREIA', 'CHISINAU', 'MOLDÁVIA'),
#     ('ASMARA', 'ERITREIA', 'DACAR', 'SENEGAL'),
#     ('ASMARA', 'ERITREIA', 'DAMASCO', 'SÍRIA'),
#     ('ASMARA', 'ERITREIA', 'HARARE', 'ZIMBABUÉ'),
#     ('ASMARA', 'ERITREIA', 'HAVANA', 'CUBA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'ATENAS', 'GRÉCIA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'BAGDADE', 'IRAQUE'),
#     ('ASTANA', 'CAZAQUISTÃO', 'BAMAKO', 'MALI'),
#     ('ASTANA', 'CAZAQUISTÃO', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'PEQUIM', 'CHINA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'BEIRUTE', 'LÍBANO'),
#     ('ASTANA', 'CAZAQUISTÃO', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('ASTANA', 'CAZAQUISTÃO', 'BUJUMBURA', 'BURUNDI'),
#     ('ASTANA', 'CAZAQUISTÃO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'CARACAS', 'VENEZUELA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'DACAR', 'SENEGAL'),
#     ('ASTANA', 'CAZAQUISTÃO', 'DAMASCO', 'SÍRIA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'HANÓI', 'VIETNAME'),
#     ('ASTANA', 'CAZAQUISTÃO', 'HARARE', 'ZIMBABUÉ'),
#     ('ASTANA', 'CAZAQUISTÃO', 'HAVANA', 'CUBA'),
#     ('ASTANA', 'CAZAQUISTÃO', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('ASTANA', 'CAZAQUISTÃO', 'JACARTA', 'INDONÉSIA'),
#     ('ATENAS', 'GRÉCIA', 'BAGDADE', 'IRAQUE'),
#     ('ATENAS', 'GRÉCIA', 'BAKU', 'AZERBAIJÃO'),
#     ('ATENAS', 'GRÉCIA', 'BAMAKO', 'MALI'),
#     ('ATENAS', 'GRÉCIA', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('ATENAS', 'GRÉCIA', 'PEQUIM', 'CHINA'),
#     ('ATENAS', 'GRÉCIA', 'BEIRUTE', 'LÍBANO'),
#     ('ATENAS', 'GRÉCIA', 'BELGRADO', 'SÉRVIA'),
#     ('ATENAS', 'GRÉCIA', 'BERLIM', 'ALEMANHA'),
#     ('ATENAS', 'GRÉCIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('ATENAS', 'GRÉCIA', 'BRUXELAS', 'BÉLGICA'),
#     ('ATENAS', 'GRÉCIA', 'BUCARESTE', 'ROMÉNIA'),
#     ('ATENAS', 'GRÉCIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('ATENAS', 'GRÉCIA', 'CAIRO', 'EGITO'),
#     ('ATENAS', 'GRÉCIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('ATENAS', 'GRÉCIA', 'CARACAS', 'VENEZUELA'),
#     ('ATENAS', 'GRÉCIA', 'COPENHAGA', 'DINAMARCA'),
#     ('ATENAS', 'GRÉCIA', 'DACAR', 'SENEGAL'),
#     ('ATENAS', 'GRÉCIA', 'DAMASCO', 'SÍRIA'),
#     ('ATENAS', 'GRÉCIA', 'DUBLIM', 'IRLANDA'),
#     ('ATENAS', 'GRÉCIA', 'HANÓI', 'VIETNAME'),
#     ('ATENAS', 'GRÉCIA', 'HAVANA', 'CUBA'),
#     ('ATENAS', 'GRÉCIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('ATENAS', 'GRÉCIA', 'JACARTA', 'INDONÉSIA'),
#     ('BAGDADE', 'IRAQUE', 'BAKU', 'AZERBAIJÃO'),
#     ('BAGDADE', 'IRAQUE', 'BAMAKO', 'MALI'),
#     ('BAGDADE', 'IRAQUE', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('BAGDADE', 'IRAQUE', 'PEQUIM', 'CHINA'),
#     ('BAGDADE', 'IRAQUE', 'BEIRUTE', 'LÍBANO'),
#     ('BAGDADE', 'IRAQUE', 'BELGRADO', 'SÉRVIA'),
#     ('BAGDADE', 'IRAQUE', 'BERLIM', 'ALEMANHA'),
#     ('BAGDADE', 'IRAQUE', 'BERNA', 'SUÍÇA'),
#     ('BAGDADE', 'IRAQUE', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BAGDADE', 'IRAQUE', 'CAIRO', 'EGITO'),
#     ('BAGDADE', 'IRAQUE', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BAGDADE', 'IRAQUE', 'CARACAS', 'VENEZUELA'),
#     ('BAGDADE', 'IRAQUE', 'DACAR', 'SENEGAL'),
#     ('BAGDADE', 'IRAQUE', 'DAMASCO', 'SÍRIA'),
#     ('BAGDADE', 'IRAQUE', 'GABORONE', 'BOTSUANA'),
#     ('BAGDADE', 'IRAQUE', 'HAVANA', 'CUBA'),
#     ('BAGDADE', 'IRAQUE', 'JACARTA', 'INDONÉSIA'),
#     ('BAKU', 'AZERBAIJÃO', 'BAMAKO', 'MALI'),
#     ('BAKU', 'AZERBAIJÃO', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('BAKU', 'AZERBAIJÃO', 'BANJUL', 'GÂMBIA'),
#     ('BAKU', 'AZERBAIJÃO', 'PEQUIM', 'CHINA'),
#     ('BAKU', 'AZERBAIJÃO', 'BEIRUTE', 'LÍBANO'),
#     ('BAKU', 'AZERBAIJÃO', 'BELGRADO', 'SÉRVIA'),
#     ('BAKU', 'AZERBAIJÃO', 'BERNA', 'SUÍÇA'),
#     ('BAKU', 'AZERBAIJÃO', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BAKU', 'AZERBAIJÃO', 'BUDAPESTE', 'HUNGRIA'),
#     ('BAKU', 'AZERBAIJÃO', 'BUJUMBURA', 'BURUNDI'),
#     ('BAKU', 'AZERBAIJÃO', 'CARACAS', 'VENEZUELA'),
#     ('BAKU', 'AZERBAIJÃO', 'DACAR', 'SENEGAL'),
#     ('BAKU', 'AZERBAIJÃO', 'DAMASCO', 'SÍRIA'),
#     ('BAKU', 'AZERBAIJÃO', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('BAKU', 'AZERBAIJÃO', 'HANÓI', 'VIETNAME'),
#     ('BAKU', 'AZERBAIJÃO', 'HARARE', 'ZIMBABUÉ'),
#     ('BAKU', 'AZERBAIJÃO', 'HAVANA', 'CUBA'),
#     ('BAKU', 'AZERBAIJÃO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BAKU', 'AZERBAIJÃO', 'JACARTA', 'INDONÉSIA'),
#     ('BAKU', 'AZERBAIJÃO', 'CATMANDU', 'NEPAL'),
#     ('BAMAKO', 'MALI', 'BANGUECOQUE', 'TAILÂNDIA'),
#     ('BAMAKO', 'MALI', 'PEQUIM', 'CHINA'),
#     ('BAMAKO', 'MALI', 'BEIRUTE', 'LÍBANO'),
#     ('BAMAKO', 'MALI', 'BELGRADO', 'SÉRVIA'),
#     ('BAMAKO', 'MALI', 'BERLIM', 'ALEMANHA'),
#     ('BAMAKO', 'MALI', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('BAMAKO', 'MALI', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BAMAKO', 'MALI', 'BUDAPESTE', 'HUNGRIA'),
#     ('BAMAKO', 'MALI', 'BUJUMBURA', 'BURUNDI'),
#     ('BAMAKO', 'MALI', 'CAIRO', 'EGITO'),
#     ('BAMAKO', 'MALI', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BAMAKO', 'MALI', 'CARACAS', 'VENEZUELA'),
#     ('BAMAKO', 'MALI', 'DACAR', 'SENEGAL'),
#     ('BAMAKO', 'MALI', 'DAMASCO', 'SÍRIA'),
#     ('BAMAKO', 'MALI', 'DUBLIM', 'IRLANDA'),
#     ('BAMAKO', 'MALI', 'HAVANA', 'CUBA'),
#     ('BAMAKO', 'MALI', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BAMAKO', 'MALI', 'JACARTA', 'INDONÉSIA'),
#     ('BAMAKO', 'MALI', 'CAMPALA', 'UGANDA'),
#     ('BAMAKO', 'MALI', 'CARTUM', 'SUDÃO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'PEQUIM', 'CHINA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BEIRUTE', 'LÍBANO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BELGRADO', 'SÉRVIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BERLIM', 'ALEMANHA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BRUXELAS', 'BÉLGICA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'BUJUMBURA', 'BURUNDI'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CAIRO', 'EGITO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CARACAS', 'VENEZUELA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CHISINAU', 'MOLDÁVIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'COPENHAGA', 'DINAMARCA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'DACAR', 'SENEGAL'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'DAMASCO', 'SÍRIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'DUBLIM', 'IRLANDA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'HAVANA', 'CUBA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'JACARTA', 'INDONÉSIA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CAMPALA', 'UGANDA'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CATMANDU', 'NEPAL'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'CARTUM', 'SUDÃO'),
#     ('BANGUECOQUE', 'TAILÂNDIA', 'KIEV', 'UCRÂNIA'),
#     ('BANJUL', 'GÂMBIA', 'PEQUIM', 'CHINA'),
#     ('BANJUL', 'GÂMBIA', 'BEIRUTE', 'LÍBANO'),
#     ('BANJUL', 'GÂMBIA', 'BELGRADO', 'SÉRVIA'),
#     ('BANJUL', 'GÂMBIA', 'BERLIM', 'ALEMANHA'),
#     ('BANJUL', 'GÂMBIA', 'BERNA', 'SUÍÇA'),
#     ('BANJUL', 'GÂMBIA', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('BANJUL', 'GÂMBIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BANJUL', 'GÂMBIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BANJUL', 'GÂMBIA', 'BUJUMBURA', 'BURUNDI'),
#     ('BANJUL', 'GÂMBIA', 'CAIRO', 'EGITO'),
#     ('BANJUL', 'GÂMBIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BANJUL', 'GÂMBIA', 'CARACAS', 'VENEZUELA'),
#     ('BANJUL', 'GÂMBIA', 'DACAR', 'SENEGAL'),
#     ('BANJUL', 'GÂMBIA', 'DAMASCO', 'SÍRIA'),
#     ('BANJUL', 'GÂMBIA', 'DUBLIM', 'IRLANDA'),
#     ('BANJUL', 'GÂMBIA', 'GABORONE', 'BOTSUANA'),
#     ('BANJUL', 'GÂMBIA', 'HAVANA', 'CUBA'),
#     ('BANJUL', 'GÂMBIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BANJUL', 'GÂMBIA', 'JACARTA', 'INDONÉSIA'),
#     ('BANJUL', 'GÂMBIA', 'CAMPALA', 'UGANDA'),
#     ('BANJUL', 'GÂMBIA', 'CATMANDU', 'NEPAL'),
#     ('BANJUL', 'GÂMBIA', 'CARTUM', 'SUDÃO'),
#     ('BANJUL', 'GÂMBIA', 'KIEV', 'UCRÂNIA'),
#     ('PEQUIM', 'CHINA', 'BEIRUTE', 'LÍBANO'),
#     ('PEQUIM', 'CHINA', 'BELGRADO', 'SÉRVIA'),
#     ('PEQUIM', 'CHINA', 'BERLIM', 'ALEMANHA'),
#     ('PEQUIM', 'CHINA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('PEQUIM', 'CHINA', 'BRUXELAS', 'BÉLGICA'),
#     ('PEQUIM', 'CHINA', 'BUDAPESTE', 'HUNGRIA'),
#     ('PEQUIM', 'CHINA', 'BUJUMBURA', 'BURUNDI'),
#     ('PEQUIM', 'CHINA', 'CAIRO', 'EGITO'),
#     ('PEQUIM', 'CHINA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('PEQUIM', 'CHINA', 'CARACAS', 'VENEZUELA'),
#     ('PEQUIM', 'CHINA', 'CHISINAU', 'MOLDÁVIA'),
#     ('PEQUIM', 'CHINA', 'COPENHAGA', 'DINAMARCA'),
#     ('PEQUIM', 'CHINA', 'DACAR', 'SENEGAL'),
#     ('PEQUIM', 'CHINA', 'DAMASCO', 'SÍRIA'),
#     ('PEQUIM', 'CHINA', 'DUBLIM', 'IRLANDA'),
#     ('PEQUIM', 'CHINA', 'HAVANA', 'CUBA'),
#     ('PEQUIM', 'CHINA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('PEQUIM', 'CHINA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('PEQUIM', 'CHINA', 'JACARTA', 'INDONÉSIA'),
#     ('PEQUIM', 'CHINA', 'CATMANDU', 'NEPAL'),
#     ('PEQUIM', 'CHINA', 'CARTUM', 'SUDÃO'),
#     ('PEQUIM', 'CHINA', 'KIEV', 'UCRÂNIA'),
#     ('BEIRUTE', 'LÍBANO', 'BELGRADO', 'SÉRVIA'),
#     ('BEIRUTE', 'LÍBANO', 'BERLIM', 'ALEMANHA'),
#     ('BEIRUTE', 'LÍBANO', 'BISQUEQUE', 'QUIRGUISTÃO'),
#     ('BEIRUTE', 'LÍBANO', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BEIRUTE', 'LÍBANO', 'BUCARESTE', 'ROMÉNIA'),
#     ('BEIRUTE', 'LÍBANO', 'BUDAPESTE', 'HUNGRIA'),
#     ('BEIRUTE', 'LÍBANO', 'BUJUMBURA', 'BURUNDI'),
#     ('BEIRUTE', 'LÍBANO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BEIRUTE', 'LÍBANO', 'CARACAS', 'VENEZUELA'),
#     ('BEIRUTE', 'LÍBANO', 'CHISINAU', 'MOLDÁVIA'),
#     ('BEIRUTE', 'LÍBANO', 'DACAR', 'SENEGAL'),
#     ('BEIRUTE', 'LÍBANO', 'DAMASCO', 'SÍRIA'),
#     ('BEIRUTE', 'LÍBANO', 'DUBLIM', 'IRLANDA'),
#     ('BEIRUTE', 'LÍBANO', 'GABORONE', 'BOTSUANA'),
#     ('BEIRUTE', 'LÍBANO', 'HANÓI', 'VIETNAME'),
#     ('BEIRUTE', 'LÍBANO', 'HARARE', 'ZIMBABUÉ'),
#     ('BEIRUTE', 'LÍBANO', 'HAVANA', 'CUBA'),
#     ('BEIRUTE', 'LÍBANO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BEIRUTE', 'LÍBANO', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BEIRUTE', 'LÍBANO', 'JACARTA', 'INDONÉSIA'),
#     ('BEIRUTE', 'LÍBANO', 'CAMPALA', 'UGANDA'),
#     ('BEIRUTE', 'LÍBANO', 'CATMANDU', 'NEPAL'),
#     ('BEIRUTE', 'LÍBANO', 'CARTUM', 'SUDÃO'),
#     ('BEIRUTE', 'LÍBANO', 'KIEV', 'UCRÂNIA'),
#     ('BEIRUTE', 'LÍBANO', 'LIBREVILLE', 'GABÃO'),
#     ('BELGRADO', 'SÉRVIA', 'BERLIM', 'ALEMANHA'),
#     ('BELGRADO', 'SÉRVIA', 'BERNA', 'SUÍÇA'),
#     ('BELGRADO', 'SÉRVIA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BELGRADO', 'SÉRVIA', 'BUJUMBURA', 'BURUNDI'),
#     ('BELGRADO', 'SÉRVIA', 'CAIRO', 'EGITO'),
#     ('BELGRADO', 'SÉRVIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BELGRADO', 'SÉRVIA', 'CARACAS', 'VENEZUELA'),
#     ('BELGRADO', 'SÉRVIA', 'CHISINAU', 'MOLDÁVIA'),
#     ('BELGRADO', 'SÉRVIA', 'DACAR', 'SENEGAL'),
#     ('BELGRADO', 'SÉRVIA', 'DAMASCO', 'SÍRIA'),
#     ('BELGRADO', 'SÉRVIA', 'GABORONE', 'BOTSUANA'),
#     ('BELGRADO', 'SÉRVIA', 'HAVANA', 'CUBA'),
#     ('BELGRADO', 'SÉRVIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BELGRADO', 'SÉRVIA', 'JACARTA', 'INDONÉSIA'),
#     ('BELGRADO', 'SÉRVIA', 'CATMANDU', 'NEPAL'),
#     ('BELGRADO', 'SÉRVIA', 'CARTUM', 'SUDÃO'),
#     ('BELGRADO', 'SÉRVIA', 'KIEV', 'UCRÂNIA'),
#     ('BELGRADO', 'SÉRVIA', 'LIBREVILLE', 'GABÃO'),
#     ('BELGRADO', 'SÉRVIA', 'LILONGWE', 'MALAUI'),
#     ('BERLIM', 'ALEMANHA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BERLIM', 'ALEMANHA', 'BRUXELAS', 'BÉLGICA'),
#     ('BERLIM', 'ALEMANHA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BERLIM', 'ALEMANHA', 'BUJUMBURA', 'BURUNDI'),
#     ('BERLIM', 'ALEMANHA', 'CAIRO', 'EGITO'),
#     ('BERLIM', 'ALEMANHA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BERLIM', 'ALEMANHA', 'CARACAS', 'VENEZUELA'),
#     ('BERLIM', 'ALEMANHA', 'COPENHAGA', 'DINAMARCA'),
#     ('BERLIM', 'ALEMANHA', 'DACAR', 'SENEGAL'),
#     ('BERLIM', 'ALEMANHA', 'DAMASCO', 'SÍRIA'),
#     ('BERLIM', 'ALEMANHA', 'DUBLIM', 'IRLANDA'),
#     ('BERLIM', 'ALEMANHA', 'HAVANA', 'CUBA'),
#     ('BERLIM', 'ALEMANHA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BERLIM', 'ALEMANHA', 'JACARTA', 'INDONÉSIA'),
#     ('BERLIM', 'ALEMANHA', 'CAMPALA', 'UGANDA'),
#     ('BERLIM', 'ALEMANHA', 'CATMANDU', 'NEPAL'),
#     ('BERLIM', 'ALEMANHA', 'CARTUM', 'SUDÃO'),
#     ('BERLIM', 'ALEMANHA', 'KIEV', 'UCRÂNIA'),
#     ('BERLIM', 'ALEMANHA', 'LIBREVILLE', 'GABÃO'),
#     ('BERLIM', 'ALEMANHA', 'LISBOA', 'PORTUGAL'),
#     ('BERNA', 'SUÍÇA', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BERNA', 'SUÍÇA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BERNA', 'SUÍÇA', 'BUJUMBURA', 'BURUNDI'),
#     ('BERNA', 'SUÍÇA', 'CAIRO', 'EGITO'),
#     ('BERNA', 'SUÍÇA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BERNA', 'SUÍÇA', 'CARACAS', 'VENEZUELA'),
#     ('BERNA', 'SUÍÇA', 'DACAR', 'SENEGAL'),
#     ('BERNA', 'SUÍÇA', 'DAMASCO', 'SÍRIA'),
#     ('BERNA', 'SUÍÇA', 'GABORONE', 'BOTSUANA'),
#     ('BERNA', 'SUÍÇA', 'HANÓI', 'VIETNAME'),
#     ('BERNA', 'SUÍÇA', 'HAVANA', 'CUBA'),
#     ('BERNA', 'SUÍÇA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BERNA', 'SUÍÇA', 'JACARTA', 'INDONÉSIA'),
#     ('BERNA', 'SUÍÇA', 'CARTUM', 'SUDÃO'),
#     ('BERNA', 'SUÍÇA', 'KIEV', 'UCRÂNIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'BRATISLAVA', 'ESLOVÁQUIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'BUCARESTE', 'ROMÉNIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'BUDAPESTE', 'HUNGRIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'BUJUMBURA', 'BURUNDI'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'CARACAS', 'VENEZUELA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'DACAR', 'SENEGAL'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'DAMASCO', 'SÍRIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'GABORONE', 'BOTSUANA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'HANÓI', 'VIETNAME'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'HARARE', 'ZIMBABUÉ'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'HAVANA', 'CUBA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'JACARTA', 'INDONÉSIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'CAMPALA', 'UGANDA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'CATMANDU', 'NEPAL'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'CARTUM', 'SUDÃO'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'KIEV', 'UCRÂNIA'),
#     ('BISQUEQUE', 'QUIRGUISTÃO', 'LIBREVILLE', 'GABÃO'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'BRUXELAS', 'BÉLGICA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'BUCARESTE', 'ROMÉNIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'BUJUMBURA', 'BURUNDI'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'CARACAS', 'VENEZUELA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'COPENHAGA', 'DINAMARCA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'DACAR', 'SENEGAL'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'DAMASCO', 'SÍRIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'DUBLIM', 'IRLANDA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'GABORONE', 'BOTSUANA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'HANÓI', 'VIETNAME'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'HARARE', 'ZIMBABUÉ'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'HAVANA', 'CUBA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'JACARTA', 'INDONÉSIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'CATMANDU', 'NEPAL'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'CARTUM', 'SUDÃO'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'KIEV', 'UCRÂNIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'KINGSTON', 'JAMAICA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'LIBREVILLE', 'GABÃO'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('BRATISLAVA', 'ESLOVÁQUIA', 'LUANDA', 'ANGOLA'),
#     ('BRUXELAS', 'BÉLGICA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BRUXELAS', 'BÉLGICA', 'BUJUMBURA', 'BURUNDI'),
#     ('BRUXELAS', 'BÉLGICA', 'CAIRO', 'EGITO'),
#     ('BRUXELAS', 'BÉLGICA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BRUXELAS', 'BÉLGICA', 'COPENHAGA', 'DINAMARCA'),
#     ('BRUXELAS', 'BÉLGICA', 'DACAR', 'SENEGAL'),
#     ('BRUXELAS', 'BÉLGICA', 'DAMASCO', 'SÍRIA'),
#     ('BRUXELAS', 'BÉLGICA', 'DUBLIM', 'IRLANDA'),
#     ('BRUXELAS', 'BÉLGICA', 'HAVANA', 'CUBA'),
#     ('BRUXELAS', 'BÉLGICA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('BRUXELAS', 'BÉLGICA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('BRUXELAS', 'BÉLGICA', 'JACARTA', 'INDONÉSIA'),
#     ('BRUXELAS', 'BÉLGICA', 'CAMPALA', 'UGANDA'),
#     ('BRUXELAS', 'BÉLGICA', 'CATMANDU', 'NEPAL'),
#     ('BRUXELAS', 'BÉLGICA', 'CARTUM', 'SUDÃO'),
#     ('BRUXELAS', 'BÉLGICA', 'KIEV', 'UCRÂNIA'),
#     ('BRUXELAS', 'BÉLGICA', 'LIBREVILLE', 'GABÃO'),
#     ('BRUXELAS', 'BÉLGICA', 'LONDRES', 'INGLATERRA'),
#     ('BRUXELAS', 'BÉLGICA', 'LUANDA', 'ANGOLA'),
#     ('BRUXELAS', 'BÉLGICA', 'LUSACA', 'ZÂMBIA'),
#     ('BUCARESTE', 'ROMÉNIA', 'BUDAPESTE', 'HUNGRIA'),
#     ('BUCARESTE', 'ROMÉNIA', 'BUJUMBURA', 'BURUNDI'),
#     ('BUCARESTE', 'ROMÉNIA', 'CAMBERRA', 'AUSTRÁLIA'),
#     ('BUCARESTE', 'ROMÉNIA', 'CARACAS', 'VENEZUELA'),
#     ('BUCARESTE', 'ROMÉNIA', 'COPENHAGA', 'DINAMARCA'),
#     ('BUCARESTE', 'ROMÉNIA', 'DACAR', 'SENEGAL'),
#     ('BUCARESTE', 'ROMÉNIA', 'DAMASCO', 'SÍRIA'),
# ...
#     ('DAMASCO', 'SÍRIA', 'HANÓI', 'VIETNAME'),
#     ('DAMASCO', 'SÍRIA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('DAMASCO', 'SÍRIA', 'CAMPALA', 'UGANDA'),
#     ('DAMASCO', 'SÍRIA', 'CATMANDU', 'NEPAL'),
#     ('DAMASCO', 'SÍRIA', 'KINGSTON', 'JAMAICA'),
#     ('DAMASCO', 'SÍRIA', 'LIBREVILLE', 'GABÃO'),
#     ('DAMASCO', 'SÍRIA', 'LILONGWE', 'MALAUI'),
#     ('DAMASCO', 'SÍRIA', 'LIMA', 'PERU'),
#     ('DAMASCO', 'SÍRIA', 'LISBOA', 'PORTUGAL'),
#     ('DAMASCO', 'SÍRIA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('DAMASCO', 'SÍRIA', 'LONDRES', 'INGLATERRA'),
#     ('DAMASCO', 'SÍRIA', 'LUSACA', 'ZÂMBIA'),
#     ('DAMASCO', 'SÍRIA', 'MADRID', 'ESPANHA'),
#     ('DAMASCO', 'SÍRIA', 'MONTEVIDEU', 'URUGUAI'),
#     ('DAMASCO', 'SÍRIA', 'MASCATE', 'OMÃ'),
#     ('DACA', 'BANGLADECHE', 'DOA', 'CATAR'),
#     ('DACA', 'BANGLADECHE', 'DUBLIM', 'IRLANDA'),
#     ('DACA', 'BANGLADECHE', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('DACA', 'BANGLADECHE', 'FUNAFUTI', 'TUVALU'),
#     ('DACA', 'BANGLADECHE', 'GEORGETOWN', 'GUIANA'),
#     ('DACA', 'BANGLADECHE', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('DACA', 'BANGLADECHE', 'CAMPALA', 'UGANDA'),
#     ('DACA', 'BANGLADECHE', 'LILONGWE', 'MALAUI'),
#     ('DACA', 'BANGLADECHE', 'LIMA', 'PERU'),
#     ('DACA', 'BANGLADECHE', 'LISBOA', 'PORTUGAL'),
#     ('DACA', 'BANGLADECHE', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('DACA', 'BANGLADECHE', 'LONDRES', 'INGLATERRA'),
#     ('DACA', 'BANGLADECHE', 'LUSACA', 'ZÂMBIA'),
#     ('DACA', 'BANGLADECHE', 'MADRID', 'ESPANHA'),
#     ('DACA', 'BANGLADECHE', 'MOSCOVO', 'RÚSSIA'),
#     ('DACA', 'BANGLADECHE', 'MASCATE', 'OMÃ'),
#     ('DACA', 'BANGLADECHE', 'NAIRÓBI', 'QUÉNIA'),
#     ('DOA', 'CATAR', 'DUBLIM', 'IRLANDA'),
#     ('DOA', 'CATAR', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('DOA', 'CATAR', 'FUNAFUTI', 'TUVALU'),
#     ('DOA', 'CATAR', 'GABORONE', 'BOTSUANA'),
#     ('DOA', 'CATAR', 'GEORGETOWN', 'GUIANA'),
#     ('DOA', 'CATAR', 'HANÓI', 'VIETNAME'),
#     ('DOA', 'CATAR', 'HARARE', 'ZIMBABUÉ'),
#     ('DOA', 'CATAR', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('DOA', 'CATAR', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('DOA', 'CATAR', 'CAMPALA', 'UGANDA'),
#     ('DOA', 'CATAR', 'CATMANDU', 'NEPAL'),
#     ('DOA', 'CATAR', 'KINGSTON', 'JAMAICA'),
#     ('DOA', 'CATAR', 'LIBREVILLE', 'GABÃO'),
#     ('DOA', 'CATAR', 'LILONGWE', 'MALAUI'),
#     ('DOA', 'CATAR', 'LIMA', 'PERU'),
#     ('DOA', 'CATAR', 'LISBOA', 'PORTUGAL'),
#     ('DOA', 'CATAR', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('DOA', 'CATAR', 'LONDRES', 'INGLATERRA'),
#     ('DOA', 'CATAR', 'LUANDA', 'ANGOLA'),
#     ('DOA', 'CATAR', 'LUSACA', 'ZÂMBIA'),
#     ('DOA', 'CATAR', 'MADRID', 'ESPANHA'),
#     ('DOA', 'CATAR', 'MANÁGUA', 'NICARÁGUA'),
#     ('DOA', 'CATAR', 'MANILA', 'FILIPINAS'),
#     ('DOA', 'CATAR', 'MAPUTO', 'MOÇAMBIQUE'),
#     ('DOA', 'CATAR', 'MINSK', 'BIELORRÚSSIA'),
#     ('DOA', 'CATAR', 'MOGADÍSCIO', 'SOMÁLIA'),
#     ('DOA', 'CATAR', 'MONRÓVIA', 'LIBÉRIA'),
#     ('DOA', 'CATAR', 'MONTEVIDEU', 'URUGUAI'),
#     ('DOA', 'CATAR', 'MOSCOVO', 'RÚSSIA'),
#     ('DOA', 'CATAR', 'MASCATE', 'OMÃ'),
#     ('DOA', 'CATAR', 'NAIRÓBI', 'QUÉNIA'),
#     ('DOA', 'CATAR', 'NASSAU', 'BAAMAS'),
#     ('DUBLIM', 'IRLANDA', 'DUCHAMBÉ', 'TAJIQUISTÃO'),
#     ('DUBLIM', 'IRLANDA', 'FUNAFUTI', 'TUVALU'),
#     ('DUBLIM', 'IRLANDA', 'GABORONE', 'BOTSUANA'),
#     ('DUBLIM', 'IRLANDA', 'GEORGETOWN', 'GUIANA'),
#     ('DUBLIM', 'IRLANDA', 'HANÓI', 'VIETNAME'),
#     ('DUBLIM', 'IRLANDA', 'HARARE', 'ZIMBABUÉ'),
#     ('DUBLIM', 'IRLANDA', 'LILONGWE', 'MALAUI'),
#     ('DUBLIM', 'IRLANDA', 'LIMA', 'PERU'),
#     ('DUBLIM', 'IRLANDA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('DUBLIM', 'IRLANDA', 'MINSK', 'BIELORRÚSSIA'),
#     ('DUBLIM', 'IRLANDA', 'MOGADÍSCIO', 'SOMÁLIA'),
#     ('DUBLIM', 'IRLANDA', 'MONTEVIDEU', 'URUGUAI'),
#     ('DUBLIM', 'IRLANDA', 'MASCATE', 'OMÃ'),
#     ('DUBLIM', 'IRLANDA', 'NAIRÓBI', 'QUÉNIA'),
#     ('DUBLIM', 'IRLANDA', 'NASSAU', 'BAAMAS'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'FUNAFUTI', 'TUVALU'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'GEORGETOWN', 'GUIANA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'CAMPALA', 'UGANDA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'KINGSTON', 'JAMAICA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'LILONGWE', 'MALAUI'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'LIMA', 'PERU'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'LISBOA', 'PORTUGAL'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'LONDRES', 'INGLATERRA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'MADRID', 'ESPANHA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'MONTEVIDEU', 'URUGUAI'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'NAIRÓBI', 'QUÉNIA'),
#     ('DUCHAMBÉ', 'TAJIQUISTÃO', 'NASSAU', 'BAAMAS'),
#     ('FUNAFUTI', 'TUVALU', 'GABORONE', 'BOTSUANA'),
#     ('FUNAFUTI', 'TUVALU', 'GEORGETOWN', 'GUIANA'),
#     ('FUNAFUTI', 'TUVALU', 'HARARE', 'ZIMBABUÉ'),
#     ('FUNAFUTI', 'TUVALU', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('FUNAFUTI', 'TUVALU', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('FUNAFUTI', 'TUVALU', 'CAMPALA', 'UGANDA'),
#     ('FUNAFUTI', 'TUVALU', 'CATMANDU', 'NEPAL'),
#     ('FUNAFUTI', 'TUVALU', 'KINGSTON', 'JAMAICA'),
#     ('FUNAFUTI', 'TUVALU', 'LIBREVILLE', 'GABÃO'),
#     ('FUNAFUTI', 'TUVALU', 'LILONGWE', 'MALAUI'),
#     ('FUNAFUTI', 'TUVALU', 'LIMA', 'PERU'),
#     ('FUNAFUTI', 'TUVALU', 'LISBOA', 'PORTUGAL'),
#     ('FUNAFUTI', 'TUVALU', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('FUNAFUTI', 'TUVALU', 'LONDRES', 'INGLATERRA'),
#     ('FUNAFUTI', 'TUVALU', 'LUSACA', 'ZÂMBIA'),
#     ('FUNAFUTI', 'TUVALU', 'MADRID', 'ESPANHA'),
#     ('FUNAFUTI', 'TUVALU', 'MANÁGUA', 'NICARÁGUA'),
#     ('FUNAFUTI', 'TUVALU', 'MOGADÍSCIO', 'SOMÁLIA'),
#     ('FUNAFUTI', 'TUVALU', 'MONTEVIDEU', 'URUGUAI'),
#     ('FUNAFUTI', 'TUVALU', 'MASCATE', 'OMÃ'),
#     ('FUNAFUTI', 'TUVALU', 'NAIRÓBI', 'QUÉNIA'),
#     ('FUNAFUTI', 'TUVALU', 'NASSAU', 'BAAMAS'),
#     ('GABORONE', 'BOTSUANA', 'GEORGETOWN', 'GUIANA'),
#     ('GABORONE', 'BOTSUANA', 'HARARE', 'ZIMBABUÉ'),
#     ('GABORONE', 'BOTSUANA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('GABORONE', 'BOTSUANA', 'KINGSTON', 'JAMAICA'),
#     ('GABORONE', 'BOTSUANA', 'LILONGWE', 'MALAUI'),
#     ('GABORONE', 'BOTSUANA', 'LIMA', 'PERU'),
#     ('GABORONE', 'BOTSUANA', 'LISBOA', 'PORTUGAL'),
#     ('GABORONE', 'BOTSUANA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('GABORONE', 'BOTSUANA', 'LONDRES', 'INGLATERRA'),
#     ('GABORONE', 'BOTSUANA', 'LUSACA', 'ZÂMBIA'),
#     ('GABORONE', 'BOTSUANA', 'MADRID', 'ESPANHA'),
#     ('GABORONE', 'BOTSUANA', 'MONTEVIDEU', 'URUGUAI'),
#     ('GABORONE', 'BOTSUANA', 'MASCATE', 'OMÃ'),
#     ('GABORONE', 'BOTSUANA', 'NAIRÓBI', 'QUÉNIA'),
#     ('GABORONE', 'BOTSUANA', 'NASSAU', 'BAAMAS'),
#     ('GEORGETOWN', 'GUIANA', 'HANÓI', 'VIETNAME'),
#     ('GEORGETOWN', 'GUIANA', 'HARARE', 'ZIMBABUÉ'),
#     ('GEORGETOWN', 'GUIANA', 'HAVANA', 'CUBA'),
#     ('GEORGETOWN', 'GUIANA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('GEORGETOWN', 'GUIANA', 'CAMPALA', 'UGANDA'),
#     ('GEORGETOWN', 'GUIANA', 'KINGSTON', 'JAMAICA'),
#     ('GEORGETOWN', 'GUIANA', 'LILONGWE', 'MALAUI'),
#     ('GEORGETOWN', 'GUIANA', 'LIMA', 'PERU'),
#     ('GEORGETOWN', 'GUIANA', 'LISBOA', 'PORTUGAL'),
#     ('GEORGETOWN', 'GUIANA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('GEORGETOWN', 'GUIANA', 'LONDRES', 'INGLATERRA'),
#     ('GEORGETOWN', 'GUIANA', 'LUANDA', 'ANGOLA'),
#     ('GEORGETOWN', 'GUIANA', 'LUSACA', 'ZÂMBIA'),
#     ('GEORGETOWN', 'GUIANA', 'MADRID', 'ESPANHA'),
#     ('GEORGETOWN', 'GUIANA', 'MANÁGUA', 'NICARÁGUA'),
#     ('GEORGETOWN', 'GUIANA', 'MANILA', 'FILIPINAS'),
#     ('GEORGETOWN', 'GUIANA', 'MONRÓVIA', 'LIBÉRIA'),
#     ('GEORGETOWN', 'GUIANA', 'MONTEVIDEU', 'URUGUAI'),
#     ('GEORGETOWN', 'GUIANA', 'MASCATE', 'OMÃ'),
#     ('GEORGETOWN', 'GUIANA', 'NAIRÓBI', 'QUÉNIA'),
#     ('GEORGETOWN', 'GUIANA', 'NASSAU', 'BAAMAS'),
#     ('HANÓI', 'VIETNAME', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('HANÓI', 'VIETNAME', 'KINGSTON', 'JAMAICA'),
#     ('HANÓI', 'VIETNAME', 'LILONGWE', 'MALAUI'),
#     ('HANÓI', 'VIETNAME', 'LIMA', 'PERU'),
#     ('HANÓI', 'VIETNAME', 'LISBOA', 'PORTUGAL'),
#     ('HANÓI', 'VIETNAME', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('HANÓI', 'VIETNAME', 'LONDRES', 'INGLATERRA'),
#     ('HANÓI', 'VIETNAME', 'LUSACA', 'ZÂMBIA'),
#     ('HANÓI', 'VIETNAME', 'MADRID', 'ESPANHA'),
#     ('HANÓI', 'VIETNAME', 'MONTEVIDEU', 'URUGUAI'),
#     ('HANÓI', 'VIETNAME', 'MASCATE', 'OMÃ'),
#     ('HANÓI', 'VIETNAME', 'NAIRÓBI', 'QUÉNIA'),
#     ('HANÓI', 'VIETNAME', 'NASSAU', 'BAAMAS'),
#     ('HARARE', 'ZIMBABUÉ', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('HARARE', 'ZIMBABUÉ', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('HARARE', 'ZIMBABUÉ', 'CAMPALA', 'UGANDA'),
#     ('HARARE', 'ZIMBABUÉ', 'KINGSTON', 'JAMAICA'),
#     ('HARARE', 'ZIMBABUÉ', 'LIBREVILLE', 'GABÃO'),
#     ('HARARE', 'ZIMBABUÉ', 'LILONGWE', 'MALAUI'),
#     ('HARARE', 'ZIMBABUÉ', 'LIMA', 'PERU'),
#     ('HARARE', 'ZIMBABUÉ', 'LISBOA', 'PORTUGAL'),
#     ('HARARE', 'ZIMBABUÉ', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('HARARE', 'ZIMBABUÉ', 'LONDRES', 'INGLATERRA'),
#     ('HARARE', 'ZIMBABUÉ', 'LUSACA', 'ZÂMBIA'),
#     ('HARARE', 'ZIMBABUÉ', 'MADRID', 'ESPANHA'),
#     ('HARARE', 'ZIMBABUÉ', 'MASCATE', 'OMÃ'),
#     ('HARARE', 'ZIMBABUÉ', 'NAIRÓBI', 'QUÉNIA'),
#     ('HARARE', 'ZIMBABUÉ', 'NASSAU', 'BAAMAS'),
#     ('HAVANA', 'CUBA', 'HELSÍNQUIA', 'FINLÂNDIA'),
#     ('HAVANA', 'CUBA', 'ISLAMABADE', 'PAQUISTÃO'),
#     ('HAVANA', 'CUBA', 'CAMPALA', 'UGANDA'),
#     ('HAVANA', 'CUBA', 'KINGSTON', 'JAMAICA'),
#     ('HAVANA', 'CUBA', 'LILONGWE', 'MALAUI'),
#     ('HAVANA', 'CUBA', 'LIMA', 'PERU'),
#     ('HAVANA', 'CUBA', 'LISBOA', 'PORTUGAL'),
#     ('HAVANA', 'CUBA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('HAVANA', 'CUBA', 'LUSACA', 'ZÂMBIA'),
#     ('HAVANA', 'CUBA', 'MADRID', 'ESPANHA'),
#     ('HAVANA', 'CUBA', 'MONTEVIDEU', 'URUGUAI'),
#     ('HAVANA', 'CUBA', 'MASCATE', 'OMÃ'),
#     ('HAVANA', 'CUBA', 'NAIRÓBI', 'QUÉNIA'),
#     ('HAVANA', 'CUBA', 'NASSAU', 'BAAMAS'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'KINGSTON', 'JAMAICA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'LIBREVILLE', 'GABÃO'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'LILONGWE', 'MALAUI'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'LIMA', 'PERU'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'MASCATE', 'OMÃ'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'NAIRÓBI', 'QUÉNIA'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'NASSAU', 'BAAMAS'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'NICÓSIA', 'CHIPRE'),
#     ('HELSÍNQUIA', 'FINLÂNDIA', 'PODGORICA', 'MONTENEGRO'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'KINGSTON', 'JAMAICA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'LILONGWE', 'MALAUI'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'LIMA', 'PERU'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'LISBOA', 'PORTUGAL'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'MADRID', 'ESPANHA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'MOGADÍSCIO', 'SOMÁLIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'MONTEVIDEU', 'URUGUAI'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'MASCATE', 'OMÃ'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'NAIRÓBI', 'QUÉNIA'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'NASSAU', 'BAAMAS'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'OTTAWA', 'CANADÁ'),
#     ('ISLAMABADE', 'PAQUISTÃO', 'PODGORICA', 'MONTENEGRO'),
#     ('JACARTA', 'INDONÉSIA', 'CAMPALA', 'UGANDA'),
#     ('JACARTA', 'INDONÉSIA', 'KINGSTON', 'JAMAICA'),
#     ('JACARTA', 'INDONÉSIA', 'LILONGWE', 'MALAUI'),
#     ('JACARTA', 'INDONÉSIA', 'LIMA', 'PERU'),
#     ('JACARTA', 'INDONÉSIA', 'LISBOA', 'PORTUGAL'),
#     ('JACARTA', 'INDONÉSIA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('JACARTA', 'INDONÉSIA', 'LUSACA', 'ZÂMBIA'),
#     ('JACARTA', 'INDONÉSIA', 'MADRID', 'ESPANHA'),
#     ('JACARTA', 'INDONÉSIA', 'MONTEVIDEU', 'URUGUAI'),
#     ('JACARTA', 'INDONÉSIA', 'MASCATE', 'OMÃ'),
#     ('JACARTA', 'INDONÉSIA', 'NAIRÓBI', 'QUÉNIA'),
#     ('JACARTA', 'INDONÉSIA', 'NASSAU', 'BAAMAS'),
#     ('JACARTA', 'INDONÉSIA', 'PODGORICA', 'MONTENEGRO'),
#     ('CAMPALA', 'UGANDA', 'LILONGWE', 'MALAUI'),
#     ('CAMPALA', 'UGANDA', 'LIMA', 'PERU'),
#     ('CAMPALA', 'UGANDA', 'LISBOA', 'PORTUGAL'),
#     ('CAMPALA', 'UGANDA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('CAMPALA', 'UGANDA', 'LONDRES', 'INGLATERRA'),
#     ('CAMPALA', 'UGANDA', 'MADRID', 'ESPANHA'),
#     ('CAMPALA', 'UGANDA', 'NAIRÓBI', 'QUÉNIA'),
#     ('CAMPALA', 'UGANDA', 'NASSAU', 'BAAMAS'),
#     ('CAMPALA', 'UGANDA', 'PODGORICA', 'MONTENEGRO'),
#     ('CAMPALA', 'UGANDA', 'RIGA', 'LETÓNIA'),
#     ('CATMANDU', 'NEPAL', 'KINGSTON', 'JAMAICA'),
#     ('CATMANDU', 'NEPAL', 'LILONGWE', 'MALAUI'),
#     ('CATMANDU', 'NEPAL', 'LIMA', 'PERU'),
#     ('CATMANDU', 'NEPAL', 'LISBOA', 'PORTUGAL'),
#     ('CATMANDU', 'NEPAL', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('CATMANDU', 'NEPAL', 'LUSACA', 'ZÂMBIA'),
#     ('CATMANDU', 'NEPAL', 'MADRID', 'ESPANHA'),
#     ('CATMANDU', 'NEPAL', 'MOGADÍSCIO', 'SOMÁLIA'),
#     ('CATMANDU', 'NEPAL', 'MONTEVIDEU', 'URUGUAI'),
#     ('CATMANDU', 'NEPAL', 'MASCATE', 'OMÃ'),
#     ('CATMANDU', 'NEPAL', 'NAIRÓBI', 'QUÉNIA'),
#     ('CATMANDU', 'NEPAL', 'NASSAU', 'BAAMAS'),
#     ('CATMANDU', 'NEPAL', 'PODGORICA', 'MONTENEGRO'),
#     ('CATMANDU', 'NEPAL', 'RIGA', 'LETÓNIA'),
#     ('CATMANDU', 'NEPAL', 'ROSEAU', 'DOMINICA'),
#     ('CARTUM', 'SUDÃO', 'KINGSTON', 'JAMAICA'),
#     ('CARTUM', 'SUDÃO', 'LILONGWE', 'MALAUI'),
#     ('CARTUM', 'SUDÃO', 'LIMA', 'PERU'),
#     ('CARTUM', 'SUDÃO', 'LISBOA', 'PORTUGAL'),
#     ('CARTUM', 'SUDÃO', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('CARTUM', 'SUDÃO', 'LUSACA', 'ZÂMBIA'),
#     ('CARTUM', 'SUDÃO', 'MADRID', 'ESPANHA'),
#     ('CARTUM', 'SUDÃO', 'MONTEVIDEU', 'URUGUAI'),
#     ('CARTUM', 'SUDÃO', 'MASCATE', 'OMÃ'),
#     ('CARTUM', 'SUDÃO', 'NAIRÓBI', 'QUÉNIA'),
#     ('CARTUM', 'SUDÃO', 'NASSAU', 'BAAMAS'),
#     ('CARTUM', 'SUDÃO', 'OTTAWA', 'CANADÁ'),
#     ('CARTUM', 'SUDÃO', 'PODGORICA', 'MONTENEGRO'),
#     ('CARTUM', 'SUDÃO', 'RIGA', 'LETÓNIA'),
#     ('CARTUM', 'SUDÃO', 'ROSEAU', 'DOMINICA'),
#     ('CARTUM', 'SUDÃO', 'SANTIAGO', 'CHILE'),
#     ('KIEV', 'UCRÂNIA', 'KINGSTON', 'JAMAICA'),
#     ('KIEV', 'UCRÂNIA', 'LILONGWE', 'MALAUI'),
#     ('KIEV', 'UCRÂNIA', 'LIMA', 'PERU'),
#     ('KIEV', 'UCRÂNIA', 'LISBOA', 'PORTUGAL'),
#     ('KIEV', 'UCRÂNIA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('KIEV', 'UCRÂNIA', 'LONDRES', 'INGLATERRA'),
#     ('KIEV', 'UCRÂNIA', 'MADRID', 'ESPANHA'),
#     ('KIEV', 'UCRÂNIA', 'MASCATE', 'OMÃ'),
#     ('KIEV', 'UCRÂNIA', 'NAIRÓBI', 'QUÉNIA'),
#     ('KIEV', 'UCRÂNIA', 'NASSAU', 'BAAMAS'),
#     ('KIEV', 'UCRÂNIA', 'NICÓSIA', 'CHIPRE'),
#     ('KIEV', 'UCRÂNIA', 'PODGORICA', 'MONTENEGRO'),
#     ('KIEV', 'UCRÂNIA', 'RIGA', 'LETÓNIA'),
#     ('KIEV', 'UCRÂNIA', 'ROSEAU', 'DOMINICA'),
#     ('KIEV', 'UCRÂNIA', 'SANTIAGO', 'CHILE'),
#     ('KIEV', 'UCRÂNIA', 'ESCÓPIA', 'MACEDÓNIA'),
#     ('KINGSTON', 'JAMAICA', 'LILONGWE', 'MALAUI'),
#     ('KINGSTON', 'JAMAICA', 'LIMA', 'PERU'),
#     ('KINGSTON', 'JAMAICA', 'LISBOA', 'PORTUGAL'),
#     ('KINGSTON', 'JAMAICA', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('KINGSTON', 'JAMAICA', 'LUSACA', 'ZÂMBIA'),
#     ('KINGSTON', 'JAMAICA', 'MADRID', 'ESPANHA'),
#     ('KINGSTON', 'JAMAICA', 'MONTEVIDEU', 'URUGUAI'),
#     ('KINGSTON', 'JAMAICA', 'MASCATE', 'OMÃ'),
#     ('KINGSTON', 'JAMAICA', 'NAIRÓBI', 'QUÉNIA'),
#     ('KINGSTON', 'JAMAICA', 'NASSAU', 'BAAMAS'),
#     ('KINGSTON', 'JAMAICA', 'NICÓSIA', 'CHIPRE'),
#     ('KINGSTON', 'JAMAICA', 'PODGORICA', 'MONTENEGRO'),
#     ('KINGSTON', 'JAMAICA', 'RIGA', 'LETÓNIA'),
#     ('KINGSTON', 'JAMAICA', 'ROSEAU', 'DOMINICA'),
#     ('KINGSTON', 'JAMAICA', 'SANTIAGO', 'CHILE'),
#     ('KINGSTON', 'JAMAICA', 'ESCÓPIA', 'MACEDÓNIA'),
#     ('LIBREVILLE', 'GABÃO', 'LILONGWE', 'MALAUI'),
#     ('LIBREVILLE', 'GABÃO', 'LIMA', 'PERU'),
#     ('LIBREVILLE', 'GABÃO', 'LISBOA', 'PORTUGAL'),
#     ('LIBREVILLE', 'GABÃO', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ('LIBREVILLE', 'GABÃO', 'LUSACA', 'ZÂMBIA'),
#     ('LIBREVILLE', 'GABÃO', 'MADRID', 'ESPANHA'),
#     ('LIBREVILLE', 'GABÃO', 'MONTEVIDEU', 'URUGUAI'),
#     ('LIBREVILLE', 'GABÃO', 'MASCATE', 'OMÃ'),
#     ('LIBREVILLE', 'GABÃO', 'NAIRÓBI', 'QUÉNIA'),
#     ('LIBREVILLE', 'GABÃO', 'NASSAU', 'BAAMAS'),
#     ('LIBREVILLE', 'GABÃO', 'PODGORICA', 'MONTENEGRO'),
#     ('LIBREVILLE', 'GABÃO', 'RIGA', 'LETÓNIA'),
#     ('LIBREVILLE', 'GABÃO', 'ROSEAU', 'DOMINICA'),
#     ('LIBREVILLE', 'GABÃO', 'SANTIAGO', 'CHILE'),
#     ('LIBREVILLE', 'GABÃO', 'ESCÓPIA', 'MACEDÓNIA'),
#     ('LIBREVILLE', 'GABÃO', 'SUVA', 'FIJI'),
#     ('LILONGWE', 'MALAUI', 'LIMA', 'PERU'),
#     ('LILONGWE', 'MALAUI', 'LISBOA', 'PORTUGAL'),
#     ('LILONGWE', 'MALAUI', 'LIUBLIANA', 'ESLOVÉNIA'),
#     ...]}])

# %% [markdown]
# ### Question Seen Modelos NILC

# %%
cbow_s300 = getModel('../models/ext/nilc/cbow_s300.txt')

# %%
question_seen_cbow_s300_lxPT_ci = question_seen_in_model(cbow_s300, testset[1], True )
question_seen_cbow_s300_lxPT_cs = question_seen_in_model(cbow_s300, testset[1], False )
question_seen_cbow_s300_LxBR_ci = question_seen_in_model(cbow_s300, testset[0], True)
question_seen_cbow_s300_LxBR_cs = question_seen_in_model(cbow_s300, testset[0], False)

# %%
print(question_seen_cbow_s300_lxPT_ci['total'])
print(question_seen_cbow_s300_lxPT_cs['total'])
print(question_seen_cbow_s300_LxBR_ci['total'])
print(question_seen_cbow_s300_LxBR_cs['total'])
# Out:
# {'q_no': 17487, 'q_seen': 16142}
# {'q_no': 17487, 'q_seen': 7125}
# {'q_no': 17558, 'q_seen': 16092}
# {'q_no': 17558, 'q_seen': 7114}

# %%
print('%.2f' % (100*float(question_seen_cbow_s300_lxPT_ci['total']['q_seen']/question_seen_cbow_s300_lxPT_ci['total']['q_no'])))
print('%.2f' % (100*float(question_seen_cbow_s300_lxPT_cs['total']['q_seen']/question_seen_cbow_s300_lxPT_cs['total']['q_no'])))
print('%.2f' % (100*float(question_seen_cbow_s300_LxBR_ci['total']['q_seen']/question_seen_cbow_s300_LxBR_ci['total']['q_no'])))
print('%.2f' % (100*float(question_seen_cbow_s300_LxBR_cs['total']['q_seen']/question_seen_cbow_s300_LxBR_cs['total']['q_no'])))
# Out:
# 92.31
# 40.74
# 91.65
# 40.52

# %%
skip_s300 = getModel('../models/ext/nilc/skip_s300.txt')

# %%
question_seen_skip_s300_lxPT_ci = question_seen_in_model(skip_s300, testset[1], True )
question_seen_skip_s300_lxPT_cs = question_seen_in_model(skip_s300, testset[1], False )
question_seen_skip_s300_LxBR_ci = question_seen_in_model(skip_s300, testset[0], True)
question_seen_skip_s300_LxBR_cs = question_seen_in_model(skip_s300, testset[0], False)

# %%
print(question_seen_skip_s300_lxPT_ci['total'])
print(question_seen_skip_s300_lxPT_cs['total'])
print(question_seen_skip_s300_LxBR_ci['total'])
print(question_seen_skip_s300_LxBR_cs['total'])
# Out:
# {'q_no': 17487, 'q_seen': 16142}
# {'q_no': 17487, 'q_seen': 7125}
# {'q_no': 17558, 'q_seen': 16092}
# {'q_no': 17558, 'q_seen': 7114}

# %%
print(' skip_s300_lxPT_ci %.2f' % (100 * float(question_seen_skip_s300_lxPT_ci['total']['q_seen']/question_seen_skip_s300_lxPT_ci['total']['q_no'])))
print(' skip_s300_lxPT_cs %.2f' % (100 * float(question_seen_skip_s300_lxPT_cs['total']['q_seen']/question_seen_skip_s300_lxPT_cs['total']['q_no'])))
print(' skip_s300_LxBR_ci %.2f' % (100 * float(question_seen_skip_s300_LxBR_ci['total']['q_seen']/question_seen_skip_s300_LxBR_ci['total']['q_no'])))
print(' skip_s300_LxBR_cs %.2f' % (100 * float(question_seen_skip_s300_LxBR_cs['total']['q_seen']/question_seen_skip_s300_LxBR_cs['total']['q_no'])))
# Out:
#  skip_s300_lxPT_ci 92.31
#  skip_s300_lxPT_cs 40.74
#  skip_s300_LxBR_ci 91.65
#  skip_s300_LxBR_cs 40.52

# %%
glove_s300 = getModel('../models/ext/nilc/glove_s300.txt')

# %%
glove_s300.most_similar_cosmul(['itália','capital'])
# Out:
# [('frança', 0.5731724500656128),
#  ('cidade', 0.5694936513900757),
#  ('espanha', 0.5664260983467102),
#  ('país', 0.5657956600189209),
#  ('sul', 0.5462279915809631),
#  ('alemanha', 0.5461822152137756),
#  ('norte', 0.5430349707603455),
#  ('roma', 0.5424421429634094),
#  ('grécia', 0.5380972623825073),
#  ('parte', 0.5333743095397949)]

# %%
question_seen_glove_s300_lxPT_ci = question_seen_in_model(glove_s300, testset[1], True )
question_seen_glove_s300_lxPT_cs = question_seen_in_model(glove_s300, testset[1], False )
question_seen_glove_s300_LxBR_ci = question_seen_in_model(glove_s300, testset[0], True)
question_seen_glove_s300_LxBR_cs = question_seen_in_model(glove_s300, testset[0], False)

# %%
print(question_seen_glove_s300_lxPT_ci['total'])
print(question_seen_glove_s300_lxPT_cs['total'])
print(question_seen_glove_s300_LxBR_ci['total'])
print(question_seen_glove_s300_LxBR_cs['total'])
# Out:
# {'q_no': 17487, 'q_seen': 16142}
# {'q_no': 17487, 'q_seen': 7125}
# {'q_no': 17558, 'q_seen': 16092}
# {'q_no': 17558, 'q_seen': 7114}

# %%
print(' glove_s300_lxPT_ci %2f' % (100 * float(question_seen_glove_s300_lxPT_ci['total']['q_seen']/question_seen_glove_s300_lxPT_ci['total']['q_no'])))
print(' glove_s300_lxPT_cs %2f' % (100 * float(question_seen_glove_s300_lxPT_cs['total']['q_seen']/question_seen_glove_s300_lxPT_cs['total']['q_no'])))
print(' glove_s300_LxBR_ci %2f' % (100 * float(question_seen_glove_s300_LxBR_ci['total']['q_seen']/question_seen_glove_s300_LxBR_ci['total']['q_no'])))
print(' glove_s300_LxBR_cs %2f' % (100 * float(question_seen_glove_s300_LxBR_cs['total']['q_seen']/question_seen_glove_s300_LxBR_cs['total']['q_no'])))
# Out:
#  glove_s300_lxPT_ci 92.308572
#  glove_s300_lxPT_cs 40.744553
#  glove_s300_LxBR_ci 91.650530
#  glove_s300_LxBR_cs 40.517143

# %%
model  = getModel('../models/ext/nilc/cbow_s300.txt')

# %%
cbow_s300 = model

# %% [markdown]
# #### Question Seen com Vocabulário irrestrito

# %%
question_seen_glove_s300_lxPT_irrest = question_seen_in_model(glove_s300, testset[1], True, restrict_vocab=None)
question_seen_glove_s300_LxBR_irrest = question_seen_in_model(glove_s300, testset[0], True, restrict_vocab=None)

question_seen_cbow_s300_lxPT_irrest = question_seen_in_model(cbow_s300, testset[1], True, restrict_vocab=None)
question_seen_cbow_s300_LxBR_irrest = question_seen_in_model(cbow_s300, testset[0], True, restrict_vocab=None)

question_seen_skip_s300_lxPT_irrest = question_seen_in_model(skip_s300, testset[1], True, restrict_vocab=None)
question_seen_skip_s300_LxBR_irrest = question_seen_in_model(skip_s300, testset[0], True, restrict_vocab=None)

# %%
print(' glove_s300_lxPT_ci %2f' % (100 * float(question_seen_glove_s300_lxPT_irrest['total']['q_seen']/question_seen_glove_s300_lxPT_irrest['total']['q_no'])))
print(' glove_s300_lxPT_cs %2f' % (100 * float(question_seen_glove_s300_lxPT_irrest['total']['q_seen']/question_seen_glove_s300_lxPT_irrest['total']['q_no'])))

print(' cbow_s300_LxBR_ci %2f' % (100 * float(question_seen_cbow_s300_LxBR_irrest['total']['q_seen']/question_seen_cbow_s300_LxBR_irrest['total']['q_no'])))
print(' cbow_s300_LxBR_cs %2f' % (100 * float(question_seen_cbow_s300_LxBR_irrest['total']['q_seen']/question_seen_cbow_s300_LxBR_irrest['total']['q_no'])))

print(' skip_s300_LxBR_ci %2f' % (100 * float(question_seen_skip_s300_LxBR_irrest['total']['q_seen']/question_seen_skip_s300_LxBR_irrest['total']['q_no'])))
print(' skip_s300_LxBR_cs %2f' % (100 * float(question_seen_skip_s300_LxBR_irrest['total']['q_seen']/question_seen_skip_s300_LxBR_irrest['total']['q_no'])))
# Out:
#  glove_s300_lxPT_ci 97.192200
#  glove_s300_lxPT_cs 97.192200
#  cbow_s300_LxBR_ci 96.992824
#  cbow_s300_LxBR_cs 96.992824
#  skip_s300_LxBR_ci 96.992824
#  skip_s300_LxBR_cs 96.992824

# %%
question_seen_glove_s300_lxPT_irrest_ci = question_seen_in_model(glove_s300, testset[1], True, restrict_vocab=None)
question_seen_glove_s300_LxBR_irrest_ci = question_seen_in_model(glove_s300, testset[0], True, restrict_vocab=None)

question_seen_glove_s300_lxPT_irrest_cs = question_seen_in_model(glove_s300, testset[1], False, restrict_vocab=None)
question_seen_glove_s300_LxBR_irrest_cs = question_seen_in_model(glove_s300, testset[0], False, restrict_vocab=None)

# %%
print(' glove_s300_lxPT_ci %.2f' % (100 * float(question_seen_glove_s300_lxPT_irrest_ci['total']['q_seen']/question_seen_glove_s300_lxPT_irrest_ci['total']['q_no'])))
print(' glove_s300_lxBr_ci %.2f' % (100 * float(question_seen_glove_s300_LxBR_irrest_ci['total']['q_seen']/question_seen_glove_s300_LxBR_irrest_ci['total']['q_no'])))

print(' glove_s300_lxPT_cs %.2f' % (100 * float(question_seen_glove_s300_lxPT_irrest_cs['total']['q_seen']/question_seen_glove_s300_lxPT_irrest_cs['total']['q_no'])))
print(' glove_s300_lxBr_cs %.2f' % (100 * float(question_seen_glove_s300_LxBR_irrest_cs['total']['q_seen']/question_seen_glove_s300_LxBR_irrest_cs['total']['q_no'])))
# Out:
#  glove_s300_lxPT_ci 97.19
#  glove_s300_lxBr_ci 96.99
#  glove_s300_lxPT_cs 42.13
#  glove_s300_lxBr_cs 41.91

# %%
res = model.evaluate_word_analogies('../testsets/ownBR.txt')

# %% [markdown]
# ## Treinamento de próprio modelo

# %% [markdown]
# ### Setup do dataset

# %% [markdown]
# Dump do wiki

# %%
# !wget https://dumps.wikimedia.org/ptwiki/20190920/ptwiki-20190920-pages-articles-multistream.xml.bz2 -O ptwiki-20190920-pages-articles-multistream.xml.bz2
# Out:
# --2019-10-01 23:20:53--  https://dumps.wikimedia.org/ptwiki/20190920/ptwiki-20190920-pages-articles-multistream.xml.bz2
# Resolving dumps.wikimedia.org (dumps.wikimedia.org)... 208.80.154.7, 2620:0:861:1:208:80:154:7
# Connecting to dumps.wikimedia.org (dumps.wikimedia.org)|208.80.154.7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1767735669 (1,6G) [application/octet-stream]
# Saving to: ‘ptwiki-20190920-pages-articles-multistream.xml.bz2’
#
# ptwiki-20190920-pag 100%[===================>]   1,65G  1,37MB/s    in 15m 9s
#
# 2019-10-01 23:36:03 (1,86 MB/s) - ‘ptwiki-20190920-pages-articles-multistream.xml.bz2’ saved [1767735669/1767735669]

# %%
# !bzip2 -dk ptwiki-20190920-pages-articles-multistream.xml.bz2

# %%
# !ls
# Out:
#  fastText
#  ptWiki0920
#  ptwiki-20190920-pages-articles-multistream.xml
#  ptwiki-20190920-pages-articles-multistream.xml.bz2
# 'Testes de Analogias para bases.ipynb'

# %% [markdown]
# Limpeza do XML

# %%
# !perl fastText/wikifil.pl ptwiki-20190920-pages-articles-multistream.xml > ptWiki0920

# %%
# !head -c 120 ptWiki0920
# Out:
#  forma o estrelar na grande nuvem de magalh es uma gal xia irregular mosaico da nebulosa do caranguejo remanescente de u

# %%
# !grep -w "galáxia irregular" ptwiki-20190920-pages-articles-multistream.xml
# Out:
# [[Imagem:Starsinthesky.jpg|thumb|[[Estrela|Formação estrelar]] na [[Grande Nuvem de Magalhães]], uma [[galáxia irregular]].]]
# Algumas galáxias de menor porte orbitam a Via Láctea, sendo, portanto [[galáxia satélite|galáxias satélite]]. A mais próxima delas é a [[Galáxia Anã do Cão Maior]], situada a cerca de 42 mil anos-luz do centro galáctico, seguida pela [[Galáxia Anã Elíptica de Sagitário]]. A [[Grande Nuvem de Magalhães]] e a [[Pequena Nuvem de Magalhães]] são as maiores dentre as galáxias satélite da Via Láctea. Ambas são visíveis a olho nu no hemisfério sul celeste como manchas brilhantes, sendo que a Grande Nuvem de Magalhães é a galáxia mais brilhante vista da Terra depois da própria Via Láctea. Ambas são [[galáxia irregular|estruturas irregulares]] e apresentam regiões de intensa formação estelar. Uma corrente de gases existe ligando as nuvens de Magalhães entre si e também com a Via Láctea, sendo sugerido que teria origem na interação gravitacional entre as galáxias.&lt;ref&gt;{{Harvnb|Waller|2003|p=119-120}}&lt;/ref&gt;&lt;ref&gt;{{citar web|url=http://www.atlasoftheuniverse.com/sattelit.html|arquivourl=https://www.webcitation.org/6Mtk3uiOB?url=http://www.atlasoftheuniverse.com/sattelit.html|arquivodata=2014-01-25|título=The Universe within 500000 Light Years|autor=Atlas of the Universe|língua=Inglês|acessodata=25 de janeiro de 2014|urlmorta=no}}&lt;/ref&gt;&lt;ref&gt;{{citar web|url=http://apod.nasa.gov/apod/local_group.html|arquivourl=https://www.webcitation.org/6MtkTXfcp?url=http://apod.nasa.gov/apod/local_group.html|arquivodata=2014-01-25|título=Index - Galaxies: Local Group|autor=[[Astronomy Picture of the Day]]|publicado=[[NASA]]|língua=Inglês|acessodata=25 de janeiro de 2014|urlmorta=no}}&lt;/ref&gt;&lt;ref&gt;{{citar web|url=http://www.sai.msu.su/apod/ap100125.html|arquivourl=https://www.webcitation.org/6MtjprPEv?url=http://www.sai.msu.su/apod/ap100125.html|arquivodata=2014-01-25|título=The Magellanic Stream|autor=[[Astronomy Picture of the Day]]|publicado=[[NASA]]|língua=Inglês|data=25 de janeiro de 2010|acessodata=25 de janeiro de 2014|urlmorta=no}}&lt;/ref&gt;
# A constelação também contém a [[Galáxia Anã do Escultor]], uma [[galáxia anã]] que é membro do [[Grupo Local]] e também o [[Grupo do Escultor]], o grupo de galáxias mais próximo ao Grupo Local. A Galáxia do Escultor ([[NGC 253]]) é uma [[galáxia espiral barrada]] e a maior deste grupo, localizada na divisão entre Sculptor e [[Cetus]]. Outro membro proeminente deste grupo é a [[galáxia irregular]] [[NGC 55]].
# Somente se observam aglomerados abertos em [[galáxia espiral|galáxias espirais]] e [[galáxia irregular|irregulares]], devido a que nelas a [[formação estelar]] é mais ativa.
# Nas [[galáxia irregular|galáxias irregulares]], os aglomerados abertos podem ser encontrados em qualquer lugar, embora por regra geral, quanto maior é a densidade dos gases maior número de aglomerados costumam ser formados. Contudo, não há evidências de aglomerados abertos nas [[galáxia elíptica|galáxias elípticas]], pois a formação de estrelas ali finalizou muitos milhões de anos antes e, portanto, os aglomerados abertos que se puderam formar no passado tiveram tempo para se dispersarem.
# |            tipo = [[galáxia irregular]] (IBm)
# '''NGC 1569''' é uma [[galáxia irregular]] localizada a mais de sete milhões de [[anos-luz]] (2,14 [[megaparsec]]s) de distância na direção da [[constelação de Camelopardalis]]. Possui uma [[magnitude aparente]] de +11,2, uma declinação de +64° 50' 51&quot; e uma [[ascensão reta]] de 4 [[hora]]s, 30 [[minuto]]s e 49,2 [[segundo]]s. Esta galáxia sofre uma intensa atividade de [[formação estelar]] que teve seu auge há 25 milhões de anos.
# '''NGC 6822''' também conhecida como '''Galáxia de Barnard''' é uma [[galáxia irregular]] localizada a aproximadamente um milhão e oitocentos mil [[anos-luz]] de distância na direção da [[constelação de Sagitário]]. Trata-se de uma galáxia pequena, possui aproximadamente quinze mil anos-luz de [[diâmetro]], uma [[magnitude aparente]] de +9,3, uma declinação de -14° 48' 37&quot; e uma [[ascensão reta]] de 19 [[hora]]s, 44 [[minuto]]s e 56,3 [[segundo]]s.
# '''NGC 1705''' é uma [[galáxia irregular]] localizada a cerca de dezessete milhões [[anos-luz]] (aproximadamente 5,212 [[megaparsec]]s) de distância na direção da [[constelação do Pintor]]. Possui aproximadamente dois mil anos-luz de [[diâmetro]], uma [[magnitude aparente]] de 11,8, uma declinação de -53º 21' 40&quot; e uma [[ascensão reta]] de 04 [[hora]]s 54 [[minuto]]s 13,9 [[segundo]]s.
# '''NGC 5195''' ou '''M51 B''' é uma [[galáxia irregular]] cuja distância em relação à [[Terra]] está  entre quatorze e quarenta milhões de [[anos-luz]]. Esta galáxia fica na direção da [[constelação dos Cães de Caça]]. Possui uma [[magnitude aparente]] de 9,6, uma declinação de +47º 15' 59&quot; e uma [[ascensão reta]] de 13 [[hora]]s 29 [[minuto]]s 58,8 [[segundo]]s.
#       <text xml:space="preserve">[[Ficheiro:Local.group.arp.600pix.jpg|200px|thumb|Um membro do Grupo Local de galáxias, a galáxia irregular [[Sextans A]] está 4,3 milhões de anos-luz distante. As brilhantes estrelas em primeiro plano da Via Láctea aparecem amareladas nesta imagem. Atrás delas encontram-se as estrelas de Sextans A com jovens aglomerados de estrelas azuis claramente visíveis.]]
# '''Messier 82''' ([[New General Catalogue|NGC]] 3034) é uma [[galáxia irregular]] localizada a cerca de doze milhões de [[anos-luz]] (aproximadamente 3,679 [[megaparsec]]s) de distância na direção da [[constelação de Ursa Maior]]. Possui uma [[magnitude aparente]] de 8,6, uma declinação de +69º 40' 43&quot; e uma [[ascensão reta]] de 09 [[hora]]s, 55 [[minuto]]s e 50,7 [[segundo]]s.
# '''NGC 520''' é uma [[galáxia irregular]] localizada a cerca de cem milhões de [[anos-luz]] (aproximadamente 30,65 [[megaparsec]]s) de distância na direção da [[constelação de Peixes]]. Possui uma [[magnitude aparente]] de 11,3, uma declinação de +03º 47' 42&quot; e uma [[ascensão reta]] de 01 [[hora]]s, 24 [[minuto]]s e 34,3 [[segundo]]s.
# '''NGC 2968''' é uma [[galáxia irregular]] situada na direção da [[constelação de Leão]]. Possui uma [[magnitude aparente]] de 11,9, uma declinação de +31º 55' 44&quot; e uma [[ascensão reta]] de 09 [[hora]]s, 43 [[minuto]]s e 12,0s.
# A imagem final revelou uma panóplia de galáxias distantes, ténues. Conseguiu-se identificar cerca de 3000 galáxias, com galáxias [[galáxia irregular|irregulares]] e em [[galáxia em espiral|espiral]] nitidamente visíveis, embora algumas galáxias do campo estejam a escassos [[pixel]]s de distância umas das outras. Ao todo, o Campo Profundo do Hubble, também conhecido pela sigla HDF (do inglês ''The Hubble Deep Field'') parece revelar menos de 10 [[estrela]]s; a maioria dos objectos no campo são galáxias distantes.
# As regiões HII são apenas encontradas em [[galáxia espiral|galáxias espirais]] como a nossa e em [[galáxia irregular|galáxias irregulares]]. Nunca são encontradas em [[galáxia elíptica|galáxias elípticas]]. Em galáxias irregulares, podem ser encontradas por toda a galáxia, mas nas espirais elas são quase invariavelmente encontradas nos braços desta. Grandes galáxias espirais podem conter milhares de regiões HII.
# Alguns especulam que a Grande Nuvem de Magalhães já foi uma galáxia espiral barrada que rompeu da Via Láctea para tornar-se uma galáxia irregular. A Grande Nuvem de Magalhães é o quarto maior membro do [[Grupo Local]], precedida da [[Andrômeda (galáxia)|Andrômeda]], a [[Via Láctea]], e a [[NGC 598|galáxia do Triângulo]]&lt;ref&gt;&lt;span style=&quot;font-size: 12px; line-height: 17.265625px; background-color: rgb(221, 238, 255);&quot;&gt;Arny, Thomas T. (2000).&amp;nbsp;&lt;/span&gt;''Explorations: An Introduction to Astronomy''&lt;span style=&quot;font-size: 12px; line-height: 17.265625px; background-color: rgb(221, 238, 255);&quot;&gt;&amp;nbsp;(2nd ed.). Boston: McGraw-Hill.&lt;/span&gt;&lt;/ref&gt;.
# |            tipo = [[galáxia irregular]] (IBm)
# '''NGC 14''' é uma [[galáxia irregular]] localizada na direcção da [[constelação]] de [[Pegasus]]. Possui uma declinação de +15° 48' 57&quot; e uma [[ascensão recta]] de 0 [[hora]]s, 08 [[minuto]]s e 46,3 [[segundo]]s.
# A '''Pequena Nuvem de Magalhães''' ('''NGC 292'''), é uma [[galáxia anã]] próxima a [[Via Láctea]].&lt;ref name=&quot;apod&quot;&gt;{{cite APOD |date=2006-06-17 |title=The Small Cloud of Magellan |access-date=2008-07-07}}&lt;/ref&gt; Classificada como [[galáxia irregular]] anã, a PNM tem aproximadamente 7000 [[anos luz]] (diâmetro),&lt;ref name=&quot;britannica.com&quot;&gt;{{citar web|título=Magellanic Cloud |obra=[[Encyclopædia Britannica]] |ano=2009 |acessodata=2009-08-30 |url=http://www.britannica.com/EBchecked/topic/356551/Magellanic-Cloud}}&lt;/ref&gt; contém algumas centenas de milhões de estrelas,&lt;ref name=&quot;apod&quot;/&gt; e a massa de aproximadamente 7 bilhões de [[massa solar]]es.&lt;ref&gt;[http://adsabs.harvard.edu/abs/2009MNRAS.395..342B NASA ADS - The total mass and dark halo properties of the Small Magellanic Cloud]&lt;/ref&gt; A NGC 292 possui uma estrutura central com formato de “barra” e é especulado que um dia foi uma [[galáxia espiral barrada]] que foi desfeita pela Via Láctea e se tornou irregular.&lt;ref&gt;{{citar web|autor = |url=http://coolcosmos.ipac.caltech.edu//cosmic_classroom/multiwavelength_astronomy/multiwavelength_museum/smc.html |título=Small Magellanic Cloud |publicado=NASA/[[Infrared Processing and Analysis Center|IPAC]] |acessodata=2008-07-07}}&lt;/ref&gt; A uma distância de aproximadamente 200.000 [[anos luz]], a NGC 292 está entre os vizinhos intergalácticos mais próximos da Via Láctea e é um dos objetos mais distantes que podem ser visíveis a olho nu.
# * [[NGC 746]] - galáxia irregular em Andromeda
# * [[NGC 838]] - galáxia irregular em Cetus
# * [[NGC 853]] - galáxia irregular em Cetus
# * [[NGC 879]] - galáxia irregular em Cetus
# * [[NGC 899]] - galáxia irregular em Cetus
# * [[NGC 943]] - galáxia irregular em Cetus, par de [[NGC 942]]
# * [[NGC 1156]] - galáxia irregular em [[Aries]]
# * [[NGC 1569]] - [[galáxia irregular]] em Girafa
# * [[NGC 2552]] - galáxia irregular em Lynx
# * [[NGC 2968]] - [[galáxia irregular]] na constelação de [[Leo]], faz par com [[NGC 2964]]
# * [[NGC 3034]] - [[M82]], [[galáxia irregular]] também conhecida como [[Galáxia do Cigarro]], em Ursa Major
# * [[NGC 4214]] - [[galáxia irregular]] em [[Canes Venatici]]
# * [[NGC 4449]] - [[galáxia irregular]] em [[Canes Venatici]]
# * [[NGC 4945]] - [[galáxia espiral]] ou [[galáxia irregular|irregular]] em [[Centaurus]]
# * [[NGC 6822]] - [[Galáxia de Barnard]], uma [[galáxia irregular]] em Sagittarius
# * [[Andrômeda IV]] — galáxia irregular satélite da galáxia de Andrômeda
# Por causa de suas massas excessivas, elas têm um curto (em termos estelares) ciclo de vida, de somente 10 a 50 milhões de anos, e são observadas principalmente em estruturas cósmicas jovens tais como [[aglomerado aberto|aglomerados abertos]], os braços de [[galáxia espiral|galáxias espirais]] e em [[galáxia irregular|galáxias irregulares]]. Elas são menos abundantes no núcleo de galáxias espirais, e raramente são observadas em [[galáxia elíptica|galáxias elípticas]] ou [[aglomerado globular|aglomerados globulares]], a maioria dos quais supõe-se ser constituídos de estrelas velhas.
# '''Dwingeloo 2''' é uma pequena [[galáxia irregular]], localizada a aproximadamente 9.3 milhões de [[anos-luz]] de distância da [[Terra]]. Dwingeloo 2 orbita em torno de [[Dwingeloo 1]], assim como [[NGC 5195]] orbita em torno da [[Galáxia do Rodamoinho]] (M51).
# '''UGCA 86''' é uma [[galáxia irregular]] do [[Grupo IC 342/Maffei]].&lt;ref name=&quot;karachentsev2005&quot;&gt;{{citar periódico
# '''IC 10''' é uma pequena [[galáxia irregular]] na direção da [[constelação]] de [[Cassiopeia (constelação)|Cassiopeia]]. Possui uma [[declinação]] de +59° 18′ 14″ e uma [[ascensão reta]] de 00 [[hora]], 20 [[minutos]] e 17.3 [[segundos]]. IC 10 é uma galáxia do [[Grupo Local]].
# '''IC 1613''' é uma pequena [[galáxia irregular]] na direção da [[constelação]] de [[Cetus]], perto da [[estrela]] [[26 Ceti]]. Possui uma [[ascensão reta]] de 01 [[hora]], 04 [[minutos]] e 47.8 [[segundos]] e uma [[declinação]] de +02° 07′ 04″. IC 1613 é uma das [[galáxias]] do [[Grupo Local]].
# Outros possíveis membros ([[galáxias]] listadas em uma ou duas referências acima) incluem as [[galáxia irregular|galáxias irregulares]] [[NGC 5238]] e [[UGC 8508]].
# '''Holmberg IX''' é uma pequena [[galáxia irregular]] e [[galáxia satélite]] de [[M81]], na direção da [[constelação]] de [[Ursa Major]]. Possui uma [[ascensão reta]] de 09 [[horas]], 57 [[minutos]] e 32.1 [[segundos]] e uma [[declinação]] de +69° 02' 46&quot;.
# A [[galáxia irregular]] [[NGC 55]], a [[galáxia espiral]] [[NGC 300]] e suas companhias têm sido consideradas como membros deste grupo. Contudo, foram medidas recentemente as distâncias para estas galáxias na região do céu de NGC 55, NGC 300 e companheiras, demonstrando que estas não estão associadas fisicamente ao Grupo do Escultor.&lt;ref name=&quot;karachentsevetal2003&quot; /&gt;
# '''Andrômeda IV''' é uma pequena [[galáxia irregular]] [[galáxia satélite|satélite]] da [[Galáxia de Andrômeda]], mas provavelmente não é uma [[galáxia]], pode ser uma [[aglomerado estelar]] ou somente uma galáxia de fundo.
# A '''Galáxia Anã de Pisces''' é um pequena [[galáxia irregular]] e parte do [[Grupo Local]]. É a possível [[galáxia satélite]] da [[Galáxia do Triângulo]] (M33). Na direção da [[constelação]] de [[Pisces]], a [[galáxia]] é chamada de ''Pisces'' ou, para diferenciá-la de outros objetos astronômicos de nome similar, ''Anã de Pisces''. De acordo com os o deslocamento de suas linhas espectrais, calcula-se que esta galáxia esteja se aproximando da [[Via Láctea]] com uma velocidade de 287 [[km/s]]. Seu tipo morfológico está classificado alternativamente entre [[galáxia anã esferoidal|esferoidal anã]] e [[galáxia irregular anã|irregular anã]], e isto é muito raro, só há duas galáxias conhecidas desse tipo.
# '''Sextans B''' (UGC 5373, DDO 70) é uma [[galáxia irregular]] na direção da [[constelação]] de [[Sextans]] e parte do [[Grupo Local]]. Sextans B está a aproximadamente 4.44 milhões de [[anos-luz]], e um dos membros mais distantes do Grupo Local.
# '''GR 8''' (também conhecido como ''UGC 8091'' ou ''DDO 155'') é uma [[galáxia|galáxia anã]] [[galáxia irregular|irregular]] rica em gás.&lt;ref name=&quot;Tolstoy1999&quot;&gt;{{citar periódico
# A '''Galáxia Anã de Antlia''' é uma [[galáxia]] [[Galáxia anã esferoidal|anã esferoidal]]/[[galáxia irregular|irregular]]. Situa-se a cerca de 1,3&amp;nbsp;[[parsec|Mpc]] (4,3 [[ano-luz|Mal]]) da Terra na [[constelação]] de [[Antlia]]. Pertence ao [[grupo Antlia]] de galáxias. Contém estrelas de todas as idades, quantidades significativas de gás, e passou por formação estelar recente. Acredita-se que a Anã de Antlia esteja interagindo com a pequena [[galáxia espiral barrada]] [[NGC 3109]].&lt;ref name=vandenBerg1999/&gt;&lt;ref name=&quot;Grebel2003&quot;/&gt;
# '''Sextans A''' é uma [[galáxia|galáxia anã]] [[galáxia irregular|irregular]] a aproximadamente 4.3 milhões de [[anos-luz]] na direção da [[constelação]] de [[Sextans]]. Ela é um dos membros mais distantes do [[Grupo Local]] e tem uma forma peculiar de um quadrado. Em sua formação ocorreram muitas [[supernova]]s e o resultado é a sua forma.[http://apod.nasa.gov/apod/ap981103.html]
# A '''Galáxia Anã Irregular do Escultor''' (no inglês ''SDIG'') é uma pequena [[galáxia irregular]] na direção da [[constelação]] de [[Sculptor]]. A galáxia foi descoberta em 1976.
# O '''Grupo M74''' (também conhecido como o ''Grupo NGC 628'') é um pequeno [[grupo de galáxias]] na direção da [[constelação]] de [[Pisces]]. A [[galáxia espiral]] em visão frontal [[M74|M74 (NGC 628)]] é o membro mais brilhante dentro do grupo. Outros membros incluem a peculiar [[galáxia espiral]] [[NGC 660]] e outras pequenas [[galáxia irregular|galáxias irregulares]].&lt;ref name=&quot;nbg&quot; /&gt;&lt;ref name=&quot;garcia1993&quot; /&gt;&lt;ref name=&quot;giuricinetal2002&quot; /&gt;
# A '''Galáxia Anã Irregular de Sagitário''' ou '''SagDIG''' (do inglês ''Sagittarius Dwarf Irregular Galaxy'') é uma [[galáxia irregular]] que faz parte do [[Grupo Local]] e está a 3,4 milhões de [[anos-luz]] da [[Terra]]. É uma [[galáxia LSB]] (baixo [[brilho superficial]]).
# '''Leo A''' (também conhecida como '''Leo III''') é uma [[galáxia irregular]] na [[constelação]] de [[Leo]] e faz parte do [[Grupo Local]]. Ela fica a aproximadamente 2,25 milhões de [[anos-luz]] da [[Terra]].
# '''IC 5152''' é uma [[galáxia irregular]] a 5,8 milhões de [[anos-luz]] na [[constelação]] de [[Indus]]. Ela foi descoberta por [[DeLisle Stewart]] em [[1908]]. Há uma questão aberta se é ou não um membro do [[Grupo Local]].
# '''UGC 8331''' é uma [[galáxia irregular]] localizada na [[constelação]] de [[Canes Venatici]]. É um membro do grupo de galáxias [[Grupo M51|M51]] e mede aproximadamente 5 x 1,5 [[parsec|kiloparsecs]] (16.000 x 5.000 [[anos-luz]]).&lt;ref name=&quot;NED&quot; /&gt; A estrutura em larga escala da galáxia é muito desorganizada e tem dois aglomerados de estrelas, na sua parte exterior, em adição ao aglomerado no centro.&lt;ref name=&quot;2009a&quot;&gt;{{citar web|url=http://arxiv.org/PS_cache/arxiv/pdf/0901/0901.4222v1.pdf|título=The rotation curves shapes of late-type dwarf galaxies|autor =R.A. Swaters, R. Sancisi, T.S. van Albada, J.M. van der Hulst|data=2009-01-27|publicado=Astronomy and Astrophysics|acessodata=2009-03-08}}&lt;/ref&gt; Estes aglomerados tornam praticamente impossível determinar a curva de rotação da galáxia e contribui para uma grande variação na distância em que os valores são obtidos com diferentes métodos.&lt;ref name=&quot;NED&quot; /&gt;&lt;ref name=&quot;2009a&quot; /&gt; A distância exata até a galáxia não é conhecida, embora um papel de [[1998]] tem a distância estimada em 8,23 [[megaparsec]]s.&lt;ref name=&quot;1998a&quot; /&gt;
# Estes são objetos que parecem ser uma série de aglomerações irregulares sem estrutura coerente. Muitos desses objetos são simplesmente [[galáxia anã|galáxias anãs]] próximas. Alguns desses objetos são galáxias interagindo, enquanto outros são pequenos [[aglomerado de galáxias|grupos de galáxias]]. Em ambos os casos, muitos das galáxias constituintes são galáxias irregulares. A superposição de duas ou mais dessas galáxias irregulares podem facilmente parecer uma única galáxia irregular maior, é por isso que o '''Atlas of Peculiar Galaxies''' (e outros catálogos) muitas vezes classificam esses pares e grupos como simples objetos.
# [[Ficheiro:Hubble Interacting Galaxy NGC 5754 (2008-04-24).jpg|thumb|300px|Arp 297: Par de galáxias [[galáxia espiral|espiral]] ([[NGC 5754]]) /[[galáxia irregular|irregular]] ([[NGC 5752]]), imagem do [[Telescópio Espacial Hubble]]]]
# Galáxias anãs espirais, em especial as anãs do tipo [[Classificação de Hubble|Sa-Sc]], são bastante raras. Em contraste, [[galáxia anã elíptica|galáxias anãs elípticas]], [[galáxia irregular|galáxias anãs irregulares]], e as versões anãs das galáxias do tipo [[Classificação de Hubble|Sm]] (que pode ser considerada transitória entre espiral e irregular em termos de morfologia) são muito comuns.&lt;ref name=&quot;schombertetal1995&quot;/&gt;
#       <text xml:space="preserve">Uma '''galáxia irregular anã''' é um sistema estelar autogravitante que possui [[luminosidade]] menor ou da ordem de 10&lt;sup&gt;8&lt;/sup&gt; luminosidades solares e aparente ausência de estrutura ou uniformidade.
# * [[Holmberg IX]], uma pequena galáxia irregular e galáxia satélite de M81
# |            tipo = [[galáxia irregular|Irregular]] (Irr)
# '''IC 4716''' é uma [[galáxia irregular]] na direção da [[Pavo|constelação do Pavão]].
# |            tipo = [[galáxia irregular]]
# '''NGC 3690''' é uma [[galáxia irregular]] na direção da [[Ursa Major|constelação de Ursa Major]]. O objeto foi descoberto pelo astrônomo [[William Herschel]] em 1790, usando um [[telescópio]] refletor com abertura de 18,7 polegadas. Devido a sua moderada [[magnitude aparente]] (+11,6), é visível apenas com [[telescópio]]s amadores ou com equipamentos superiores.
#  |            tipo   = [[galáxia irregular]]
# '''NGC 7663''' é uma [[galáxia irregular]] na direção da [[Aquarius|constelação de Aquarius]]. O objeto foi descoberto pelo astrônomo [[Gaspare Ferrari]] em 1865, usando um [[telescópio]] refrator com abertura de 9,5 polegadas. Devido a sua moderada [[magnitude aparente]] (+14,5), é visível apenas com telescópios amadores ou com equipamentos superiores.

# %% [markdown]
# Alternatives to cleaning dump
#
# https://radimrehurek.com/gensim/corpora/wikicorpus.html

# %% [markdown]
# ## Treinamento

# %% [markdown]
# #### Modelo sem pre-processamento

# %%
model = fasttext.train_unsupervised('ptWiki0920')

# %%
model.save_model('../models/ptWiki0920-noPP.vec')

# %%
trainUnsupervisedTxt('ptWiki0920', '../models/ptWiki0920-noPP-skip-300'+'.bin', dimension=300)
# Out:
# 'Model ptWiki0920 saved(300 <fasttext.FastText._FastText object at 0x7f0bb7f949b0>) @ ../models/ptWiki0920-noPP-skip-300.bin'

# %% [markdown]
# #### Modelos com pre-processamento

# %%
ptStopwords = nltk.corpus.stopwords.words('portuguese')

def normalize(txtData) :
    return txtData.lower()

def rmStopWords(txtData) :
    tokens = nltk.word_tokenize(txtData)
    processedData = [ word for word in tokens if word not in ptStopwords]
    return " ".join(processedData)

# %%
with open('ptWiki0920', 'r') as file:
    with open('ptWiki0920-norm-stop', 'w') as outFile:
        for line in file:
            outFile.write(normalize(rmStopWords(line)))
# print (preProcessData[80:100])

# %%
trainUnsupervisedTxt('ptWiki0920-norm-stop', '../models/ptWiki0920-norm-stop-skip-100'+'.vec')

# %%
trainUnsupervisedTxt('ptWiki0920-norm-stop', '../models/ptWiki0920-norm-stop-skip-300'+'.bin', dimension=300)
# Out:
# 'Model ptWiki0920-norm-stop saved(300 <fasttext.FastText._FastText object at 0x7f0badf37518>) @ ../models/ptWiki0920-norm-stop-skip-300.bin'

# %% [markdown]
# \* ***aparentemente o script de decupagem do html normaliza o texto***

# %% [markdown]
# #### Modelo so com rm-Stopwords e ` dim 300`

# %%
with open('ptWiki0920', 'r') as file:
    with open('ptWiki0920-stop', 'w') as outFile:
        for line in file:
            outFile.write(rmStopWords(line))

# %%
trainUnsupervisedTxt('ptWiki0920-stop', '../models/ptWiki0920-stop-skip-300'+'.bin', dimension=300)

# %%
trainUnsupervisedTxt('ptWiki0920-stop', '../models/ptWiki0920-stop-skip-100'+'.bin', dimension=100)

# %% [markdown]
# ### Comparação do Vocabulário pre-processado x n-processado

# %%
most_frequent_noPP = noPP_skip_100['model'].index2entity[:100]

# %%
ptStopwords = nltk.corpus.stopwords.words('portuguese')

intersection_most_frequent = [word for word in most_frequent_noPP if word in ptStopwords]

# %%
print(intersection_most_frequent)
print(len(intersection_most_frequent))
# Out:
# ['de', 'o', 'a', 'e', 'do', 'em', 'da', 'que', 'um', 'com', 'no', 'uma', 'para', 'na', 'por', 'os', 'se', 'foi', 'como', 'as', 'dos', 'ao', 'mais', 'sua', 'ou', 'seu', 'das', 'pela', 'pelo', 'ele', 'mas', 'entre', 'nos', 'era', 'tem', 'foram', 'quando', 'seus', 'esta']
# 39

# %%
norm_stop_skip_100['model'].index2entity[:100]
# Out:
# ['one',
#  'zero',
#  'two',
#  'nine',
#  'three',
#  'eight',
#  'four',
#  'five',
#  'seven',
#  'six',
#  's',
#  'categoria',
#  'm',
#  'es',
#  'n',
#  'rio',
#  'h',
#  'f',
#  'ncia',
#  'utc',
#  'p',
#  'min',
#  'tamb',
#  'c',
#  't',
#  'the',
#  'ser',
#  'est',
#  'ria',
#  'd',
#  'pr',
#  'v',
#  'l',
#  'discuss',
#  'dia',
#  'id',
#  'j',
#  'rios',
#  'bgcolor',
#  'of',
#  'sobre',
#  'anos',
#  'liga',
#  'at',
#  'vel',
#  'lia',
#  'brasil',
#  'cidade',
#  'r',
#  'redirecionamento',
#  'hist',
#  'tica',
#  'in',
#  'g',
#  'rd',
#  'mar',
#  'dio',
#  'janeiro',
#  'ano',
#  'externas',
#  'pol',
#  'nome',
#  'grande',
#  'lan',
#  'ncias',
#  'onde',
#  'ver',
#  'b',
#  'cio',
#  'ap',
#  'pa',
#  'estados',
#  'estado',
#  'rea',
#  'regi',
#  'durante',
#  'primeiro',
#  'local',
#  'primeira',
#  'outros',
#  'pode',
#  'parte',
#  'al',
#  'ter',
#  'km',
#  'jogos',
#  'gols',
#  'sendo',
#  'rias',
#  'esp',
#  'unidos',
#  'q',
#  'lista',
#  'nia',
#  'i',
#  'dois',
#  'ainda',
#  'cada',
#  'morte',
#  'sul']

# %%
noPP_skip_100['model'].index2entity[:100]
# Out:
# ['de',
#  'o',
#  'one',
#  'zero',
#  'two',
#  'a',
#  'e',
#  'nine',
#  'do',
#  'em',
#  'three',
#  'da',
#  'eight',
#  'que',
#  'four',
#  'five',
#  'seven',
#  'six',
#  's',
#  'um',
#  'com',
#  'no',
#  'categoria',
#  'uma',
#  'para',
#  'm',
#  'na',
#  'es',
#  'por',
#  'os',
#  'se',
#  'n',
#  'foi',
#  'como',
#  'as',
#  'dos',
#  'rio',
#  'h',
#  'ao',
#  'mais',
#  'sua',
#  'f',
#  'ou',
#  'ncia',
#  'utc',
#  'p',
#  'seu',
#  'das',
#  'min',
#  'tamb',
#  'c',
#  't',
#  'the',
#  'ser',
#  'est',
#  'ria',
#  'pela',
#  'pelo',
#  'd',
#  'pr',
#  'ele',
#  'v',
#  'mas',
#  'l',
#  'discuss',
#  'entre',
#  'dia',
#  'id',
#  'j',
#  'rios',
#  'bgcolor',
#  'of',
#  'sobre',
#  'nos',
#  'anos',
#  'liga',
#  'at',
#  'vel',
#  'lia',
#  'era',
#  'brasil',
#  'cidade',
#  'r',
#  'tem',
#  'redirecionamento',
#  'hist',
#  'tica',
#  'in',
#  'g',
#  'rd',
#  'mar',
#  'dio',
#  'foram',
#  'janeiro',
#  'quando',
#  'ano',
#  'seus',
#  'externas',
#  'pol',
#  'esta']

# %%
pp_noPP_intersection = [pp_word for pp_word in norm_stop_skip_100['model'].index2entity[:100] if pp_word in most_frequent_noPP]

# %%
print('Intersection between Preprocessed model and not PP \n',pp_noPP_intersection)
print('Tamanho %d' % len(pp_noPP_intersection))
# Out:
# Intersection between Preprocessed model and not PP
#  ['one', 'zero', 'two', 'nine', 'three', 'eight', 'four', 'five', 'seven', 'six', 's', 'categoria', 'm', 'es', 'n', 'rio', 'h', 'f', 'ncia', 'utc', 'p', 'min', 'tamb', 'c', 't', 'the', 'ser', 'est', 'ria', 'd', 'pr', 'v', 'l', 'discuss', 'dia', 'id', 'j', 'rios', 'bgcolor', 'of', 'sobre', 'anos', 'liga', 'at', 'vel', 'lia', 'brasil', 'cidade', 'r', 'redirecionamento', 'hist', 'tica', 'in', 'g', 'rd', 'mar', 'dio', 'janeiro', 'ano', 'externas', 'pol']
# Tamanho 61

# %% [markdown]
# Das 100 palavras mais frequentes no modelo sem pre-processamento, 39 são stopwords.

# %%
noPP_skip_100['model']['Brasil']
# Out:
# array([-3.20488930e-01,  7.34150708e-02, -2.25654840e-01, -4.33122486e-01,
#         4.23747241e-01,  7.08579719e-02, -4.41147760e-02, -3.95013273e-01,
#        -3.51756483e-01, -1.84792265e-01, -8.73326540e-01, -1.38309136e-01,
#        -9.54652876e-02,  5.06048277e-02, -2.97635913e-01,  3.32867801e-01,
#         1.21611424e-01, -2.01417714e-01,  4.43238802e-02, -1.68290004e-01,
#         4.61084433e-02,  3.11402250e-02, -1.68521747e-01,  6.06458932e-02,
#         9.56166461e-02, -9.55177844e-02, -2.68204331e-01, -4.78912503e-01,
#        -1.84049681e-02,  1.75404176e-01,  3.42079312e-01,  3.66617888e-02,
#        -6.45369440e-02,  3.69723499e-01,  5.07388785e-02,  2.80019730e-01,
#        -3.74184877e-01,  2.48893976e-01, -3.05782165e-02, -1.05200201e-01,
#         2.54557043e-01, -4.61127758e-01,  6.94447905e-02, -1.82592208e-04,
#         8.04761276e-02, -1.84754059e-01,  8.09174478e-02,  1.36033118e-01,
#        -2.78557301e-01, -6.46118701e-01, -2.71684974e-01,  3.93784255e-01,
#         1.29571006e-01, -3.37331355e-01, -2.56009176e-02,  4.35716838e-01,
#         4.35055882e-01, -6.63862377e-02, -1.98848117e-02,  3.53612095e-01,
#        -1.44963488e-01, -2.08131477e-01,  4.08381894e-02,  7.38463551e-02,
#        -3.76916200e-01, -5.50078452e-01,  1.35509223e-01,  3.00208211e-01,
#         3.73443142e-02, -1.04416333e-01, -4.38505918e-01, -2.32029781e-01,
#        -2.03261245e-02,  2.09155828e-01, -1.19686751e-02,  8.56656879e-02,
#         7.97053799e-02,  1.25641510e-01, -1.18952341e-01, -4.80556674e-02,
#        -3.76188397e-01,  3.61791924e-02, -1.45321324e-01,  1.35249645e-01,
#        -3.53973433e-02,  1.54252183e-02, -2.30136126e-01,  4.71522771e-02,
#        -8.64439830e-02,  5.34305312e-02, -5.01223430e-02, -2.75975972e-01,
#        -2.03121081e-02, -1.10253841e-01, -4.44944017e-02,  8.73555169e-02,
#        -3.56524736e-01, -3.15930359e-02,  1.62358135e-01,  4.32433970e-02],
#       dtype=float32)

# %%
noPP_skip_100['model']['brasil']
# Out:
# array([-6.3858616e-01,  3.6946565e-02, -2.1032934e-01,  4.9100355e-03,
#         5.1675802e-01,  3.3930570e-01, -1.6995139e-01, -3.5193259e-01,
#        -7.5601719e-02, -1.1550857e-01, -4.3874732e-01, -1.7515351e-01,
#        -2.6592660e-01,  5.1678073e-02, -4.3907508e-01,  4.1048348e-01,
#        -1.2571995e-01, -5.4090235e-02, -2.4331547e-01,  7.4416143e-01,
#        -2.3910758e-01, -2.1536571e-01, -5.3951602e-02,  2.4117766e-01,
#         9.7411059e-02, -1.3098441e-01, -1.7464896e-01, -3.3646679e-01,
#        -1.7805803e-01,  2.1332951e-01,  6.3000315e-01,  3.4801105e-01,
#        -3.7784794e-01,  5.0278330e-01, -1.7716159e-01,  1.5232222e-01,
#        -4.4185031e-02,  1.4282545e-01, -4.3121364e-02, -1.9646448e-01,
#         7.0832327e-02, -2.0538923e-01,  1.6553715e-02,  1.2250408e-02,
#         2.8486386e-01,  5.7246373e-03,  2.7733743e-01,  3.9052942e-01,
#        -3.7644553e-01, -5.7954472e-01, -2.2947466e-01,  4.5308942e-04,
#        -5.2892751e-01, -2.0448387e-01,  1.3774104e-01,  4.1630098e-01,
#         2.0331378e-01,  2.2044471e-01, -1.4630806e-01, -3.9676219e-02,
#        -6.4463502e-01, -5.2897207e-02,  2.2090623e-01,  2.4036480e-01,
#         6.5443411e-02, -1.5253548e-01,  2.2539626e-01, -1.3332237e-01,
#        -2.1361504e-01, -3.2017344e-01, -4.0489444e-01, -1.4778845e-01,
#        -1.0690877e-02, -3.4652898e-01, -1.8402918e-01,  9.6651770e-02,
#         2.8944454e-01, -1.0600468e-01, -5.4171437e-01,  3.7555465e-01,
#        -1.3888562e-01,  2.4624802e-01,  7.3020607e-02, -9.2663392e-02,
#        -7.6641463e-02,  3.1603226e-01, -4.6992889e-01,  2.7854088e-01,
#        -1.7249870e-01, -2.2886948e-01,  6.0049083e-02, -2.3599996e-01,
#         2.9185307e-01, -1.4550889e-01, -1.4556451e-01,  3.1817073e-01,
#        -2.1854709e-01, -1.4382741e-01,  1.4011961e-01, -9.8477110e-02],
#       dtype=float32)

# %%
def question_seen_in_model(model, test, case_insensitive=True, restrict_vocab = 300000):
    ok_vocab = [w for w in model.index2word[:restrict_vocab]]
    if(case_insensitive):
        tmp_vocab = [w.lower() for w in ok_vocab]
        ok_vocab = tmp_vocab
    with open(test, 'r') as analogies:
        sections, section = {}, None
        qs_section, qt_section = 0, 0
        for line_no, line in enumerate(analogies):
            if ': ' in line:
                if section:
                    old_section = section
                    sections[old_section]['qs'] = qs_section
                    sections[old_section]['qt'] = qt_section
                    sections[old_section]['coverage'] = float(qs_section/qt_section)
                section = line
                sections[section] = {}
                qs_section = 0
                qt_section = 0
            else:
                if not section:
                    raise ValueError('missing entry header')
                else:
                    if case_insensitive:
                        a,b,c,d = [word.lower() for word in line.split()] 
                    else:
                        a,b,c,d = [word for word in line.split()]
                    if a in ok_vocab and b in ok_vocab and c in ok_vocab and d in ok_vocab:
                        qs_section += 1
                    qt_section += 1
        old_section = section
        sections[old_section]['qs'] = qs_section
        sections[old_section]['qt'] = qt_section
        sections[old_section]['coverage'] = float(qs_section/qt_section)
    
    total = {'q_no':0, 'q_seen': 0}
    for sec_key in sections:
        total['q_no'] += sections[sec_key]['qt']
        total['q_seen'] += sections[sec_key]['qs']
    
    return {'sections':sections, 'total':total}

# %%
question_seen_noPP_skip_100_lxPT_ci = question_seen_in_model(noPP_skip_100['model'], testset[1], True )
question_seen_noPP_skip_100_lxPT_cs = question_seen_in_model(noPP_skip_100['model'], testset[1], False )
question_seen_noPP_skip_100_LxBR_ci = question_seen_in_model(noPP_skip_100['model'], testset[0], True)
question_seen_noPP_skip_100_LxBR_cs = question_seen_in_model(noPP_skip_100['model'], testset[0], False)
# Out:
# 506
# 4524
# 866
# 2467
# 462
# 930
# 702
# 13
# 600
# 1056
# 1599
# 1560
# 1332
# 870
# 506
# 4524
# 866
# 2467
# 462
# 930
# 702
# 13
# 600
# 1056
# 1599
# 1560
# 1332
# 870
# 506
# 4524
# 866
# 2467
# 462
# 930
# 756
# 30
# 600
# 1056
# 1599
# 1560
# 1332
# 870
# 506
# 4524
# 866
# 2467
# 462
# 930
# 756
# 30
# 600
# 1056
# 1599
# 1560
# 1332
# 870

# %%
ok_vocab =

# %%
print(question_seen_noPP_skip_100_lxPT_ci['total'])
print(question_seen_noPP_skip_100_lxPT_cs['total'])
print(question_seen_noPP_skip_100_LxBR_ci['total'])
print(question_seen_noPP_skip_100_LxBR_cs['total'])
# Out:
# {'q_no': 17487, 'q_seen': 6125}
# {'q_no': 17487, 'q_seen': 6125}
# {'q_no': 17558, 'q_seen': 6227}
# {'q_no': 17558, 'q_seen': 6227}

# %% [markdown]
# ### Detalhes dos testset AnalogiesBr

# %%
sections = {}
with open(testset[0], 'r') as analogy_file:
    section = None
    qt_section = 0
    for line_no, line in enumerate(analogy_file):
        if(line_no <3):
            print(line: capital-common-countries

Atenas Grécia Bagdá Iraque

Atenas Grécia Bancoque Tailândia)
        if ': ' in line:
            if section:
                old_section = section
                sections[old_section] = qt_section
                qt_section = 0
            section = line
        else:
            qt_section += 1
    old_section = section
    sections[old_section] = qt_section
    qt_section = 0
print (sections)
# Out:
# : capital-common-countries
#
# Atenas Grécia Bagdá Iraque
#
# Atenas Grécia Bancoque Tailândia
#
# {': capital-common-countries\n': 506, ': capital-world\n': 4524, ': currency\n': 866, ': city-in-state\n': 2467, ': family\n': 462, ': gram1-adjective-to-adverb\n': 930, ': gram2-opposite\n': 756, ': gram3-comparative\n': 30, ': gram4-superlative\n': 600, ': gram5-present-participle\n': 1056, ': gram6-nationality-adjective\n': 1599, ': gram7-past-tense\n': 1560, ': gram8-plural\n': 1332, ': gram9-plural-verbs\n': 870}

# %%
si, se = 0,0
for key in sections:
    if 'gram' in key:
        si += sections[key]
    else:
        se += sections[key]
print ('SI %d - SE %d' % (si,  se))
# Out:
# SI 8733 - SE 8825

# %% [markdown]
# ### Detalhes do Testset AnalogiesPT

# %%
sections = {}
with open(testset[1], 'r') as analogy_file:
    section = None
    qt_section = 0
    for line_no, line in enumerate(analogy_file):
        if ': ' in line:
            if section:
                old_section = section
                sections[old_section] = qt_section
                qt_section = 0
            section = line
        else:
            qt_section += 1
    old_section = section
    sections[old_section] = qt_section
    qt_section = 0
print (testset[1])
print(sections)

si_pt, se_pt = 0,0
for key in sections:
    if 'gram' in key:
        si_pt += sections[key]
    else:
        se_pt += sections[key]
print ('SI %d - SE %d' % (si_pt,  se_pt))
# Out:
# ../testsets/LX-4WAnalogies.txt
# {': capital-common-countries\n': 506, ': capital-world\n': 4524, ': currency\n': 866, ': city-in-state\n': 2467, ': family\n': 462, ': gram1-adjective-to-adverb\n': 930, ': gram2-opposite\n': 702, ': gram3-comparative\n': 13, ': gram4-superlative\n': 600, ': gram5-present-participle\n': 1056, ': gram6-nationality-adjective\n': 1599, ': gram7-past-tense\n': 1560, ': gram8-plural\n': 1332, ': gram9-plural-verbs\n': 870}
# SI 8662 - SE 8825

# %% [markdown]
# ## Acuracia

# %% [markdown]
# ### Testes para modelo ptWiki0920-noPP

# %% [markdown]
# ../testsets/LX-4WAnalogiesBr.txt Total accuracy: 45.83 % Questions seen / total: 6227 17558 35.47 %
#
# ../testsets/LX-4WAnalogies.txt Total accuracy: 46.96 % Questions seen / total: 6125 17487 35.03 %

# %%
noPP_skip_100 = get_model_info('../models/ptWiki0920-noPP-skip-100.vec', testset, get_facebook_vecs_word_analogy_accuracy, True)

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-noPP-skip-100.vec ../testsets/LX-4WAnalogiesBr.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 92.86 %  (39 / 42)	  Total accuracy: 92.86 %   Semantic accuracy: 92.86 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 57.37 %  (389 / 678)	  Total accuracy: 59.44 %   Semantic accuracy: 59.44 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 55.15 %   Semantic accuracy: 55.15 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 15.37 %  (158 / 1028)	  Total accuracy: 32.48 %   Semantic accuracy: 32.48 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 68.18 %  (90 / 132)	  Total accuracy: 34.92 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 30.74 %  (142 / 462)	  Total accuracy: 34.11 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 30.74 %
#                 gram2-opposite: ACCURACY TOP1: 19.05 %  (40 / 210)	  Total accuracy: 32.90 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 27.08 %
#              gram3-comparative: ACCURACY TOP1: 26.67 %  (8 / 30)	  Total accuracy: 32.83 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 27.07 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 32.87 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 27.26 %
#       gram5-present-participle: ACCURACY TOP1: 59.78 %  (556 / 930)	  Total accuracy: 39.87 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 45.73 %
#    gram6-nationality-adjective: ACCURACY TOP1: 60.56 %  (43 / 71)	  Total accuracy: 40.27 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 46.34 %
#               gram7-past-tense: ACCURACY TOP1: 53.15 %  (708 / 1332)	  Total accuracy: 43.72 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 49.33 %
#                   gram8-plural: ACCURACY TOP1: 60.46 %  (393 / 650)	  Total accuracy: 45.65 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 51.29 %
#             gram9-plural-verbs: ACCURACY TOP1: 47.50 %  (285 / 600)	  Total accuracy: 45.83 %   Semantic accuracy: 34.92 %   Syntactic accuracy: 50.76 %
# Questions seen / total: 6227 17558   35.47 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-noPP-skip-100.vec ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 76.79 %  (43 / 56)	  Total accuracy: 76.79 %   Semantic accuracy: 76.79 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 56.85 %  (386 / 679)	  Total accuracy: 58.37 %   Semantic accuracy: 58.37 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 54.24 %   Semantic accuracy: 54.24 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 10.23 %  (90 / 880)	  Total accuracy: 31.06 %   Semantic accuracy: 31.06 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 63.46 %  (99 / 156)	  Total accuracy: 33.83 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 30.95 %  (143 / 462)	  Total accuracy: 33.25 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 30.95 %
#                 gram2-opposite: ACCURACY TOP1: 19.52 %  (41 / 210)	  Total accuracy: 32.09 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 27.38 %
#              gram3-comparative: ACCURACY TOP1: 30.77 %  (4 / 13)	  Total accuracy: 32.09 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 27.45 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 32.13 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 27.64 %
#       gram5-present-participle: ACCURACY TOP1: 59.78 %  (556 / 930)	  Total accuracy: 39.59 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 46.08 %
#    gram6-nationality-adjective: ACCURACY TOP1: 60.56 %  (43 / 71)	  Total accuracy: 40.01 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 46.69 %
#               gram7-past-tense: ACCURACY TOP1: 57.18 %  (804 / 1406)	  Total accuracy: 44.91 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 51.45 %
#                   gram8-plural: ACCURACY TOP1: 62.17 %  (373 / 600)	  Total accuracy: 46.79 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 53.19 %
#             gram9-plural-verbs: ACCURACY TOP1: 48.50 %  (291 / 600)	  Total accuracy: 46.96 %   Semantic accuracy: 33.83 %   Syntactic accuracy: 52.54 %
# Questions seen / total: 6125 17487   35.03 %

# %% [markdown]
# ### Testes para modelo '../models/ptWiki0920-noPP-skip-300'

# %%
noPP_skip_300 = get_model_info('../models/ptWiki0920-noPP-skip-300.bin', testset, get_facebook_vecs_word_analogy_accuracy, facebook_model=True)

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-noPP-skip-300.bin ../testsets/LX-4WAnalogiesBr.txt 300000
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-noPP-skip-300.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 100.00 %  (42 / 42)	  Total accuracy: 100.00 %   Semantic accuracy: 100.00 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 59.88 %  (406 / 678)	  Total accuracy: 62.22 %   Semantic accuracy: 62.22 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 57.73 %   Semantic accuracy: 57.73 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 25.58 %  (263 / 1028)	  Total accuracy: 39.41 %   Semantic accuracy: 39.41 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 68.94 %  (91 / 132)	  Total accuracy: 41.43 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 37.23 %  (172 / 462)	  Total accuracy: 40.62 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 37.23 %
#                 gram2-opposite: ACCURACY TOP1: 26.19 %  (55 / 210)	  Total accuracy: 39.46 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 33.78 %
#              gram3-comparative: ACCURACY TOP1: 36.67 %  (11 / 30)	  Total accuracy: 39.42 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 33.90 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 39.45 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 34.04 %
#       gram5-present-participle: ACCURACY TOP1: 69.78 %  (649 / 930)	  Total accuracy: 47.34 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 54.33 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 47.65 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 54.71 %
#               gram7-past-tense: ACCURACY TOP1: 59.98 %  (799 / 1332)	  Total accuracy: 50.95 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 57.02 %
#                   gram8-plural: ACCURACY TOP1: 80.00 %  (520 / 650)	  Total accuracy: 54.31 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 61.07 %
#             gram9-plural-verbs: ACCURACY TOP1: 55.83 %  (335 / 600)	  Total accuracy: 54.46 %   Semantic accuracy: 41.43 %   Syntactic accuracy: 60.34 %
# Questions seen / total: 6227 17558   35.47 %
#
#       capital-common-countries: ACCURACY TOP1: 94.64 %  (53 / 56)	  Total accuracy: 94.64 %   Semantic accuracy: 94.64 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 57.00 %  (387 / 679)	  Total accuracy: 59.86 %   Semantic accuracy: 59.86 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 55.63 %   Semantic accuracy: 55.63 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 20.34 %  (179 / 880)	  Total accuracy: 37.04 %   Semantic accuracy: 37.04 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 65.38 %  (102 / 156)	  Total accuracy: 39.46 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 37.23 %  (172 / 462)	  Total accuracy: 39.01 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 37.23 %
#                 gram2-opposite: ACCURACY TOP1: 29.52 %  (62 / 210)	  Total accuracy: 38.22 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 34.82 %
#              gram3-comparative: ACCURACY TOP1: 38.46 %  (5 / 13)	  Total accuracy: 38.22 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 34.89 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 38.24 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 35.02 %
#       gram5-present-participle: ACCURACY TOP1: 69.78 %  (649 / 930)	  Total accuracy: 46.75 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 54.97 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 47.09 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 55.32 %
#               gram7-past-tense: ACCURACY TOP1: 64.79 %  (911 / 1406)	  Total accuracy: 52.14 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 59.62 %
#                   gram8-plural: ACCURACY TOP1: 79.50 %  (477 / 600)	  Total accuracy: 55.11 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 62.84 %
#             gram9-plural-verbs: ACCURACY TOP1: 54.50 %  (327 / 600)	  Total accuracy: 55.05 %   Semantic accuracy: 39.46 %   Syntactic accuracy: 61.68 %
# Questions seen / total: 6125 17487   35.03 %

# %% [markdown]
# ### Testes para modelo ptWiki0920-norm-stop
#
# * Variação de Vocabulário 200000 X 300000

# %%
norm_stop_skip_100 = get_model_info('../models/ptWiki0920-norm-stop-skip-100.vec', testset, get_facebook_vecs_word_analogy_accuracy, facebook_model=True)

# %%
print(norm_stop_skip_100['model_ref'], norm_stop_skip_100['benchmark'][testset[0]]['log'])
print(norm_stop_skip_100['model_ref'], norm_stop_skip_100['benchmark'][testset[1]]['log'])
# Out:
# ../models/ptWiki0920-norm-stop-skip-100.vec ../testsets/LX-4WAnalogiesBr.txt 0.4525  | case insensitive
# ../models/ptWiki0920-norm-stop-skip-100.vec ../testsets/LX-4WAnalogies.txt 0.4560  | case insensitive

# %% [markdown]
# ../testsets/LX-4WAnalogiesBr.txt Total accuracy: 45.25 % Questions seen / total: 6113 17558   34.82 %
#
# ../testsets/LX-4WAnalogies.txt Total accuracy: 45.60 % Questions seen / total: 6005 17487   34.34 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-skip-100.vec ../testsets/LX-4WAnalogiesBr.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 90.48 %  (38 / 42)	  Total accuracy: 90.48 %   Semantic accuracy: 90.48 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 57.08 %  (387 / 678)	  Total accuracy: 59.03 %   Semantic accuracy: 59.03 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 1.79 %  (1 / 56)	  Total accuracy: 54.90 %   Semantic accuracy: 54.90 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 19.26 %  (198 / 1028)	  Total accuracy: 34.59 %   Semantic accuracy: 34.59 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 50.00 %  (45 / 90)	  Total accuracy: 35.32 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 28.35 %  (131 / 462)	  Total accuracy: 33.96 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 28.35 %
#                 gram2-opposite: ACCURACY TOP1: 19.52 %  (41 / 210)	  Total accuracy: 32.77 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 25.60 %
#              gram3-comparative: ACCURACY TOP1: 36.67 %  (11 / 30)	  Total accuracy: 32.82 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 26.07 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 32.86 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 26.27 %
#       gram5-present-participle: ACCURACY TOP1: 59.03 %  (549 / 930)	  Total accuracy: 39.75 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 44.87 %
#    gram6-nationality-adjective: ACCURACY TOP1: 64.79 %  (46 / 71)	  Total accuracy: 40.24 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 45.70 %
#               gram7-past-tense: ACCURACY TOP1: 51.11 %  (644 / 1260)	  Total accuracy: 43.06 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 48.00 %
#                   gram8-plural: ACCURACY TOP1: 62.00 %  (403 / 650)	  Total accuracy: 45.29 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 50.51 %
#             gram9-plural-verbs: ACCURACY TOP1: 44.83 %  (269 / 600)	  Total accuracy: 45.25 %   Semantic accuracy: 35.32 %   Syntactic accuracy: 49.70 %
# Questions seen / total: 6113 17558   34.82 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-skip-100.vec ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 76.79 %  (43 / 56)	  Total accuracy: 76.79 %   Semantic accuracy: 76.79 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 56.11 %  (381 / 679)	  Total accuracy: 57.69 %   Semantic accuracy: 57.69 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 1.79 %  (1 / 56)	  Total accuracy: 53.73 %   Semantic accuracy: 53.73 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 13.30 %  (117 / 880)	  Total accuracy: 32.44 %   Semantic accuracy: 32.44 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 45.45 %  (50 / 110)	  Total accuracy: 33.24 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 29.00 %  (134 / 462)	  Total accuracy: 32.37 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 29.00 %
#                 gram2-opposite: ACCURACY TOP1: 19.52 %  (41 / 210)	  Total accuracy: 31.27 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 26.04 %
#              gram3-comparative: ACCURACY TOP1: 38.46 %  (5 / 13)	  Total accuracy: 31.31 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 26.28 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 31.35 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 26.48 %
#       gram5-present-participle: ACCURACY TOP1: 59.03 %  (549 / 930)	  Total accuracy: 38.92 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 45.16 %
#    gram6-nationality-adjective: ACCURACY TOP1: 64.79 %  (46 / 71)	  Total accuracy: 39.45 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 45.98 %
#               gram7-past-tense: ACCURACY TOP1: 54.35 %  (724 / 1332)	  Total accuracy: 43.58 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 49.67 %
#                   gram8-plural: ACCURACY TOP1: 63.17 %  (379 / 600)	  Total accuracy: 45.75 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 51.90 %
#             gram9-plural-verbs: ACCURACY TOP1: 44.17 %  (265 / 600)	  Total accuracy: 45.60 %   Semantic accuracy: 33.24 %   Syntactic accuracy: 50.80 %
# Questions seen / total: 6005 17487   34.34 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-skip-100.vec ../testsets/LX-4WAnalogiesBr.txt 200000
# Out:
#       capital-common-countries: ACCURACY TOP1: 90.48 %  (38 / 42)	  Total accuracy: 90.48 %   Semantic accuracy: 90.48 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 58.65 %  (383 / 653)	  Total accuracy: 60.58 %   Semantic accuracy: 60.58 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 1.79 %  (1 / 56)	  Total accuracy: 56.19 %   Semantic accuracy: 56.19 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 19.84 %  (204 / 1028)	  Total accuracy: 35.19 %   Semantic accuracy: 35.19 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 52.22 %  (47 / 90)	  Total accuracy: 36.01 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 29.44 %  (136 / 462)	  Total accuracy: 34.71 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 29.44 %
#                 gram2-opposite: ACCURACY TOP1: 20.88 %  (38 / 182)	  Total accuracy: 33.70 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 27.02 %
#              gram3-comparative: ACCURACY TOP1: 36.67 %  (11 / 30)	  Total accuracy: 33.74 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 27.45 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 33.78 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 27.65 %
#       gram5-present-participle: ACCURACY TOP1: 64.53 %  (524 / 812)	  Total accuracy: 41.21 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 47.72 %
#    gram6-nationality-adjective: ACCURACY TOP1: 73.24 %  (52 / 71)	  Total accuracy: 41.87 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 48.88 %
#               gram7-past-tense: ACCURACY TOP1: 51.98 %  (655 / 1260)	  Total accuracy: 44.59 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 50.27 %
#                   gram8-plural: ACCURACY TOP1: 64.46 %  (419 / 650)	  Total accuracy: 47.00 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 52.92 %
#             gram9-plural-verbs: ACCURACY TOP1: 46.83 %  (281 / 600)	  Total accuracy: 46.99 %   Semantic accuracy: 36.01 %   Syntactic accuracy: 52.03 %
# Questions seen / total: 5942 17558   33.84 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-skip-100.vec ../testsets/LX-4WAnalogies.txt 200000
# Out:
#       capital-common-countries: ACCURACY TOP1: 76.79 %  (43 / 56)	  Total accuracy: 76.79 %   Semantic accuracy: 76.79 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 57.73 %  (377 / 653)	  Total accuracy: 59.24 %   Semantic accuracy: 59.24 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 1.79 %  (1 / 56)	  Total accuracy: 55.03 %   Semantic accuracy: 55.03 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 13.86 %  (122 / 880)	  Total accuracy: 33.01 %   Semantic accuracy: 33.01 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 47.27 %  (52 / 110)	  Total accuracy: 33.90 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 30.09 %  (139 / 462)	  Total accuracy: 33.11 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 30.09 %
#                 gram2-opposite: ACCURACY TOP1: 20.88 %  (38 / 182)	  Total accuracy: 32.18 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 27.48 %
#              gram3-comparative: ACCURACY TOP1: 38.46 %  (5 / 13)	  Total accuracy: 32.21 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 27.70 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 32.26 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 27.90 %
#       gram5-present-participle: ACCURACY TOP1: 64.53 %  (524 / 812)	  Total accuracy: 40.37 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 48.07 %
#    gram6-nationality-adjective: ACCURACY TOP1: 73.24 %  (52 / 71)	  Total accuracy: 41.08 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 49.22 %
#               gram7-past-tense: ACCURACY TOP1: 55.40 %  (698 / 1260)	  Total accuracy: 45.03 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 52.00 %
#                   gram8-plural: ACCURACY TOP1: 65.67 %  (394 / 600)	  Total accuracy: 47.43 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 54.40 %
#             gram9-plural-verbs: ACCURACY TOP1: 45.33 %  (272 / 600)	  Total accuracy: 47.21 %   Semantic accuracy: 33.90 %   Syntactic accuracy: 53.05 %
# Questions seen / total: 5761 17487   32.94 %

# %% [markdown]
# DIM 300

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-skip-300.bin ../testsets/LX-4WAnalogiesBr.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 97.62 %  (41 / 42)	  Total accuracy: 97.62 %   Semantic accuracy: 97.62 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 57.96 %  (393 / 678)	  Total accuracy: 60.28 %   Semantic accuracy: 60.28 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 55.93 %   Semantic accuracy: 55.93 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 26.75 %  (275 / 1028)	  Total accuracy: 39.30 %   Semantic accuracy: 39.30 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 60.00 %  (54 / 90)	  Total accuracy: 40.29 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 37.66 %  (174 / 462)	  Total accuracy: 39.77 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 37.66 %
#                 gram2-opposite: ACCURACY TOP1: 22.86 %  (48 / 210)	  Total accuracy: 38.39 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 33.04 %
#              gram3-comparative: ACCURACY TOP1: 36.67 %  (11 / 30)	  Total accuracy: 38.37 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 33.19 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 38.39 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 33.33 %
#       gram5-present-participle: ACCURACY TOP1: 69.89 %  (650 / 930)	  Total accuracy: 46.69 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 54.09 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 47.02 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 54.48 %
#               gram7-past-tense: ACCURACY TOP1: 62.62 %  (789 / 1260)	  Total accuracy: 51.06 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 57.93 %
#                   gram8-plural: ACCURACY TOP1: 80.31 %  (522 / 650)	  Total accuracy: 54.51 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 61.95 %
#             gram9-plural-verbs: ACCURACY TOP1: 54.17 %  (325 / 600)	  Total accuracy: 54.47 %   Semantic accuracy: 40.29 %   Syntactic accuracy: 60.84 %
# Questions seen / total: 6113 17558   34.82 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-skip-300.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 85.71 %  (48 / 56)	  Total accuracy: 85.71 %   Semantic accuracy: 85.71 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 56.85 %  (386 / 679)	  Total accuracy: 59.05 %   Semantic accuracy: 59.05 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 54.87 %   Semantic accuracy: 54.87 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 22.05 %  (194 / 880)	  Total accuracy: 37.58 %   Semantic accuracy: 37.58 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 57.27 %  (63 / 110)	  Total accuracy: 38.80 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 38.53 %  (178 / 462)	  Total accuracy: 38.74 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 38.53 %
#                 gram2-opposite: ACCURACY TOP1: 23.81 %  (50 / 210)	  Total accuracy: 37.46 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 33.93 %
#              gram3-comparative: ACCURACY TOP1: 38.46 %  (5 / 13)	  Total accuracy: 37.47 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 34.01 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 37.50 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 34.15 %
#       gram5-present-participle: ACCURACY TOP1: 69.89 %  (650 / 930)	  Total accuracy: 46.36 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 54.66 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 46.70 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 55.02 %
#               gram7-past-tense: ACCURACY TOP1: 66.97 %  (892 / 1332)	  Total accuracy: 52.32 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 60.28 %
#                   gram8-plural: ACCURACY TOP1: 79.33 %  (476 / 600)	  Total accuracy: 55.32 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 63.44 %
#             gram9-plural-verbs: ACCURACY TOP1: 52.33 %  (314 / 600)	  Total accuracy: 55.02 %   Semantic accuracy: 38.80 %   Syntactic accuracy: 61.86 %
# Questions seen / total: 6005 17487   34.34 %

# %%
# !ls ../models/
# Out:
# ext				 ptWiki0920-norm-stop-cbow-100.bin
# mock.txt			 ptWiki0920-norm-stop-cbow-300.bin
# oldModels			 ptWiki0920-norm-stop-skip-100.vec
# ptWiki0920300-noPP-cbow-300.bin  ptWiki0920-norm-stop-skip-300.bin
# ptWiki0920-noPP-cbow-100.bin	 ptWiki0920-stop-skip-100.bin
# ptWiki0920-noPP-skip-100.vec	 ptWiki0920-stop-skip-300.bin
# ptWiki0920-noPP-skip-300.bin

# %% [markdown]
# #### Testes para modelo ptWiki0920-stop

# %% [markdown]
# ../testsets/LX-4WAnalogiesBr.txt Total accuracy: 45.05 % Questions seen / total: 6113 17558   34.82 %
#
# ../testsets/LX-4WAnalogies.txt Total accuracy:  45.25 % Questions seen / total: 6005 17487   34.34 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-stop-skip-100.bin ../testsets/LX-4WAnalogiesBr.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 92.86 %  (39 / 42)	  Total accuracy: 92.86 %   Semantic accuracy: 92.86 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 57.67 %  (391 / 678)	  Total accuracy: 59.72 %   Semantic accuracy: 59.72 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 1.79 %  (1 / 56)	  Total accuracy: 55.54 %   Semantic accuracy: 55.54 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 18.09 %  (186 / 1028)	  Total accuracy: 34.20 %   Semantic accuracy: 34.20 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 48.89 %  (44 / 90)	  Total accuracy: 34.90 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 30.74 %  (142 / 462)	  Total accuracy: 34.08 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 30.74 %
#                 gram2-opposite: ACCURACY TOP1: 20.00 %  (42 / 210)	  Total accuracy: 32.93 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 27.38 %
#              gram3-comparative: ACCURACY TOP1: 36.67 %  (11 / 30)	  Total accuracy: 32.97 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 27.78 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 33.01 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 27.97 %
#       gram5-present-participle: ACCURACY TOP1: 58.17 %  (541 / 930)	  Total accuracy: 39.64 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 45.12 %
#    gram6-nationality-adjective: ACCURACY TOP1: 64.79 %  (46 / 71)	  Total accuracy: 40.13 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 45.93 %
#               gram7-past-tense: ACCURACY TOP1: 50.87 %  (641 / 1260)	  Total accuracy: 42.92 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 48.03 %
#                   gram8-plural: ACCURACY TOP1: 61.85 %  (402 / 650)	  Total accuracy: 45.15 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 50.51 %
#             gram9-plural-verbs: ACCURACY TOP1: 44.17 %  (265 / 600)	  Total accuracy: 45.05 %   Semantic accuracy: 34.90 %   Syntactic accuracy: 49.61 %
# Questions seen / total: 6113 17558   34.82 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-stop-skip-100.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 78.57 %  (44 / 56)	  Total accuracy: 78.57 %   Semantic accuracy: 78.57 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 55.23 %  (375 / 679)	  Total accuracy: 57.01 %   Semantic accuracy: 57.01 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 1.79 %  (1 / 56)	  Total accuracy: 53.10 %   Semantic accuracy: 53.10 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 13.41 %  (118 / 880)	  Total accuracy: 32.20 %   Semantic accuracy: 32.20 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 47.27 %  (52 / 110)	  Total accuracy: 33.13 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 30.95 %  (143 / 462)	  Total accuracy: 32.68 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 30.95 %
#                 gram2-opposite: ACCURACY TOP1: 19.52 %  (41 / 210)	  Total accuracy: 31.55 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 27.38 %
#              gram3-comparative: ACCURACY TOP1: 38.46 %  (5 / 13)	  Total accuracy: 31.59 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 27.59 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 31.63 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 27.79 %
#       gram5-present-participle: ACCURACY TOP1: 58.17 %  (541 / 930)	  Total accuracy: 38.89 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 45.22 %
#    gram6-nationality-adjective: ACCURACY TOP1: 64.79 %  (46 / 71)	  Total accuracy: 39.42 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 46.04 %
#               gram7-past-tense: ACCURACY TOP1: 53.53 %  (713 / 1332)	  Total accuracy: 43.33 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 49.34 %
#                   gram8-plural: ACCURACY TOP1: 63.00 %  (378 / 600)	  Total accuracy: 45.51 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 51.60 %
#             gram9-plural-verbs: ACCURACY TOP1: 42.83 %  (257 / 600)	  Total accuracy: 45.25 %   Semantic accuracy: 33.13 %   Syntactic accuracy: 50.36 %
# Questions seen / total: 6005 17487   34.34 %

# %% [markdown]
# #### Testes para modelo ptWiki0920-stop300

# %% [markdown]
# ../testsets/LX-4WAnalogiesBr.txt Total accuracy: 54.87 % Questions seen / total: 6113 17558   34.82 %
#
# ../testsets/LX-4WAnalogies.txt Total accuracy: 55.22 % Questions seen / total: 6005 17487   34.34 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-stop-skip-300.bin ../testsets/LX-4WAnalogiesBr.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 97.62 %  (41 / 42)	  Total accuracy: 97.62 %   Semantic accuracy: 97.62 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 59.73 %  (405 / 678)	  Total accuracy: 61.94 %   Semantic accuracy: 61.94 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 57.47 %   Semantic accuracy: 57.47 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 27.33 %  (281 / 1028)	  Total accuracy: 40.30 %   Semantic accuracy: 40.30 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 61.11 %  (55 / 90)	  Total accuracy: 41.29 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 38.53 %  (178 / 462)	  Total accuracy: 40.75 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 38.53 %
#                 gram2-opposite: ACCURACY TOP1: 23.33 %  (49 / 210)	  Total accuracy: 39.32 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 33.78 %
#              gram3-comparative: ACCURACY TOP1: 36.67 %  (11 / 30)	  Total accuracy: 39.29 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 33.90 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 39.32 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 34.04 %
#       gram5-present-participle: ACCURACY TOP1: 67.20 %  (625 / 930)	  Total accuracy: 46.66 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 52.87 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 46.99 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 53.31 %
#               gram7-past-tense: ACCURACY TOP1: 63.65 %  (802 / 1260)	  Total accuracy: 51.31 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 57.70 %
#                   gram8-plural: ACCURACY TOP1: 81.54 %  (530 / 650)	  Total accuracy: 54.87 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 61.98 %
#             gram9-plural-verbs: ACCURACY TOP1: 54.83 %  (329 / 600)	  Total accuracy: 54.87 %   Semantic accuracy: 41.29 %   Syntactic accuracy: 60.96 %
# Questions seen / total: 6113 17558   34.82 %

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-stop-skip-300.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 85.71 %  (48 / 56)	  Total accuracy: 85.71 %   Semantic accuracy: 85.71 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 56.41 %  (383 / 679)	  Total accuracy: 58.64 %   Semantic accuracy: 58.64 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 54.49 %   Semantic accuracy: 54.49 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 21.82 %  (192 / 880)	  Total accuracy: 37.28 %   Semantic accuracy: 37.28 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 58.18 %  (64 / 110)	  Total accuracy: 38.57 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 38.96 %  (180 / 462)	  Total accuracy: 38.65 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 38.96 %
#                 gram2-opposite: ACCURACY TOP1: 25.71 %  (54 / 210)	  Total accuracy: 37.55 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 34.82 %
#              gram3-comparative: ACCURACY TOP1: 38.46 %  (5 / 13)	  Total accuracy: 37.55 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 34.89 %
#              gram4-superlative: ACCURACY TOP1: 50.00 %  (3 / 6)	  Total accuracy: 37.58 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 35.02 %
#       gram5-present-participle: ACCURACY TOP1: 67.20 %  (625 / 930)	  Total accuracy: 45.68 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 53.49 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 46.04 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 53.90 %
#               gram7-past-tense: ACCURACY TOP1: 68.24 %  (909 / 1332)	  Total accuracy: 52.20 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 60.22 %
#                   gram8-plural: ACCURACY TOP1: 80.83 %  (485 / 600)	  Total accuracy: 55.37 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 63.63 %
#             gram9-plural-verbs: ACCURACY TOP1: 53.83 %  (323 / 600)	  Total accuracy: 55.22 %   Semantic accuracy: 38.57 %   Syntactic accuracy: 62.24 %
# Questions seen / total: 6005 17487   34.34 %

# %% [markdown]
# ## Treinamento de Modelo com CBOW

# %%
print('Referencia de corpus')
# !ls
# Out:
# Referencia de corpus
#  fastText	        ptwiki-20190920-pages-articles-multistream.xml
#  ptWiki0920	        ptwiki-20190920-pages-articles-multistream.xml.bz2
#  ptWiki0920-norm-stop  'Testes de Analogias para bases-Copy1.ipynb'
#  ptWiki0920-stop       'Testes de Analogias para bases.ipynb'

# %%
testset = glob('../testsets/LX-4WAnalogies*')

# %% [markdown]
# ### Modelo treinado sem PP, Cbow, dimensao 100

# %%
trainUnsupervisedTxt('ptWiki0920', '../models/ptWiki0920-noPP-cbow-100.bin', model="cbow", dimension=100)

# %%
noPP_cbow_100 = get_model_info('../models/ptWiki0920-noPP-cbow-100.bin', testset, get_facebook_vecs_word_analogy_accuracy, facebook_model=True)

# %%
print(noPP_cbow_100['model_ref'], noPP_cbow_100['benchmark'][testset[0]]['log'])
print(noPP_cbow_100['model_ref'], noPP_cbow_100['benchmark'][testset[1]]['log'] )
# Out:
# ../models/ptWiki0920-noPP-cbow-100.bin ../testsets/LX-4WAnalogiesBr.txt 0.4659  | case insensitive
# ../models/ptWiki0920-noPP-cbow-100.bin ../testsets/LX-4WAnalogies.txt 0.4963  | case insensitive

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-noPP-cbow-100.bin ../testsets/LX-4WAnalogiesBr.txt 300000
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-noPP-cbow-100.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 78.57 %  (33 / 42)	  Total accuracy: 78.57 %   Semantic accuracy: 78.57 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 21.24 %  (144 / 678)	  Total accuracy: 24.58 %   Semantic accuracy: 24.58 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 22.81 %   Semantic accuracy: 22.81 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 9.82 %  (101 / 1028)	  Total accuracy: 15.41 %   Semantic accuracy: 15.41 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 68.94 %  (91 / 132)	  Total accuracy: 19.06 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 51.30 %  (237 / 462)	  Total accuracy: 25.27 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 51.30 %
#                 gram2-opposite: ACCURACY TOP1: 33.33 %  (70 / 210)	  Total accuracy: 25.92 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 45.68 %
#              gram3-comparative: ACCURACY TOP1: 33.33 %  (10 / 30)	  Total accuracy: 26.00 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 45.16 %
#              gram4-superlative: ACCURACY TOP1: 33.33 %  (2 / 6)	  Total accuracy: 26.02 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 45.06 %
#       gram5-present-participle: ACCURACY TOP1: 73.44 %  (683 / 930)	  Total accuracy: 38.36 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 61.17 %
#    gram6-nationality-adjective: ACCURACY TOP1: 60.56 %  (43 / 71)	  Total accuracy: 38.79 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 61.15 %
#               gram7-past-tense: ACCURACY TOP1: 64.79 %  (863 / 1332)	  Total accuracy: 45.75 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 62.74 %
#                   gram8-plural: ACCURACY TOP1: 46.46 %  (302 / 650)	  Total accuracy: 45.83 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 59.88 %
#             gram9-plural-verbs: ACCURACY TOP1: 53.67 %  (322 / 600)	  Total accuracy: 46.59 %   Semantic accuracy: 19.06 %   Syntactic accuracy: 59.01 %
# Questions seen / total: 6227 17558   35.47 %
#
#       capital-common-countries: ACCURACY TOP1: 66.07 %  (37 / 56)	  Total accuracy: 66.07 %   Semantic accuracy: 66.07 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 20.32 %  (138 / 679)	  Total accuracy: 23.81 %   Semantic accuracy: 23.81 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 22.12 %   Semantic accuracy: 22.12 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 9.43 %  (83 / 880)	  Total accuracy: 15.44 %   Semantic accuracy: 15.44 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 62.18 %  (97 / 156)	  Total accuracy: 19.43 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 51.08 %  (236 / 462)	  Total accuracy: 25.82 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 51.08 %
#                 gram2-opposite: ACCURACY TOP1: 38.10 %  (80 / 210)	  Total accuracy: 26.85 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 47.02 %
#              gram3-comparative: ACCURACY TOP1: 30.77 %  (4 / 13)	  Total accuracy: 26.87 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 46.72 %
#              gram4-superlative: ACCURACY TOP1: 33.33 %  (2 / 6)	  Total accuracy: 26.89 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 46.60 %
#       gram5-present-participle: ACCURACY TOP1: 73.44 %  (683 / 930)	  Total accuracy: 39.44 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 62.00 %
#    gram6-nationality-adjective: ACCURACY TOP1: 60.56 %  (43 / 71)	  Total accuracy: 39.87 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 61.94 %
#               gram7-past-tense: ACCURACY TOP1: 67.57 %  (950 / 1406)	  Total accuracy: 47.78 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 64.49 %
#                   gram8-plural: ACCURACY TOP1: 48.83 %  (293 / 600)	  Total accuracy: 47.89 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 61.95 %
#             gram9-plural-verbs: ACCURACY TOP1: 65.67 %  (394 / 600)	  Total accuracy: 49.63 %   Semantic accuracy: 19.43 %   Syntactic accuracy: 62.47 %
# Questions seen / total: 6125 17487   35.03 %

# %% [markdown]
# #### Resumo
# ../models/ptWiki0920-noPP-cbow-100.bin ../testsets/LX-4WAnalogiesBr.txt 0.4659  Semantic accuracy: 19.06 %   Syntactic accuracy: 59.01 %
# ../models/ptWiki0920-noPP-cbow-100.bin ../testsets/LX-4WAnalogies.txt 0.4963  Semantic accuracy: 19.43 %   Syntactic accuracy: 62.47 %

# %% [markdown]
# ### Modelo treinado Remoção de Stopwords e normalização, Cbow, dimensao 100

# %%
trainUnsupervisedTxt('ptWiki0920-norm-stop', '../models/ptWiki0920-norm-stop-cbow-100.bin', model="cbow", dimension=100)

# %%
cbow_norm_stop_cbow_100 = get_model_info('../models/ptWiki0920-norm-stop-cbow-100.bin', testset, get_facebook_vecs_word_analogy_accuracy, facebook_model=True)

# %%
print(cbow_norm_stop_cbow_100['model_ref'], cbow_norm_stop_cbow_100['benchmark'][testset[0]]['log'] )
print(cbow_norm_stop_cbow_100['model_ref'], cbow_norm_stop_cbow_100['benchmark'][testset[1]]['log'])
# Out:
# ../models/ptWiki0920-norm-stop-cbow-100.bin ../testsets/LX-4WAnalogiesBr.txt 0.5061  | case insensitive
# ../models/ptWiki0920-norm-stop-cbow-100.bin ../testsets/LX-4WAnalogies.txt 0.5347  | case insensitive

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-cbow-100.bin ../testsets/LX-4WAnalogiesBr.txt 300000
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-cbow-100.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 83.33 %  (35 / 42)	  Total accuracy: 83.33 %   Semantic accuracy: 83.33 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 26.40 %  (179 / 678)	  Total accuracy: 29.72 %   Semantic accuracy: 29.72 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 27.58 %   Semantic accuracy: 27.58 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 11.96 %  (123 / 1028)	  Total accuracy: 18.68 %   Semantic accuracy: 18.68 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 56.67 %  (51 / 90)	  Total accuracy: 20.49 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 54.11 %  (250 / 462)	  Total accuracy: 27.08 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 54.11 %
#                 gram2-opposite: ACCURACY TOP1: 32.38 %  (68 / 210)	  Total accuracy: 27.51 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 47.32 %
#              gram3-comparative: ACCURACY TOP1: 30.00 %  (9 / 30)	  Total accuracy: 27.54 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 46.58 %
#              gram4-superlative: ACCURACY TOP1: 16.67 %  (1 / 6)	  Total accuracy: 27.52 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 46.33 %
#       gram5-present-participle: ACCURACY TOP1: 73.98 %  (688 / 930)	  Total accuracy: 39.75 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 62.03 %
#    gram6-nationality-adjective: ACCURACY TOP1: 60.56 %  (43 / 71)	  Total accuracy: 40.16 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 61.97 %
#               gram7-past-tense: ACCURACY TOP1: 69.37 %  (874 / 1260)	  Total accuracy: 47.73 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 65.11 %
#                   gram8-plural: ACCURACY TOP1: 68.00 %  (442 / 650)	  Total accuracy: 50.12 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 65.63 %
#             gram9-plural-verbs: ACCURACY TOP1: 55.17 %  (331 / 600)	  Total accuracy: 50.61 %   Semantic accuracy: 20.49 %   Syntactic accuracy: 64.14 %
# Questions seen / total: 6113 17558   34.82 %
#
#       capital-common-countries: ACCURACY TOP1: 69.64 %  (39 / 56)	  Total accuracy: 69.64 %   Semantic accuracy: 69.64 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 25.77 %  (175 / 679)	  Total accuracy: 29.12 %   Semantic accuracy: 29.12 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 27.05 %   Semantic accuracy: 27.05 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 9.89 %  (87 / 880)	  Total accuracy: 18.01 %   Semantic accuracy: 18.01 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 49.09 %  (54 / 110)	  Total accuracy: 19.93 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 54.76 %  (253 / 462)	  Total accuracy: 27.11 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 54.76 %
#                 gram2-opposite: ACCURACY TOP1: 35.71 %  (75 / 210)	  Total accuracy: 27.84 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 48.81 %
#              gram3-comparative: ACCURACY TOP1: 23.08 %  (3 / 13)	  Total accuracy: 27.82 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 48.32 %
#              gram4-superlative: ACCURACY TOP1: 16.67 %  (1 / 6)	  Total accuracy: 27.79 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 48.05 %
#       gram5-present-participle: ACCURACY TOP1: 73.98 %  (688 / 930)	  Total accuracy: 40.42 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 62.92 %
#    gram6-nationality-adjective: ACCURACY TOP1: 60.56 %  (43 / 71)	  Total accuracy: 40.83 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 62.83 %
#               gram7-past-tense: ACCURACY TOP1: 72.60 %  (967 / 1332)	  Total accuracy: 49.64 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 67.13 %
#                   gram8-plural: ACCURACY TOP1: 70.33 %  (422 / 600)	  Total accuracy: 51.93 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 67.66 %
#             gram9-plural-verbs: ACCURACY TOP1: 67.33 %  (404 / 600)	  Total accuracy: 53.47 %   Semantic accuracy: 19.93 %   Syntactic accuracy: 67.61 %
# Questions seen / total: 6005 17487   34.34 %

# %% [markdown]
# #### Resumo
# ../models/ptWiki0920-norm-stop-cbow-100.bin ../testsets/LX-4WAnalogiesBr.txt 0.5061 Semantic accuracy: 20.49 %   Syntactic accuracy: 64.14 %
#
# ../models/ptWiki0920-norm-stop-cbow-100.bin ../testsets/LX-4WAnalogies.txt 0.5347 Semantic accuracy: 19.93 %   Syntactic accuracy: 67.61 %

# %% [markdown]
# ### Modelo treinado sem pre-processamento, CBOW, Dimensao 300

# %%
trainUnsupervisedTxt('ptWiki0920', '../models/ptWiki0920300-noPP-cbow-300'+'.bin', model="cbow", dimension=300)

# %%
noPP_cbow_300 = get_model_info('../models/ptWiki0920300-noPP-cbow-300.bin', testset, get_facebook_vecs_word_analogy_accuracy, facebook_model=True)

# %%
print(noPP_cbow_300['model_ref'],' @ ', noPP_cbow_300['benchmark'][testset[0]]['log'])
print(noPP_cbow_300['model_ref'],' @ ', noPP_cbow_300['benchmark'][testset[1]]['log'])
# Out:
# ../models/ptWiki0920300-noPP-cbow-300.bin  @  ../testsets/LX-4WAnalogiesBr.txt 0.5202  | case insensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin  @  ../testsets/LX-4WAnalogies.txt 0.5549  | case insensitive

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920300-noPP-cbow-300.bin ../testsets/LX-4WAnalogiesBr.txt 300000
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920300-noPP-cbow-300.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 76.19 %  (32 / 42)	  Total accuracy: 76.19 %   Semantic accuracy: 76.19 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 20.50 %  (139 / 678)	  Total accuracy: 23.75 %   Semantic accuracy: 23.75 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 22.04 %   Semantic accuracy: 22.04 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 5.93 %  (61 / 1028)	  Total accuracy: 12.86 %   Semantic accuracy: 12.86 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 66.67 %  (88 / 132)	  Total accuracy: 16.53 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 64.07 %  (296 / 462)	  Total accuracy: 25.69 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 64.07 %
#                 gram2-opposite: ACCURACY TOP1: 41.43 %  (87 / 210)	  Total accuracy: 26.96 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 56.99 %
#              gram3-comparative: ACCURACY TOP1: 60.00 %  (18 / 30)	  Total accuracy: 27.33 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 57.12 %
#              gram4-superlative: ACCURACY TOP1: 83.33 %  (5 / 6)	  Total accuracy: 27.46 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 57.34 %
#       gram5-present-participle: ACCURACY TOP1: 81.08 %  (754 / 930)	  Total accuracy: 41.41 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 70.82 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 41.84 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 70.51 %
#               gram7-past-tense: ACCURACY TOP1: 72.37 %  (964 / 1332)	  Total accuracy: 50.01 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 71.33 %
#                   gram8-plural: ACCURACY TOP1: 62.62 %  (407 / 650)	  Total accuracy: 51.47 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 69.79 %
#             gram9-plural-verbs: ACCURACY TOP1: 57.17 %  (343 / 600)	  Total accuracy: 52.02 %   Semantic accuracy: 16.53 %   Syntactic accuracy: 68.03 %
# Questions seen / total: 6227 17558   35.47 %
#
#       capital-common-countries: ACCURACY TOP1: 64.29 %  (36 / 56)	  Total accuracy: 64.29 %   Semantic accuracy: 64.29 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 19.29 %  (131 / 679)	  Total accuracy: 22.72 %   Semantic accuracy: 22.72 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 21.11 %   Semantic accuracy: 21.11 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 6.14 %  (54 / 880)	  Total accuracy: 13.23 %   Semantic accuracy: 13.23 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 61.54 %  (96 / 156)	  Total accuracy: 17.35 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 65.80 %  (304 / 462)	  Total accuracy: 27.13 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 65.80 %
#                 gram2-opposite: ACCURACY TOP1: 49.05 %  (103 / 210)	  Total accuracy: 28.97 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 60.57 %
#              gram3-comparative: ACCURACY TOP1: 61.54 %  (8 / 13)	  Total accuracy: 29.14 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 60.58 %
#              gram4-superlative: ACCURACY TOP1: 83.33 %  (5 / 6)	  Total accuracy: 29.27 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 60.78 %
#       gram5-present-participle: ACCURACY TOP1: 81.08 %  (754 / 930)	  Total accuracy: 43.24 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 72.42 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 43.65 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 72.04 %
#               gram7-past-tense: ACCURACY TOP1: 75.96 %  (1068 / 1406)	  Total accuracy: 52.87 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 73.82 %
#                   gram8-plural: ACCURACY TOP1: 63.33 %  (380 / 600)	  Total accuracy: 54.01 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 72.12 %
#             gram9-plural-verbs: ACCURACY TOP1: 69.17 %  (415 / 600)	  Total accuracy: 55.49 %   Semantic accuracy: 17.35 %   Syntactic accuracy: 71.71 %
# Questions seen / total: 6125 17487   35.03 %

# %% [markdown]
# #### Resumo
# ../models/ptWiki0920300-noPP-cbow-300.bin  @  ../testsets/LX-4WAnalogiesBr.txt 0.5202 Semantic accuracy: 16.53 %   Syntactic accuracy: 68.03 %
#
# ../models/ptWiki0920300-noPP-cbow-300.bin  @  ../testsets/LX-4WAnalogies.txt 0.5549  Semantic accuracy: 17.35 %   Syntactic accuracy: 71.71 %

# %% [markdown]
# ### Modelo treinado com remoção de stopwords e normalização, CBOW, dimensão 300**

# %%
trainUnsupervisedTxt('ptWiki0920-norm-stop', '../models/ptWiki0920-norm-stop-300'+'.bin', model="cbow", dimension=300)

# %%
norm_stop_300 = get_model_info('../models/ptWiki0920-norm-stop-cbow-300.bin', testset, get_facebook_vecs_word_analogy_accuracy, facebook_model=True)

# %%
print(norm_stop_300['model_ref'], norm_stop_300['benchmark'][testset[0]]['log'])
print(norm_stop_300['model_ref'], norm_stop_300['benchmark'][testset[1]]['log'])
# Out:
# ../models/ptWiki0920-norm-stop-cbow-300.bin ../testsets/LX-4WAnalogiesBr.txt 0.5405  | case insensitive
# ../models/ptWiki0920-norm-stop-cbow-300.bin ../testsets/LX-4WAnalogies.txt 0.5749  | case insensitive

# %%
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-cbow-300.bin ../testsets/LX-4WAnalogiesBr.txt 300000
! python fastText/python/doc/examples/compute_accuracy.py ../models/ptWiki0920-norm-stop-cbow-300.bin ../testsets/LX-4WAnalogies.txt 300000
# Out:
#       capital-common-countries: ACCURACY TOP1: 80.95 %  (34 / 42)	  Total accuracy: 80.95 %   Semantic accuracy: 80.95 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 21.53 %  (146 / 678)	  Total accuracy: 25.00 %   Semantic accuracy: 25.00 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 23.20 %   Semantic accuracy: 23.20 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 7.49 %  (77 / 1028)	  Total accuracy: 14.25 %   Semantic accuracy: 14.25 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 58.89 %  (53 / 90)	  Total accuracy: 16.37 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 59.96 %  (277 / 462)	  Total accuracy: 24.92 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 59.96 %
#                 gram2-opposite: ACCURACY TOP1: 37.14 %  (78 / 210)	  Total accuracy: 25.92 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 52.83 %
#              gram3-comparative: ACCURACY TOP1: 46.67 %  (14 / 30)	  Total accuracy: 26.16 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 52.56 %
#              gram4-superlative: ACCURACY TOP1: 66.67 %  (4 / 6)	  Total accuracy: 26.25 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 52.68 %
#       gram5-present-participle: ACCURACY TOP1: 82.26 %  (765 / 930)	  Total accuracy: 41.00 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 69.47 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 41.44 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 69.22 %
#               gram7-past-tense: ACCURACY TOP1: 74.60 %  (940 / 1260)	  Total accuracy: 50.03 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 71.51 %
#                   gram8-plural: ACCURACY TOP1: 80.92 %  (526 / 650)	  Total accuracy: 53.67 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 73.20 %
#             gram9-plural-verbs: ACCURACY TOP1: 57.50 %  (345 / 600)	  Total accuracy: 54.05 %   Semantic accuracy: 16.37 %   Syntactic accuracy: 70.96 %
# Questions seen / total: 6113 17558   34.82 %
#
#       capital-common-countries: ACCURACY TOP1: 69.64 %  (39 / 56)	  Total accuracy: 69.64 %   Semantic accuracy: 69.64 %   Syntactic accuracy: 0.00 %
#                  capital-world: ACCURACY TOP1: 21.06 %  (143 / 679)	  Total accuracy: 24.76 %   Semantic accuracy: 24.76 %   Syntactic accuracy: 0.00 %
#                       currency: ACCURACY TOP1: 0.00 %  (0 / 56)	  Total accuracy: 23.01 %   Semantic accuracy: 23.01 %   Syntactic accuracy: 0.00 %
#                  city-in-state: ACCURACY TOP1: 7.16 %  (63 / 880)	  Total accuracy: 14.66 %   Semantic accuracy: 14.66 %   Syntactic accuracy: 0.00 %
#                         family: ACCURACY TOP1: 52.73 %  (58 / 110)	  Total accuracy: 17.01 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 0.00 %
#      gram1-adjective-to-adverb: ACCURACY TOP1: 61.26 %  (283 / 462)	  Total accuracy: 26.13 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 61.26 %
#                 gram2-opposite: ACCURACY TOP1: 44.29 %  (93 / 210)	  Total accuracy: 27.68 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 55.95 %
#              gram3-comparative: ACCURACY TOP1: 46.15 %  (6 / 13)	  Total accuracy: 27.78 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 55.77 %
#              gram4-superlative: ACCURACY TOP1: 66.67 %  (4 / 6)	  Total accuracy: 27.87 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 55.86 %
#       gram5-present-participle: ACCURACY TOP1: 82.26 %  (765 / 930)	  Total accuracy: 42.74 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 71.01 %
#    gram6-nationality-adjective: ACCURACY TOP1: 63.38 %  (45 / 71)	  Total accuracy: 43.16 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 70.69 %
#               gram7-past-tense: ACCURACY TOP1: 78.68 %  (1048 / 1332)	  Total accuracy: 53.01 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 74.21 %
#                   gram8-plural: ACCURACY TOP1: 82.00 %  (492 / 600)	  Total accuracy: 56.23 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 75.50 %
#             gram9-plural-verbs: ACCURACY TOP1: 68.83 %  (413 / 600)	  Total accuracy: 57.49 %   Semantic accuracy: 17.01 %   Syntactic accuracy: 74.55 %
# Questions seen / total: 6005 17487   34.34 %

# %% [markdown]
# #### Resumo
# ../models/ptWiki0920-norm-stop-cbow-300.bin ../testsets/LX-4WAnalogiesBr.txt 0.5405 Semantic accuracy: 16.37 %   Syntactic accuracy: 70.96 %
#
# ../models/ptWiki0920-norm-stop-cbow-300.bin ../testsets/LX-4WAnalogies.txt 0.5749 Semantic accuracy: 17.01 %   Syntactic accuracy: 74.55 %

# %% [markdown]
# ### Avaliação conjunta com Pool Multiprocessing

# %%
pt_wiki_model_list = glob('../models/ptWiki*')
testset = ['../testsets/LX-4WAnalogiesBr.txt', '../testsets/LX-4WAnalogies.txt']
ptWikiPool = multiprocessing.Pool()

PtWikiPool_res = ptWikiPool.starmap(eval_default_param, build_model_accuracy_tuple(pt_wiki_model_list, testset, get_facebook_vecs_word_analogy_accuracy, True
                                                                                  ))

# %% [markdown]
# ### Análise de acurácia para perguntas permutadas

# %% [markdown]
# * Observamos abaixo perguntas retiradas do testset, na categoria de país-capital. O objetivo é avaliar as permutações da perguntas para prever qualquer uma das palavras na pergunta, e não somente a ultima.

# %%
model = load_facebook_vectors('../models/ptWiki0920-norm-stop-cbow-300.bin')

# %%
model.most_similar(['PEQUIM','BERLIM'],['ALEMANHA'])
# Out:
# [('fonologia', 0.319120317697525),
#  ('gerativismo', 0.307516485452652),
#  ('brasileirismo', 0.3042718470096588),
#  ('informativas', 0.2936704158782959),
#  ('brasileiropop', 0.2915341854095459),
#  ('simporte', 0.29116183519363403),
#  ('sbpbrasil', 0.29109519720077515),
#  ('folclorismo', 0.28938236832618713),
#  ('xadrezismo', 0.288007915019989),
#  ('brasileirocopa', 0.2872498035430908)]

# %%
model.most_similar(['pequim','berlim'],['alemanha'])
# Out:
# [('xangai', 0.5828249454498291),
#  ('bequim', 0.5500543117523193),
#  ('nanquim', 0.5461136102676392),
#  ('zhangzhou', 0.5403828620910645),
#  ('moscou', 0.535670280456543),
#  ('sequim', 0.5303146839141846),
#  ('pequiz', 0.5237914323806763),
#  ('perlim', 0.5233457684516907),
#  ('moscovo', 0.5150915384292603),
#  ('equim', 0.5134990811347961)]

# %%
model.most_similar(['pequim','alemanha'],['berlim'])
# Out:
# [('china', 0.7143341302871704),
#  ('chinantec', 0.6527328491210938),
#  ('chinasa', 0.647666335105896),
#  ('chinanteca', 0.6465834379196167),
#  ('chinantecas', 0.6324456930160522),
#  ('chinanteco', 0.6302004456520081),
#  ('pequis', 0.6272468566894531),
#  ('pequisa', 0.6269203424453735),
#  ('chinampa', 0.6263154745101929),
#  ('pequi', 0.6219850778579712)]

# %%
model.most_similar(['pequim','egito'],['cairo'])
# Out:
# [('china', 0.6310254335403442),
#  ('chineses', 0.5763074159622192),
#  ('obshchina', 0.5600889921188354),
#  ('pequis', 0.5575646758079529),
#  ('chinas', 0.5570805072784424),
#  ('chinesas', 0.5569696426391602),
#  ('equim', 0.5536428689956665),
#  ('rpchina', 0.548112154006958),
#  ('dchina', 0.5416480302810669),
#  ('qinu', 0.5392635464668274)]

# %%
model.most_similar(['cairo','china'],['pequim'])
# Out:
# [('egito', 0.6022971868515015),
#  ('cairota', 0.5998178124427795),
#  ('cairom', 0.5903569459915161),
#  ('cairos', 0.5544114112854004),
#  ('chinameca', 0.53751540184021),
#  ('hadramaute', 0.5334338545799255),
#  ('cairoli', 0.5247357487678528),
#  ('chade', 0.5201066136360168),
#  ('cairate', 0.5193891525268555),
#  ('cairotas', 0.5183498859405518)]

# %%
model.most_similar(['china','cairo'],['egito'])
# Out:
# [('changzhou', 0.7101659178733826),
#  ('chengzhou', 0.6909531354904175),
#  ('chengdong', 0.6797289848327637),
#  ('changjiang', 0.6790489554405212),
#  ('chenzhou', 0.6721263527870178),
#  ('nanjing', 0.6717712879180908),
#  ('hangzhou', 0.6648585200309753),
#  ('suzhou', 0.6613156199455261),
#  ('shengzhou', 0.6567591428756714),
#  ('chongqing', 0.655300498008728)]

# %%
model.most_similar(['egito','pequim'],['china'])
# Out:
# [('cairo', 0.6343752145767212),
#  ('egipto', 0.6325528621673584),
#  ('atenas', 0.5384305119514465),
#  ('egipcio', 0.5347484946250916),
#  ('egitaniense', 0.5332800149917603),
#  ('nfis', 0.5308082103729248),
#  ('fara', 0.5289286375045776),
#  ('vegito', 0.5287285447120667),
#  ('egipcianos', 0.5267181396484375),
#  ('egira', 0.5257495045661926)]

# %%
print(results[0]['correct'][:5])
# Out:
# [('PEQUIM', 'CHINA', 'BERLIM', 'ALEMANHA'), ('PEQUIM', 'CHINA', 'CAIRO', 'EGITO'), ('PEQUIM', 'CHINA', 'HAVANA', 'CUBA'), ('PEQUIM', 'CHINA', 'LONDRES', 'INGLATERRA'), ('BERLIM', 'ALEMANHA', 'HAVANA', 'CUBA')]

# %%
model.most_similar(['pequim', 'espanha'],['madrid'])
# Out:
# [('china', 0.6547271013259888),
#  ('bequim', 0.617762565612793),
#  ('equim', 0.6094659566879272),
#  ('pequi', 0.6092944145202637),
#  ('chinanteca', 0.6052078008651733),
#  ('rpchina', 0.6035335063934326),
#  ('chinameca', 0.6020873188972473),
#  ('pequis', 0.5938908457756042),
#  ('pequito', 0.5929934978485107),
#  ('chineses', 0.5906508564949036)]

# %%
model.most_similar(['madrid','china'],['pequim'])
# Out:
# [('lamadrid', 0.6548174619674683),
#  ('madridreal', 0.6370139718055725),
#  ('vaciamadrid', 0.611453652381897),
#  ('madridborder', 0.601535439491272),
#  ('realmadrid', 0.5999178290367126),
#  ('madri', 0.5934512615203857),
#  ('atlmadrid', 0.5856846570968628),
#  ('telemadrid', 0.5812236070632935),
#  ('espanha', 0.5767569541931152),
#  ('valladolid', 0.5739721059799194)]

# %%
model.most_similar(['madrid','china'],['espanha'])
# Out:
# [('shangqing', 0.6008337736129761),
#  ('chines', 0.5941194295883179),
#  ('chinawut', 0.5900689363479614),
#  ('nanjing', 0.5899882316589355),
#  ('changjiang', 0.5898436307907104),
#  ('chinese', 0.589677095413208),
#  ('chengzhou', 0.5894589424133301),
#  ('chengjiang', 0.5893243551254272),
#  ('changzhou', 0.5885428786277771),
#  ('chongqing', 0.5862443447113037)]

# %%
model.most_similar(['pequim','noruega'],['oslo'])
# Out:
# [('china', 0.7162374258041382),
#  ('chinanteca', 0.6867305040359497),
#  ('pequis', 0.6672309041023254),
#  ('chinantec', 0.655956506729126),
#  ('chinantecas', 0.6506609916687012),
#  ('pequito', 0.6477333307266235),
#  ('chinampa', 0.6447343826293945),
#  ('pequiz', 0.644403874874115),
#  ('rpchina', 0.6389163732528687),
#  ('chinasa', 0.6379231214523315)]

# %%
model.most_similar(['pequim','noruega'],['china'])
# Out:
# [('oslo', 0.7026902437210083),
#  ('noruego', 0.6771032810211182),
#  ('norueg', 0.6520507335662842),
#  ('norueguesa', 0.6439430713653564),
#  ('noruegues', 0.6313618421554565),
#  ('noruegu', 0.6305091977119446),
#  ('estocolmo', 0.6284868717193604),
#  ('noruegueses', 0.608055591583252),
#  ('copenhague', 0.6065146327018738),
#  ('copenhaga', 0.603462815284729)]

# %%
model.most_similar(['oslo','china'],['noruega'])
# Out:
# [('pequim', 0.6368434429168701),
#  ('xangai', 0.6351529955863953),
#  ('chinai', 0.6303622722625732),
#  ('zhongyang', 0.6198270320892334),
#  ('zhongjing', 0.6137735843658447),
#  ('qianjiang', 0.6114833950996399),
#  ('nanjing', 0.611340343952179),
#  ('chinawut', 0.609315812587738),
#  ('changjiang', 0.6040310859680176),
#  ('chengjiang', 0.6036378741264343)]

# %%
model.most_similar(['oslo','china'],['pequim'])
# Out:
# [('oslofjord', 0.6721451282501221),
#  ('noruega', 0.6696286201477051),
#  ('norueg', 0.6479545831680298),
#  ('noruego', 0.596128523349762),
#  ('norwegen', 0.5603457689285278),
#  ('trondheimsfjord', 0.5560199022293091),
#  ('norwegian', 0.5538036227226257),
#  ('nordvik', 0.5483222603797913),
#  ('noruegu', 0.5473634600639343),
#  ('noruegues', 0.5457675457000732)]

# %%
print(results[0]['incorrect'][:5])
# Out:
# [('PEQUIM', 'CHINA', 'MADRID', 'ESPANHA'), ('PEQUIM', 'CHINA', 'OSLO', 'NORUEGA'), ('BERLIM', 'ALEMANHA', 'CAIRO', 'EGITO'), ('HAVANA', 'CUBA', 'MADRID', 'ESPANHA'), ('HAVANA', 'CUBA', 'OSLO', 'NORUEGA')]

# %%
# !rm ../models/ptWiki0920-noPP-skip-300.bin

# %% [markdown]
# * A partir dos resultados, observamos que não necessariamente a corretude de uma formação da pergunta garante o mesmo resultado para suas permutações.

# %% [markdown]
# * Embeddings multi-idiomas
# * Treino com AutoTune de parâmetros

# %% [markdown]
# ### Comparação OwnModel Br-Eng

# %%
ownTestset = glob('../testsets/own*')

# %%
models_for_own_testset = ['../models/ptWiki0920300-noPP-cbow-300.bin','../models/ext/fasttext/cc.pt.300.vec','../models/ext/nilc/skip_s300.txt']
keyed_vec_models_for_own_testset = ['../models/ext/nilc/skip_s300.txt']

# %%
print('testsets: ', ownTestset)
print('models to test: ', models_for_own_testset)
# Out:
# testsets:  ['../testsets/ownEng.txt', '../testsets/ownBR.txt']
# models to test:  ['../models/ptWiki0920300-noPP-cbow-300.bin', '../models/ext/fasttext/cc.pt.300.vec', '../models/ext/nilc/skip_s300.txt']

# %%
pool = multiprocessing.Pool()
own_test_br = '../testsets/ownBR.txt'
pool_res = pool.starmap(eval_all_params, [('../models/ptWiki0920300-noPP-cbow-300.bin',own_test_br, get_facebook_vecs_word_analogy_accuracy, True),
                                         ('../models/ext/fasttext/cc.pt.300.vec',own_test_br, get_facebook_vecs_word_analogy_accuracy, False),
                                         ('../models/ext/nilc/skip_s300.txt',own_test_br, get_facebook_vecs_word_analogy_accuracy, False)])
# Out:
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case insensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txt0.0 | case insensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case sensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txtNone | case sensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/ownBR.txt0.07407407407407407 | setting 0 to missing words | case insensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/ownBR.txt0.125 | case insensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case sensitive
# ../models/ext/nilc/skip_s300.txt @ ../testsets/ownBR.txtNone | case sensitive
# ../models/ext/fasttext/cc.pt.300.vec @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case insensitive
# ../models/ext/fasttext/cc.pt.300.vec @ ../testsets/ownBR.txt0.0 | case insensitive
# ../models/ext/fasttext/cc.pt.300.vec @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case sensitive
# ../models/ext/fasttext/cc.pt.300.vec @ ../testsets/ownBR.txt0.0 | case sensitive

# %%
pool = multiprocessing.Pool()
own_test_eng = '../testsets/ownEng.txt'
pool_res = pool.starmap(eval_all_params, [('../models/ext/fasttext//wiki-news-300d-1M-subword.vec',own_test_eng, get_facebook_vecs_word_analogy_accuracy, False),
                                         ('../models/ext/fasttext/wiki-news-300d-1M.vec',own_test_eng, get_facebook_vecs_word_analogy_accuracy, False)])
# Out:
# ../models/ext/fasttext//wiki-news-300d-1M-subword.vec @ ../testsets/ownEng.txt0.07407407407407407 | setting 0 to missing words | case insensitive
# ../models/ext/fasttext//wiki-news-300d-1M-subword.vec @ ../testsets/ownEng.txt0.2222222222222222 | case insensitive
# ../models/ext/fasttext//wiki-news-300d-1M-subword.vec @ ../testsets/ownEng.txt0.0 | setting 0 to missing words | case sensitive
# ../models/ext/fasttext//wiki-news-300d-1M-subword.vec @ ../testsets/ownEng.txt0.0 | case sensitive
# ../models/ext/fasttext/wiki-news-300d-1M.vec @ ../testsets/ownEng.txt0.07407407407407407 | setting 0 to missing words | case insensitive
# ../models/ext/fasttext/wiki-news-300d-1M.vec @ ../testsets/ownEng.txt0.2222222222222222 | case insensitive
# ../models/ext/fasttext/wiki-news-300d-1M.vec @ ../testsets/ownEng.txt0.0 | setting 0 to missing words | case sensitive
# ../models/ext/fasttext/wiki-news-300d-1M.vec @ ../testsets/ownEng.txt0.0 | case sensitive

# %%
eval_all_params('../models/ptWiki0920300-noPP-cbow-300.bin',own_test_br, get_facebook_vecs_word_analogy_accuracy, True)
# Out:
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case insensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txt0.0 | case insensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txt0.0 | setting 0 to missing words | case sensitive
# ../models/ptWiki0920300-noPP-cbow-300.bin @ ../testsets/ownBR.txtNone | case sensitive

# %% [markdown]
# ## [OLD] Treinando Modelos pre-processados e n-processados
# Dump BRwiki

# %% [markdown]
# # Referencia
#
# https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf
